# %%
# import
from xml.etree import ElementTree as ET
from xml.etree.ElementTree import Element, dump, ElementTree
import numpy as np

# Use Open source 'pubmed_parser'
import pubmed_parser as pp

# %%
# import glob

# targetPattern = r"pmid/*.txt"
# pmidFile = glob.glob(targetPattern)

# # convert python style path
# for i in range(len(pmidFile)):
#     pmidFile[i] = pmidFile[i].replace('\\', '/')
#     print(pmidFile[i])
# Out:
# pmid/pmid-Dornasealf-set.txt
# pmid/pmid-Lepirudin-set.txt
# pmid/pmid-Ximelagatr-set.txt

# %%
import pickle

with open("D:/WorkSpace/master_thesis/Drug_Bank/result/approved_pmid_100.pkl", "rb") as fr:
    approved_pmid = pickle.load(fr)

# %%
# Drug bank common name list
import pandas as pd
drugbank_approved_df = pd.read_csv('D:/WorkSpace/master_thesis/Drug_Bank/result/drugbank_approved.tsv', sep='\t')
drugName = drugbank_approved_df['name']

# %%
import requests
from lxml import etree
from lxml import html

# esearch ================================================================
# # Hyper parameter
# reldate = '3650' # 10 years
# retmax = '20'
# i = 0 # for test

# search_base = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term='
# search_url = search_base + drugName[i] + '[title]&reldate=' + reldate + '&datetype=pdat&retmax=' + retmax +'&usehistory=y'

# # get pmid xml data
# page = requests.get(search_url)
# tree = html.fromstring(page.content)

# # get pmid by drug name
# pmid_list = ''
# for pmid in tree.xpath("//idlist/id"):
#     pmid_list = ",".join(pmid_list)
# esearch ================================================================


# fetch_base = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=' 
# retmode = '&retmode=xml'

documents = dict()
for i in range(len(drugName)):
    # fetch by pmid
    pmid_list = ",".join(approved_pmid[drugName[i]])

    try:
        data = pp.parse_xml_web(pmid_list, sleep=1, save_xml=False)
        title = data['title']
        abstract = data['abstract']
        
        if title is not None:
            documents[drugName[i]] = (title + ' ' + abstract + ' ')
            print(str(i) + '. '  + drugName[i] + ' - Success getting documents'  )
        else:
            print(str(i) + '. - No result')
            
    except Exception as e:
        print(str(i) + '. ' + drugName[i] +' - Fail')
        print(e)
# Out:
# 0. Lepirudin - Success getting documents
# 1. Cetuximab - Success getting documents
# 2. Dornase alfa - Success getting documents
# 3. Denileukin diftitox - Success getting documents
# 4. Etanercept - Success getting documents
# 5. Bivalirudin - Success getting documents
# 6. Leuprolide - Success getting documents
# 7. Peginterferon alfa-2a - Success getting documents
# 8. Alteplase - Success getting documents
# 9. Sermorelin - Success getting documents
# 10. Interferon alfa-n1 - Success getting documents
# 11. Darbepoetin alfa - Success getting documents
# 12. Urokinase - Fail
# sequence item 57: expected str instance, NoneType found
# 13. Goserelin - Success getting documents
# 14. Reteplase - Success getting documents
# 15. Erythropoietin - Success getting documents
# 16. Salmon calcitonin - Success getting documents
# 17. Interferon alfa-n3 - Success getting documents
# 18. Pegfilgrastim - Success getting documents
# 19. Sargramostim - Success getting documents
# 20. Peginterferon alfa-2b - Success getting documents
# 21. Asparaginase Escherichia coli - Success getting documents
# 22. Thyrotropin alfa - Success getting documents
# 23. Antihemophilic factor, human recombinant - Success getting documents
# 24. Anakinra - Success getting documents
# 25. Gramicidin D - Success getting documents
# 26. Human immunoglobulin G - Success getting documents
# 27. Anistreplase - Success getting documents
# 28. Insulin human - Success getting documents
# 29. Tenecteplase - Success getting documents
# 30. Menotropins - Success getting documents
# 31. Interferon gamma-1b - Success getting documents
# 32. Interferon alfa-2a, Recombinant - Success getting documents
# 33. Desmopressin - Success getting documents
# 34. Coagulation factor VIIa Recombinant Human - Success getting documents
# 35. Oprelvekin - Success getting documents
# 36. Palifermin - Success getting documents
# 37. Glucagon - Success getting documents
# 38. Aldesleukin - Success getting documents
# 39. Botulinum Toxin Type B - Success getting documents
# 40. Omalizumab - Success getting documents
# 41. Lutropin alfa - Success getting documents
# 42. Lyme disease vaccine (recombinant OspA) - Success getting documents
# 43. Insulin lispro - Success getting documents
# 44. Insulin glargine - Fail
# sequence item 65: expected str instance, NoneType found
# 45. Collagenase clostridium histolyticum - Success getting documents
# 46. Rasburicase - Success getting documents
# 47. Cetrorelix - Success getting documents
# 48. Adalimumab - Fail
# sequence item 42: expected str instance, NoneType found
# 49. Somatotropin - Success getting documents
# 50. Imiglucerase - Success getting documents
# 51. Abciximab - Success getting documents
# 52. Drotrecogin alfa - Success getting documents
# 53. Gemtuzumab ozogamicin - Success getting documents
# 54. Alpha-1-proteinase inhibitor - Success getting documents
# 55. Pegaspargase - Success getting documents
# 56. Interferon beta-1a - Success getting documents
# 57. Pegademase - Success getting documents
# 58. Albumin human - Success getting documents
# 59. Eptifibatide - Success getting documents
# 60. Infliximab - Success getting documents
# 61. Follitropin - Success getting documents
# 62. Vasopressin - Success getting documents
# 63. Interferon beta-1b - Success getting documents
# 64. Interferon alfacon-1 - Success getting documents
# 65. Hyaluronidase (ovine) - Success getting documents
# 66. Insulin pork - Success getting documents
# 67. Trastuzumab - Fail
# sequence item 43: expected str instance, NoneType found
# 68. Rituximab - Fail
# sequence item 69: expected str instance, NoneType found
# 69. Basiliximab - Success getting documents
# 70. Muromonab - Success getting documents
# 71. Digoxin Immune Fab (Ovine) - Success getting documents
# 72. Ibritumomab tiuxetan - Fail
# sequence item 5: expected str instance, NoneType found
# 73. Daptomycin - Success getting documents
# 74. Tositumomab - Success getting documents
# 75. Pegvisomant - Success getting documents
# 76. Botulinum toxin type A - Success getting documents
# 77. Pancrelipase - Success getting documents
# 78. Streptokinase - Success getting documents
# 79. Alemtuzumab - Success getting documents
# 80. Alglucerase - Success getting documents
# 81. Capromab pendetide - Success getting documents
# 82. Laronidase - Success getting documents
# 83. Cyclosporine - Success getting documents
# 84. Alefacept - Fail
# sequence item 2: expected str instance, NoneType found
# 85. Urofollitropin - Success getting documents
# 86. Efalizumab - Success getting documents
# 87. Choriogonadotropin alfa - Success getting documents
# 88. Antithymocyte immunoglobulin (rabbit) - Success getting documents
# 89. Filgrastim - Success getting documents
# 90. Coagulation Factor IX (Recombinant) - Success getting documents
# 91. Becaplermin - Success getting documents
# 92. Agalsidase beta - Success getting documents
# 93. Octreotide - Success getting documents
# 94. Interferon alfa-2b - Success getting documents
# 95. Abarelix - Success getting documents
# 96. Oxytocin - Fail
# sequence item 2: expected str instance, NoneType found
# 97. Natalizumab - Success getting documents
# 98. Enfuvirtide - Success getting documents
# 99. Palivizumab - Success getting documents
# 100. Bevacizumab - Success getting documents
# 101. Pyridoxal phosphate - Fail
# sequence item 9: expected str instance, NoneType found
# 102. Cyanocobalamin - Success getting documents
# 103. Ademetionine - Success getting documents
# 104. Pyruvic acid - Success getting documents
# 105. Phenylalanine - Fail
# sequence item 5: expected str instance, NoneType found
# 106. Biotin - Success getting documents
# 107. Choline - Fail
# sequence item 14: expected str instance, NoneType found
# 108. L-Lysine - Success getting documents
# 109. Ascorbic acid - Fail
# sequence item 5: expected str instance, NoneType found
# 110. Aspartic acid - Success getting documents
# 111. Ornithine - Success getting documents
# 112. L-Glutamine - Success getting documents
# 113. Adenosine phosphate - Success getting documents
# 114. alpha-Linolenic acid - Success getting documents
# 115. Methionine - Fail
# sequence item 62: expected str instance, NoneType found
# 116. Tyrosine - Success getting documents
# 117. Calcitriol - Success getting documents
# 118. Lutein - Fail
# sequence item 82: expected str instance, NoneType found
# 119. Cystine - Fail
# sequence item 59: expected str instance, NoneType found
# 120. Succinic acid - Fail
# sequence item 19: expected str instance, NoneType found
# 121. Riboflavin - Success getting documents
# 122. N-Acetylglucosamine - Fail
# sequence item 1: expected str instance, NoneType found
# 123. Glutamic acid - Success getting documents
# 124. Glutathione - Fail
# sequence item 6: expected str instance, NoneType found
# 125. Glycine - Success getting documents
# 126. Calcifediol - Success getting documents
# 127. Creatine - Success getting documents
# 128. Tryptophan - Success getting documents
# 129. Cysteine - Success getting documents
# 130. Thiamine - Success getting documents
# 131. Ergocalciferol - Success getting documents
# 132. Threonine - Fail
# sequence item 61: expected str instance, NoneType found
# 133. NADH - Fail
# sequence item 37: expected str instance, NoneType found
# 134. Folic acid - Success getting documents
# 135. Icosapent - Success getting documents
# 136. Valine - Success getting documents
# 137. Vitamin A - Fail
# sequence item 33: expected str instance, NoneType found
# 138. Vitamin E - Success getting documents
# 139. Pyridoxine - Success getting documents
# 140. Lipoic acid - Fail
# sequence item 87: expected str instance, NoneType found
# 141. Cholecalciferol - Success getting documents
# 142. Menadione - Success getting documents
# 143. Adenine - Success getting documents
# 144. Asparagine - Success getting documents
# 145. Pravastatin - Success getting documents
# 146. Fluvoxamine - Success getting documents
# 147. Valsartan - Success getting documents
# 148. Ramipril - Success getting documents
# 149. Masoprocol - Success getting documents
# 150. Flunisolide - Success getting documents
# 151. Baclofen - Success getting documents
# 152. Amphetamine - Success getting documents
# 153. Pentagastrin - Success getting documents
# 154. Nicotine - Success getting documents
# 155. Cevimeline - Success getting documents
# 156. Lorazepam - Success getting documents
# 157. Esmolol - Success getting documents
# 158. Bortezomib - Success getting documents
# 159. Ethchlorvynol - Success getting documents
# 160. Carbidopa - Success getting documents
# 161. Phentermine - Success getting documents
# 162. Indecainide - Success getting documents
# 163. Tramadol - Success getting documents
# 164. Vidarabine - Success getting documents
# 165. Betaxolol - Success getting documents
# 166. Fluconazole - Fail
# sequence item 16: expected str instance, NoneType found
# 167. Troglitazone - Success getting documents
# 168. Oseltamivir - Success getting documents
# 169. Erythromycin - Success getting documents
# 170. Hydroxocobalamin - Success getting documents
# 171. Caffeine - Success getting documents
# 172. Succinylcholine - Success getting documents
# 173. Sildenafil - Success getting documents
# 174. Dofetilide - Success getting documents
# 175. Pyrimethamine - Fail
# sequence item 14: expected str instance, NoneType found
# 176. Reserpine - Fail
# sequence item 6: expected str instance, NoneType found
# 177. Azithromycin - Success getting documents
# 178. Ticlopidine - Success getting documents
# 179. Trospium - Success getting documents
# 180. Adapalene - Success getting documents
# 181. Midodrine - Success getting documents
# 182. Pantoprazole - Success getting documents
# 183. Torasemide - Success getting documents
# 184. Citalopram - Fail
# sequence item 78: expected str instance, NoneType found
# 185. Eletriptan - Success getting documents
# 186. Bethanidine - Success getting documents
# 187. Moxifloxacin - Success getting documents
# 188. Oxyphenonium - Success getting documents
# 189. Nelfinavir - Success getting documents
# 190. Isoetharine - Success getting documents
# 191. Glimepiride - Fail
# sequence item 38: expected str instance, NoneType found
# 192. Diflorasone - Success getting documents
# 193. Indinavir - Success getting documents
# 194. Gadodiamide - Success getting documents
# 195. Guanadrel - Success getting documents
# 196. Lovastatin - Success getting documents
# 197. Enflurane - Success getting documents
# 198. Cefotiam - Success getting documents
# 199. Pregabalin - Success getting documents
# 200. Temazepam - Success getting documents
# 201. Aminosalicylic acid - Success getting documents
# 202. Reboxetine - Success getting documents
# 203. Milrinone - Success getting documents
# 204. Pipobroman - Success getting documents
# 205. Butabarbital - Success getting documents
# 206. Nevirapine - Success getting documents
# 207. Oxiconazole - Success getting documents
# 208. Alclometasone - Success getting documents
# 209. Butalbital - Success getting documents
# 210. Cladribine - Success getting documents
# 211. Ranolazine - Success getting documents
# 212. Mesalazine - Success getting documents
# 213. Benzatropine - Success getting documents
# 214. Ziprasidone - Success getting documents
# 215. Methysergide - Success getting documents
# 216. Cabergoline - Success getting documents
# 217. Idoxuridine - Success getting documents
# 218. Dapsone - Success getting documents
# 219. Terconazole - Success getting documents
# 220. Phenytoin - Success getting documents
# 221. Medrysone - Success getting documents
# 222. Doxycycline - Success getting documents
# 223. Diethylstilbestrol - Fail
# sequence item 44: expected str instance, NoneType found
# 224. Lymecycline - Success getting documents
# 225. Clotrimazole - Success getting documents
# 226. Calcium acetate - Success getting documents
# 227. Sulfanilamide - Success getting documents
# 228. Cycloserine - Fail
# sequence item 82: expected str instance, NoneType found
# 229. Anagrelide - Success getting documents
# 230. Carmustine - Fail
# sequence item 9: expected str instance, NoneType found
# 231. Sulfisoxazole - Success getting documents
# 232. Metoprolol - Success getting documents
# 233. Crotamiton - Success getting documents
# 234. Dicoumarol - Success getting documents
# 235. Cefmenoxime - Success getting documents
# 236. Ropinirole - Success getting documents
# 237. Isradipine - Success getting documents
# 238. Diatrizoate - Success getting documents
# 239. Betazole - Success getting documents
# 240. Topiramate - Success getting documents
# 241. Cefmetazole - Fail
# sequence item 5: expected str instance, NoneType found
# 242. Olmesartan - Success getting documents
# 243. Amsacrine - Success getting documents
# 244. Theophylline - Success getting documents
# 245. Argatroban - Success getting documents
# 246. Liothyronine - Success getting documents
# 247. Disopyramide - Success getting documents
# 248. Lidocaine - Success getting documents
# 249. Pamidronic acid - Success getting documents
# 250. Clemastine - Fail
# sequence item 4: expected str instance, NoneType found
# 251. Acarbose - Success getting documents
# 252. Venlafaxine - Fail
# sequence item 84: expected str instance, NoneType found
# 253. Conjugated estrogens - Success getting documents
# 254. Travoprost - Success getting documents
# 255. Amcinonide - Success getting documents
# 256. Atomoxetine - Success getting documents
# 257. Bleomycin - Success getting documents
# 258. Chlorambucil - Fail
# sequence item 70: expected str instance, NoneType found
# 259. Etomidate - Success getting documents
# 260. Raltitrexed - Success getting documents
# 261. Etonogestrel - Success getting documents
# 262. Morphine - Success getting documents
# 263. Ropivacaine - Success getting documents
# 264. Bupivacaine - Success getting documents
# 265. Dapiprazole - Success getting documents
# 266. Penciclovir - Fail
# sequence item 8: expected str instance, NoneType found
# 267. Tenofovir disoproxil - Success getting documents
# 268. Flucloxacillin - Success getting documents
# 269. Tranexamic acid - Success getting documents
# 270. Ertapenem - Fail
# sequence item 26: expected str instance, NoneType found
# 271. Desogestrel - Success getting documents
# 272. Mitomycin - Success getting documents
# 273. Talbutal - Success getting documents
# 274. Bexarotene - Success getting documents
# 275. Ibutilide - Success getting documents
# 276. Vindesine - Success getting documents
# 277. Chlorthalidone - Success getting documents
# 278. Pentobarbital - Fail
# sequence item 14: expected str instance, NoneType found
# 279. Valproic acid - Fail
# sequence item 75: expected str instance, NoneType found
# 280. Capreomycin - Fail
# sequence item 17: expected str instance, NoneType found
# 281. Zolmitriptan - Fail
# sequence item 23: expected str instance, NoneType found
# 282. Acetaminophen - Success getting documents
# 283. Gefitinib - Success getting documents
# 284. Codeine - Success getting documents
# 285. Piperacillin - Success getting documents
# 286. Dihydroergotamine - Fail
# sequence item 1: expected str instance, NoneType found
# 287. Amitriptyline - Success getting documents
# 288. Floxuridine - Success getting documents
# 289. Tolcapone - Success getting documents
# 290. Fluorometholone - Success getting documents
# 291. Nitroprusside - Success getting documents
# 292. Calcium glucoheptonate - Success getting documents
# 293. Hydromorphone - Success getting documents
# 294. Indomethacin - Success getting documents
# 295. Ethambutol - Fail
# sequence item 35: expected str instance, NoneType found
# 296. Metformin - Success getting documents
# 297. Ipratropium - Success getting documents
# 298. Methadone - Fail
# sequence item 14: expected str instance, NoneType found
# 299. Olanzapine - Fail
# sequence item 91: expected str instance, NoneType found
# 300. Atenolol - Success getting documents
# 301. Nitrofural - Success getting documents
# 302. Pimecrolimus - Success getting documents
# 303. Omeprazole - Success getting documents
# 304. Pyrazinamide - Fail
# sequence item 35: expected str instance, NoneType found
# 305. Metixene - Success getting documents
# 306. Cetirizine - Success getting documents
# 307. Terfenadine - Success getting documents
# 308. Diltiazem - Success getting documents
# 309. Protriptyline - Success getting documents
# 310. Aminohippuric acid - Success getting documents
# 311. Alfuzosin - Success getting documents
# 312. Trimethadione - Success getting documents
# 313. Nitisinone - Success getting documents
# 314. Clobazam - Success getting documents
# 315. Minoxidil - Success getting documents
# 316. Megestrol acetate - Success getting documents
# 317. Tioguanine - Success getting documents
# 318. Methylergometrine - Success getting documents
# 319. Buclizine - Success getting documents
# 320. Aztreonam - Fail
# sequence item 11: expected str instance, NoneType found
# 321. Chlorzoxazone - Success getting documents
# 322. Aminoglutethimide - Success getting documents
# 323. Mefloquine - Success getting documents
# 324. Sulfadiazine - Success getting documents
# 325. Sapropterin - Success getting documents
# 326. Vinorelbine - Success getting documents
# 327. Anidulafungin - Fail
# sequence item 51: expected str instance, NoneType found
# 328. Clozapine - Success getting documents
# 329. Sucralfate - Success getting documents
# 330. Grepafloxacin - Success getting documents
# 331. Doxylamine - Success getting documents
# 332. Levonorgestrel - Success getting documents
# 333. Norepinephrine - Fail
# sequence item 52: expected str instance, NoneType found
# 334. Cidofovir - Success getting documents
# 335. Mirtazapine - Success getting documents
# 336. Meprobamate - Success getting documents
# 337. Thiethylperazine - Success getting documents
# 338. Timolol - Success getting documents
# 339. Treprostinil - Success getting documents
# 340. Colestipol - Success getting documents
# 341. Trihexyphenidyl - Success getting documents
# 342. Palonosetron - Success getting documents
# 343. Dydrogesterone - Success getting documents
# 344. Mexiletine - Success getting documents
# 345. Dexrazoxane - Success getting documents
# 346. Amlodipine - Success getting documents
# 347. Tacrine - Success getting documents
# 348. Oxyphencyclimine - Success getting documents
# 349. Triamterene - Success getting documents
# 350. Valrubicin - Success getting documents
# 351. Procyclidine - Success getting documents
# 352. Phenylephrine - Success getting documents
# 353. Carbimazole - Success getting documents
# 354. Digoxin - Success getting documents
# 355. Sulpiride - Success getting documents
# 356. Profenamine - Success getting documents
# 357. Nimodipine - Success getting documents
# 358. Beclomethasone dipropionate - Success getting documents
# 359. Carisoprodol - Success getting documents
# 360. Progesterone - Success getting documents
# 361. Phenylpropanolamine - Success getting documents
# 362. Sorafenib - Success getting documents
# 363. Zoledronic acid - Success getting documents
# 364. Griseofulvin - Success getting documents
# 365. Nisoldipine - Success getting documents
# 366. Eszopiclone - Success getting documents
# 367. Ceruletide - Success getting documents
# 368. Alprazolam - Success getting documents
# 369. Dexbrompheniramine - Success getting documents
# 370. Gentian violet cation - Success getting documents
# 371. Ardeparin - Success getting documents
# 372. Loxapine - Success getting documents
# 373. Remoxipride - Success getting documents
# 374. Mupirocin - Fail
# sequence item 78: expected str instance, NoneType found
# 375. Carbamoylcholine - Success getting documents
# 376. Rosiglitazone - Success getting documents
# 377. Pramipexole - Success getting documents
# 378. Acetohexamide - Success getting documents
# 379. Ampicillin - Fail
# sequence item 15: expected str instance, NoneType found
# 380. Metocurine iodide - Success getting documents
# 381. Phenoxymethylpenicillin - Success getting documents
# 382. Secobarbital - Success getting documents
# 383. Miglustat - Success getting documents
# 384. Promazine - Success getting documents
# 385. Spironolactone - Success getting documents
# 386. Methylphenidate - Success getting documents
# 387. Methocarbamol - Success getting documents
# 388. Hyoscyamine - Success getting documents
# 389. Zolpidem - Success getting documents
# 390. Famciclovir - Success getting documents
# 391. Triprolidine - Success getting documents
# 392. Streptozocin - Fail
# sequence item 6: expected str instance, NoneType found
# 393. Carboprost tromethamine - Success getting documents
# 394. Cefpiramide - Success getting documents
# 395. Lindane - Success getting documents
# 396. Trifluridine - Success getting documents
# 397. Prochlorperazine - Success getting documents
# 398. Cyproheptadine - Success getting documents
# 399. Nitric Oxide - Success getting documents
# 400. Bendroflumethiazide - Success getting documents
# 401. Allopurinol - Success getting documents
# 402. Ceftazidime - Fail
# sequence item 39: expected str instance, NoneType found
# 403. Cerivastatin - Success getting documents
# 404. Trimethoprim - Fail
# sequence item 6: expected str instance, NoneType found
# 405. Gemcitabine - Success getting documents
# 406. Entecavir - Success getting documents
# 407. Betamethasone - Success getting documents
# 408. Teniposide - Success getting documents
# 409. Epirubicin - Fail
# sequence item 15: expected str instance, NoneType found
# 410. Chloramphenicol - Success getting documents
# 411. Loracarbef - Success getting documents
# 412. Lansoprazole - Fail
# sequence item 15: expected str instance, NoneType found
# 413. Dipivefrin - Success getting documents
# 414. Droperidol - Success getting documents
# 415. Levothyroxine - Success getting documents
# 416. Framycetin - Success getting documents
# 417. Meperidine - Success getting documents
# 418. Loratadine - Success getting documents
# 419. Cefalotin - Success getting documents
# 420. Prazosin - Fail
# sequence item 14: expected str instance, NoneType found
# 421. Imipramine - Success getting documents
# 422. Acitretin - Success getting documents
# 423. Verteporfin - Success getting documents
# 424. Nabumetone - Success getting documents
# 425. Methscopolamine bromide - Success getting documents
# 426. Sodium tetradecyl sulfate - Success getting documents
# 427. Ketorolac - Fail
# sequence item 94: expected str instance, NoneType found
# 428. Enoxacin - Success getting documents
# 429. Quinine - Success getting documents
# 430. Tenoxicam - Success getting documents
# 431. Dronabinol - Success getting documents
# 432. Montelukast - Success getting documents
# 433. Fluoxetine - Success getting documents
# 434. Hexylcaine - Success getting documents
# 435. Methohexital - Success getting documents
# 436. Chlordiazepoxide - Success getting documents
# 437. Duloxetine - Success getting documents
# 438. Chlorpromazine - Success getting documents
# 439. Rimantadine - Success getting documents
# 440. Amikacin - Fail
# sequence item 33: expected str instance, NoneType found
# 441. Lenalidomide - Success getting documents
# 442. Raloxifene - Success getting documents
# 443. Celecoxib - Fail
# sequence item 6: expected str instance, NoneType found
# 444. Gallamine triethiodide - Success getting documents
# 445. Brimonidine - Success getting documents
# 446. Dicloxacillin - Success getting documents
# 447. Nabilone - Success getting documents
# 448. Pefloxacin - Success getting documents
# 449. Altretamine - Success getting documents
# 450. Sotalol - Success getting documents
# 451. Buspirone - Success getting documents
# 452. Miglitol - Success getting documents
# 453. Fosinopril - Success getting documents
# 454. Cefotaxime - Success getting documents
# 455. Entacapone - Success getting documents
# 456. Zidovudine - Fail
# sequence item 44: expected str instance, NoneType found
# 457. Darifenacin - Success getting documents
# 458. Oxycodone - Success getting documents
# 459. Phenindione - Success getting documents
# 460. Flutamide - Success getting documents
# 461. Tolmetin - Success getting documents
# 462. Cimetidine - Fail
# sequence item 13: expected str instance, NoneType found
# 463. Haloperidol - Fail
# sequence item 67: expected str instance, NoneType found
# 464. Ritonavir - Success getting documents
# 465. Levallorphan - Success getting documents
# 466. Nitazoxanide - Success getting documents
# 467. Triflupromazine - Success getting documents
# 468. Dextrothyroxine - Success getting documents
# 469. Acetyldigitoxin - Success getting documents
# 470. Vancomycin - Fail
# sequence item 90: expected str instance, NoneType found
# 471. Aminocaproic acid - Success getting documents
# 472. Dextromethorphan - Fail
# sequence item 6: expected str instance, NoneType found
# 473. Cisplatin - Success getting documents
# 474. Bentoquatam - Success getting documents
# 475. Anisotropine methylbromide - Success getting documents
# 476. Albendazole - Fail
# sequence item 72: expected str instance, NoneType found
# 477. Trandolapril - Success getting documents
# 478. Caspofungin - Success getting documents
# 479. Carteolol - Success getting documents
# 480. Alitretinoin - Success getting documents
# 481. Metolazone - Success getting documents
# 482. Tolnaftate - Success getting documents
# 483. Oxaliplatin - Fail
# sequence item 50: expected str instance, NoneType found
# 484. Cinchocaine - Success getting documents
# 485. Lercanidipine - Fail
# sequence item 3: expected str instance, NoneType found
# 486. Foscarnet - Success getting documents
# 487. Erlotinib - Success getting documents
# 488. Cyclophosphamide - Fail
# sequence item 10: expected str instance, NoneType found
# 489. Mephenytoin - Success getting documents
# 490. Rofecoxib - Success getting documents
# 491. Chlormerodrin - Success getting documents
# 492. Cefdinir - Success getting documents
# 493. Guanidine - Fail
# sequence item 63: expected str instance, NoneType found
# 494. Ciprofloxacin - Success getting documents
# 495. Gadoversetamide - Success getting documents
# 496. Toremifene - Success getting documents
# 497. Nortriptyline - Success getting documents
# 498. Vincristine - Fail
# sequence item 65: expected str instance, NoneType found
# 499. Benazepril - Success getting documents
# 500. Amoxapine - Success getting documents
# 501. Fluorouracil - Success getting documents
# 502. Pyridostigmine - Success getting documents
# 503. Desoximetasone - Success getting documents
# 504. Azelaic acid - Success getting documents
# 505. Zafirlukast - Success getting documents
# 506. Propylthiouracil - Fail
# sequence item 42: expected str instance, NoneType found
# 507. Acetohydroxamic acid - Success getting documents
# 508. Pentostatin - Success getting documents
# 509. Methoxsalen - Success getting documents
# 510. Piroxicam - Fail
# sequence item 24: expected str instance, NoneType found
# 511. Lamotrigine - Success getting documents
# 512. Perflutren - Success getting documents
# 513. Hydroxyzine - Success getting documents
# 514. Zanamivir - Fail
# sequence item 21: expected str instance, NoneType found
# 515. Bosentan - Fail
# sequence item 2: expected str instance, NoneType found
# 516. Tigecycline - Fail
# sequence item 7: expected str instance, NoneType found
# 517. Doxapram - Success getting documents
# 518. Benzthiazide - Success getting documents
# 519. Methotrexate - Fail
# sequence item 47: expected str instance, NoneType found
# 520. Carbamazepine - Fail
# sequence item 69: expected str instance, NoneType found
# 521. Cisatracurium - Success getting documents
# 522. Succimer - Success getting documents
# 523. Cephalexin - Success getting documents
# 524. Cinnarizine - Success getting documents
# 525. Fondaparinux - Success getting documents
# 526. Vinblastine - Success getting documents
# 527. Propranolol - Fail
# sequence item 56: expected str instance, NoneType found
# 528. Atropine - Success getting documents
# 529. Fenoprofen - Success getting documents
# 530. Fenfluramine - Success getting documents
# 531. Clonidine - Success getting documents
# 532. Sulfamethizole - Success getting documents
# 533. Valaciclovir - Success getting documents
# 534. Carbenicillin - Success getting documents
# 535. Mazindol - Success getting documents
# 536. Valdecoxib - Success getting documents
# 537. Lactulose - Success getting documents
# 538. Voriconazole - Fail
# sequence item 9: expected str instance, NoneType found
# 539. Levocarnitine - Success getting documents
# 540. Enalapril - Success getting documents
# 541. Nizatidine - Success getting documents
# 542. Diclofenac - Fail
# sequence item 12: expected str instance, NoneType found
# 543. Fluticasone propionate - Success getting documents
# 544. Lisuride - Success getting documents
# 545. Doxazosin - Success getting documents
# 546. Fluocinolone acetonide - Success getting documents
# 547. Piperazine - Success getting documents
# 548. Ethosuximide - Success getting documents
# 549. Amiloride - Success getting documents
# 550. Oxytetracycline - Success getting documents
# 551. Ulobetasol - Success getting documents
# 552. Gadoteridol - Success getting documents
# 553. Labetalol - Success getting documents
# 554. Thiopental - Success getting documents
# 555. Monobenzone - Success getting documents
# 556. Linezolid - Fail
# sequence item 99: expected str instance, NoneType found
# 557. Ivermectin - Success getting documents
# 558. Medroxyprogesterone acetate - Success getting documents
# 559. Cisapride - Success getting documents
# 560. Sulindac - Success getting documents
# 561. Cyclothiazide - Success getting documents
# 562. Nafcillin - Fail
# sequence item 40: expected str instance, NoneType found
# 563. Chloroquine - Success getting documents
# 564. Ethionamide - Success getting documents
# 565. Metaraminol - Success getting documents
# 566. Butorphanol - Success getting documents
# 567. Bisoprolol - Success getting documents
# 568. Amodiaquine - Success getting documents
# 569. Furazolidone - Success getting documents
# 570. Rifabutin - Fail
# sequence item 42: expected str instance, NoneType found
# 571. Paramethadione - Success getting documents
# 572. Demeclocycline - Success getting documents
# 573. Imatinib - Fail
# sequence item 25: expected str instance, NoneType found
# 574. Triamcinolone - Success getting documents
# 575. Oxandrolone - Success getting documents
# 576. Nicardipine - Success getting documents
# 577. Fluphenazine - Success getting documents
# 578. Testosterone - Fail
# sequence item 1: expected str instance, NoneType found
# 579. Efavirenz - Success getting documents
# 580. Bacitracin - Success getting documents
# 581. Niacin - Success getting documents
# 582. Clorazepic acid - Success getting documents
# 583. Guanabenz - Success getting documents
# 584. Alendronic acid - Success getting documents
# 585. Clofarabine - Success getting documents
# 586. Docosanol - Success getting documents
# 587. Dexmedetomidine - Success getting documents
# 588. Sulfacetamide - Success getting documents
# 589. Prednisone - Success getting documents
# 590. Clofibrate - Success getting documents
# 591. Astemizole - Success getting documents
# 592. Inulin - Fail
# sequence item 58: expected str instance, NoneType found
# 593. Butoconazole - Success getting documents
# 594. Adenosine - Fail
# sequence item 56: expected str instance, NoneType found
# 595. Simvastatin - Success getting documents
# 596. Pemetrexed - Success getting documents
# 597. Mebendazole - Fail
# sequence item 39: expected str instance, NoneType found
# 598. Gonadorelin - Success getting documents
# 599. Dyclonine - Success getting documents
# 600. Nystatin - Success getting documents
# 601. Dextropropoxyphene - Success getting documents
# 602. Mitotane - Success getting documents
# 603. Stavudine - Success getting documents
# 604. Leucovorin - Success getting documents
# 605. Dyphylline - Success getting documents
# 606. Pentazocine - Success getting documents
# 607. Magnesium sulfate - Success getting documents
# 608. Latanoprost - Success getting documents
# 609. Estrone - Fail
# sequence item 43: expected str instance, NoneType found
# 610. Trazodone - Fail
# sequence item 95: expected str instance, NoneType found
# 611. Mecamylamine - Success getting documents
# 612. Sevelamer - Success getting documents
# 613. Acamprosate - Success getting documents
# 614. Metaxalone - Success getting documents
# 615. Verapamil - Fail
# sequence item 13: expected str instance, NoneType found
# 616. Trimethobenzamide - Success getting documents
# 617. Flumethasone - Success getting documents
# 618. Sulfametopyrazine - Success getting documents
# 619. Nilutamide - Fail
# sequence item 8: expected str instance, NoneType found
# 620. Nafarelin - Success getting documents
# 621. Epinephrine - Success getting documents
# 622. Sumatriptan - Success getting documents
# 623. Pirenzepine - Success getting documents
# 624. Cefixime - Success getting documents
# 625. Chlorpropamide - Success getting documents
# 626. Aprepitant - Success getting documents
# 627. Galantamine - Success getting documents
# 628. Tamoxifen - Fail
# sequence item 22: expected str instance, NoneType found
# 629. Benzyl benzoate - Success getting documents
# 630. Isoflurophate - Success getting documents
# 631. Losartan - Success getting documents
# 632. Thioridazine - Success getting documents
# 633. Moricizine - Success getting documents
# 634. Amphotericin B - Fail
# sequence item 22: expected str instance, NoneType found
# 635. Warfarin - Success getting documents
# 636. Midazolam - Success getting documents
# 637. Tobramycin - Fail
# sequence item 65: expected str instance, NoneType found
# 638. Trovafloxacin - Success getting documents
# 639. Pentosan polysulfate - Success getting documents
# 640. Fludrocortisone - Success getting documents
# 641. Mycophenolate mofetil - Success getting documents
# 642. Cephaloglycin - Success getting documents
# 643. Flurazepam - Success getting documents
# 644. Moexipril - Success getting documents
# 645. Phentolamine - Success getting documents
# 646. Fluorescein - Fail
# sequence item 13: expected str instance, NoneType found
# 647. Daunorubicin - Success getting documents
# 648. Furosemide - Success getting documents
# 649. Ergotamine - Fail
# sequence item 1: expected str instance, NoneType found
# 650. Tizanidine - Success getting documents
# 651. Nitrofurantoin - Success getting documents
# 652. Nicergoline - Success getting documents
# 653. Eplerenone - Fail
# sequence item 94: expected str instance, NoneType found
# 654. Amprenavir - Success getting documents
# 655. Icodextrin - Success getting documents
# 656. Methazolamide - Success getting documents
# 657. Naltrexone - Fail
# sequence item 39: expected str instance, NoneType found
# 658. Delavirdine - Success getting documents
# 659. Tamsulosin - Success getting documents
# 660. Porfimer sodium - Success getting documents
# 661. Sufentanil - Fail
# sequence item 1: expected str instance, NoneType found
# 662. Lamivudine - Fail
# sequence item 24: expected str instance, NoneType found
# 663. Ibandronate - Success getting documents
# 664. Diethylcarbamazine - Success getting documents
# 665. Flurbiprofen - Success getting documents
# 666. Oxacillin - Fail
# sequence item 35: expected str instance, NoneType found
# 667. Apomorphine - Fail
# sequence item 44: expected str instance, NoneType found
# 668. Paroxetine - Success getting documents
# 669. Nedocromil - Success getting documents
# 670. Norethisterone - Success getting documents
# 671. Adefovir dipivoxil - Success getting documents
# 672. Azatadine - Success getting documents
# 673. Clodronic acid - Success getting documents
# 674. Procaine - Success getting documents
# 675. Lisinopril - Success getting documents
# 676. Methoxamine - Success getting documents
# 677. Imiquimod - Fail
# sequence item 65: expected str instance, NoneType found
# 678. Homatropine methylbromide - Success getting documents
# 679. Trimipramine - Success getting documents
# 680. Nitroglycerin - Success getting documents
# 681. Rocuronium - Success getting documents
# 682. Thiabendazole - Success getting documents
# 683. Nateglinide - Success getting documents
# 684. Atracurium besylate - Success getting documents
# 685. Pralidoxime - Success getting documents
# 686. Risperidone - Fail
# sequence item 59: expected str instance, NoneType found
# 687. Naftifine - Fail
# sequence item 2: expected str instance, NoneType found
# 688. Esomeprazole - Success getting documents
# 689. Meclizine - Success getting documents
# 690. Pentamidine - Fail
# sequence item 36: expected str instance, NoneType found
# 691. Hetacillin - Success getting documents
# 692. Riluzole - Success getting documents
# 693. Hydrocortisone - Success getting documents
# 694. Mannitol - Fail
# sequence item 71: expected str instance, NoneType found
# 695. Gadobenic acid - Success getting documents
# 696. Zileuton - Success getting documents
# 697. Modafinil - Success getting documents
# 698. Deferoxamine - Success getting documents
# 699. Scopolamine - Fail
# sequence item 9: expected str instance, NoneType found
# 700. Carbinoxamine - Success getting documents
# 701. Etodolac - Success getting documents
# 702. Prilocaine - Success getting documents
# 703. Epinastine - Success getting documents
# 704. Tranylcypromine - Success getting documents
# 705. Isoflurane - Success getting documents
# 706. Ethotoin - Success getting documents
# 707. Tretinoin - Success getting documents
# 708. Hexachlorophene - Success getting documents
# 709. Dolasetron - Success getting documents
# 710. Clopidogrel - Fail
# sequence item 33: expected str instance, NoneType found
# 711. Tetracycline - Fail
# sequence item 78: expected str instance, NoneType found
# 712. Meropenem - Fail
# sequence item 74: expected str instance, NoneType found
# 713. Potassium chloride - Success getting documents
# 714. Irinotecan - Fail
# sequence item 3: expected str instance, NoneType found
# 715. Methimazole - Success getting documents
# 716. Metyrosine - Success getting documents
# 717. Clavulanic acid - Success getting documents
# 718. Olopatadine - Success getting documents
# 719. Hydrocortamate - Success getting documents
# 720. Alprostadil - Success getting documents
# 721. Clidinium - Success getting documents
# 722. Malathion - Success getting documents
# 723. Etoposide - Success getting documents
# 724. Hydroflumethiazide - Success getting documents
# 725. Tirofiban - Success getting documents
# 726. Oxcarbazepine - Fail
# sequence item 71: expected str instance, NoneType found
# 727. Propiomazine - Success getting documents
# 728. Roxithromycin - Success getting documents
# 729. Nalidixic acid - Success getting documents
# 730. Phenelzine - Success getting documents
# 731. Propantheline - Success getting documents
# 732. Estradiol - Success getting documents
# 733. Mefenamic acid - Success getting documents
# 734. Cryptenamine - Success getting documents
# 735. Acyclovir - Fail
# sequence item 26: expected str instance, NoneType found
# 736. Naproxen - Success getting documents
# 737. Gadopentetic acid - Success getting documents
# 738. Perindopril - Success getting documents
# 739. Uracil mustard - Success getting documents
# 740. Tripelennamine - Success getting documents
# 741. Haloprogin - Success getting documents
# 742. Primidone - Success getting documents
# 743. Sulfasalazine - Success getting documents
# 744. Candesartan cilexetil - Success getting documents
# 745. Tolazoline - Success getting documents
# 746. Gentamicin - Success getting documents
# 747. Tazarotene - Success getting documents
# 748. Fenoldopam - Success getting documents
# 749. Halazepam - Success getting documents
# 750. Alfentanil - Success getting documents
# 751. Colistin - Success getting documents
# 752. Dicyclomine - Success getting documents
# 753. Minaprine - Success getting documents
# 754. Pentoxifylline - Success getting documents
# 755. Proparacaine - Success getting documents
# 756. Indapamide - Success getting documents
# 757. Tropicamide - Success getting documents
# 758. Biperiden - Success getting documents
# 759. Ribavirin - Success getting documents
# 760. Phenylbutazone - Success getting documents
# 761. Fentanyl - Fail
# sequence item 95: expected str instance, NoneType found
# 762. Meloxicam - Success getting documents
# 763. Orciprenaline - Success getting documents
# 764. Rosoxacin - Success getting documents
# 765. Propofol - Success getting documents
# 766. Acetazolamide - Fail
# sequence item 8: expected str instance, NoneType found
# 767. Tadalafil - Success getting documents
# 768. Carprofen - Success getting documents
# 769. Disulfiram - Success getting documents
# 770. Ethynodiol diacetate - Success getting documents
# 771. Enprofylline - Success getting documents
# 772. Levomenthol - Success getting documents
# 773. Natamycin - Success getting documents
# 774. Cinoxacin - Success getting documents
# 775. Fosfomycin - Fail
# sequence item 18: expected str instance, NoneType found
# 776. Diazepam - Success getting documents
# 777. Phenmetrazine - Success getting documents
# 778. Trifluoperazine - Success getting documents
# 779. Phensuximide - Success getting documents
# 780. Cefaclor - Success getting documents
# 781. Mifepristone - Success getting documents
# 782. Brompheniramine - Success getting documents
# 783. Loperamide - Fail
# sequence item 16: expected str instance, NoneType found
# 784. Clocortolone - Success getting documents
# 785. Tolazamide - Success getting documents
# 786. Hydroxypropyl cellulose - Success getting documents
# 787. Dobutamine - Success getting documents
# 788. Oxazepam - Success getting documents
# 789. Donepezil - Success getting documents
# 790. Nalbuphine - Success getting documents
# 791. Clofazimine - Fail
# sequence item 17: expected str instance, NoneType found
# 792. Flurandrenolide - Success getting documents
# 793. Cysteamine - Fail
# sequence item 84: expected str instance, NoneType found
# 794. Levamisole - Success getting documents
# 795. Methylphenobarbital - Success getting documents
# 796. Perphenazine - Success getting documents
# 797. Dacarbazine - Success getting documents
# 798. Pseudoephedrine - Fail
# sequence item 45: expected str instance, NoneType found
# 799. Temozolomide - Fail
# sequence item 7: expected str instance, NoneType found
# 800. Levorphanol - Success getting documents
# 801. Aminolevulinic acid - Success getting documents
# 802. Chlorphenesin - Success getting documents
# 803. Terbinafine - Fail
# sequence item 31: expected str instance, NoneType found
# 804. Penicillamine - Success getting documents
# 805. Prednisolone - Fail
# sequence item 38: expected str instance, NoneType found
# 806. Diflunisal - Success getting documents
# 807. Vardenafil - Success getting documents
# 808. Ranitidine - Success getting documents
# 809. Tacrolimus - Success getting documents
# 810. Benzphetamine - Success getting documents
# 811. Ritodrine - Success getting documents
# 812. Benzonatate - Success getting documents
# 813. Dorzolamide - Success getting documents
# 814. Suprofen - Success getting documents
# 815. Terbutaline - Success getting documents
# 816. Conivaptan - Success getting documents
# 817. Loteprednol etabonate - Success getting documents
# 818. Guaifenesin - Success getting documents
# 819. Flupentixol - Success getting documents
# 820. Eprosartan - Success getting documents
# 821. Sirolimus - Success getting documents
# 822. Chlorhexidine - Success getting documents
# 823. Emtricitabine - Success getting documents
# 824. Chlorothiazide - Success getting documents
# 825. Quinapril - Success getting documents
# 826. Clomifene - Success getting documents
# 827. Isosorbide dinitrate - Success getting documents
# 828. Risedronic acid - Success getting documents
# 829. Pemirolast - Success getting documents
# 830. Bumetanide - Success getting documents
# 831. Mechlorethamine - Success getting documents
# 832. Granisetron - Success getting documents
# 833. Dienestrol - Success getting documents
# 834. Sulfapyridine - Success getting documents
# 835. Oxybuprocaine - Success getting documents
# 836. Iron Dextran - Success getting documents
# 837. Testolactone - Success getting documents
# 838. Benzylpenicilloyl polylysine - Success getting documents
# 839. Rimexolone - Success getting documents
# 840. Triazolam - Success getting documents
# 841. Ethanol - Fail
# sequence item 1: expected str instance, NoneType found
# 842. Remifentanil - Success getting documents
# 843. Didanosine - Fail
# sequence item 0: expected str instance, NoneType found
# 844. Methdilazine - Success getting documents
# 845. Etacrynic acid - Success getting documents
# 846. Ondansetron - Success getting documents
# 847. Bimatoprost - Success getting documents
# 848. Tiagabine - Success getting documents
# 849. Cocaine - Success getting documents
# 850. Quinidine - Success getting documents
# 851. Zonisamide - Success getting documents
# 852. Paricalcitol - Success getting documents
# 853. Tinidazole - Success getting documents
# 854. Repaglinide - Fail
# sequence item 18: expected str instance, NoneType found
# 855. Anileridine - Success getting documents
# 856. Phenformin - Success getting documents
# 857. Amantadine - Success getting documents
# 858. Metronidazole - Fail
# sequence item 13: expected str instance, NoneType found
# 859. Dinoprostone - Success getting documents
# 860. Almotriptan - Success getting documents
# 861. Spectinomycin - Success getting documents
# 862. Ketotifen - Success getting documents
# 863. Buprenorphine - Success getting documents
# 864. Levosimendan - Success getting documents
# 865. Ceforanide - Success getting documents
# 866. Cyclobenzaprine - Success getting documents
# 867. Phenoxybenzamine - Success getting documents
# 868. Famotidine - Success getting documents
# 869. Azacitidine - Fail
# sequence item 69: expected str instance, NoneType found
# 870. Misoprostol - Success getting documents
# 871. Colesevelam - Success getting documents
# 872. Metacycline - Success getting documents
# 873. Tipranavir - Success getting documents
# 874. Mesoridazine - Success getting documents
# 875. Maprotiline - Success getting documents
# 876. Oxymetazoline - Success getting documents
# 877. Salicylic acid - Success getting documents
# 878. Diethylpropion - Success getting documents
# 879. Salmeterol - Success getting documents
# 880. Meclofenamic acid - Success getting documents
# 881. Methantheline - Success getting documents
# 882. Hexafluronium - Success getting documents
# 883. Cycrimine - Success getting documents
# 884. Zalcitabine - Success getting documents
# 885. Demecarium - Success getting documents
# 886. Acetylsalicylic acid - Success getting documents
# 887. Phenprocoumon - Success getting documents
# 888. Fulvestrant - Fail
# sequence item 33: expected str instance, NoneType found
# 889. Mezlocillin - Success getting documents
# 890. Felbamate - Success getting documents
# 891. Fexofenadine - Success getting documents
# 892. Isoniazid - Success getting documents
# 893. Naratriptan - Success getting documents
# 894. Rizatriptan - Success getting documents
# 895. Netilmicin - Success getting documents
# 896. Hydrocodone - Success getting documents
# 897. Norgestimate - Success getting documents
# 898. Carboplatin - Fail
# sequence item 11: expected str instance, NoneType found
# 899. Methylprednisolone - Fail
# sequence item 73: expected str instance, NoneType found
# 900. Pindolol - Success getting documents
# 901. Mepivacaine - Success getting documents
# 902. Zaleplon - Success getting documents
# 903. Bromfenac - Success getting documents
# 904. Apraclonidine - Success getting documents
# 905. Ethiodized oil - Success getting documents
# 906. Telmisartan - Success getting documents
# 907. Desloratadine - Success getting documents
# 908. Methyldopa - Success getting documents
# 909. Alosetron - Success getting documents
# 910. Dactinomycin - Success getting documents
# 911. Selenium Sulfide - Success getting documents
# 912. Azelastine - Success getting documents
# 913. Ezetimibe - Success getting documents
# 914. Edetic acid - Success getting documents
# 915. Dipyridamole - Success getting documents
# 916. Telithromycin - Fail
# sequence item 1: expected str instance, NoneType found
# 917. Ethinylestradiol - Success getting documents
# 918. Lomefloxacin - Success getting documents
# 919. Cyclopentolate - Success getting documents
# 920. Ramelteon - Success getting documents
# 921. Physostigmine - Success getting documents
# 922. Isotretinoin - Success getting documents
# 923. Formoterol - Success getting documents
# 924. Nandrolone phenpropionate - Success getting documents
# 925. Dimenhydrinate - Success getting documents
# 926. Glycopyrronium - Success getting documents
# 927. Cytarabine - Success getting documents
# 928. Dopamine - Fail
# sequence item 22: expected str instance, NoneType found
# 929. Rivastigmine - Success getting documents
# 930. Exemestane - Fail
# sequence item 18: expected str instance, NoneType found
# 931. Oxaprozin - Success getting documents
# 932. Methyl aminolevulinate - Success getting documents
# 933. Azathioprine - Success getting documents
# 934. Neomycin - Fail
# sequence item 15: expected str instance, NoneType found
# 935. Auranofin - Success getting documents
# 936. Gabapentin - Success getting documents
# 937. Doxorubicin - Fail
# sequence item 31: expected str instance, NoneType found
# 938. Frovatriptan - Success getting documents
# 939. Hydrochlorothiazide - Success getting documents
# 940. Cyclacillin - Success getting documents
# 941. Salbutamol - Fail
# sequence item 99: expected str instance, NoneType found
# 942. Levobupivacaine - Success getting documents
# 943. Cromoglicic acid - Success getting documents
# ...
# 1189. Decitabine - Success getting documents
# 1190. Posaconazole - Success getting documents
# 1191. Darunavir - Fail
# sequence item 55: expected str instance, NoneType found
# 1192. Telbivudine - Success getting documents
# 1193. Sinecatechins - Success getting documents
# 1194. Paliperidone - Success getting documents
# 1195. Sunitinib - Success getting documents
# 1196. Panitumumab - Fail
# sequence item 46: expected str instance, NoneType found
# 1197. Ranibizumab - Success getting documents
# 1198. Idursulfase - Success getting documents
# 1199. Alglucosidase alfa - Success getting documents
# 1200. Varenicline - Success getting documents
# 1201. Arformoterol - Success getting documents
# 1202. Hydralazine - Fail
# sequence item 77: expected str instance, NoneType found
# 1203. Exenatide - Success getting documents
# 1204. Mecasermin - Success getting documents
# 1205. Pramlintide - Success getting documents
# 1206. Galsulfase - Success getting documents
# 1207. Nelarabine - Success getting documents
# 1208. Abatacept - Success getting documents
# 1209. Carbetocin - Success getting documents
# 1210. Lumiracoxib - Success getting documents
# 1211. Tetracosactide - Success getting documents
# 1212. Corticotropin - Success getting documents
# 1213. Fenoterol - Success getting documents
# 1214. Pirbuterol - Success getting documents
# 1215. Bismuth subsalicylate - Success getting documents
# 1216. Glucosamine - Fail
# sequence item 1: expected str instance, NoneType found
# 1217. Practolol - Success getting documents
# 1218. Sulfacytine - Success getting documents
# 1219. Sulfadoxine - Fail
# sequence item 9: expected str instance, NoneType found
# 1220. Rolitetracycline - Success getting documents
# 1221. Oxtriphylline - Success getting documents
# 1222. Insulin aspart - Success getting documents
# 1223. Insulin detemir - Success getting documents
# 1224. Insulin glulisine - Success getting documents
# 1225. Fosamprenavir - Success getting documents
# 1226. Fosphenytoin - Success getting documents
# 1227. Kava - Fail
# sequence item 32: expected str instance, NoneType found
# 1228. St. John's Wort - Fail
# sequence item 0: expected str instance, NoneType found
# 1229. Polythiazide - Success getting documents
# 1230. Quinethazone - Success getting documents
# 1231. Cefamandole - Success getting documents
# 1232. Cefazolin - Success getting documents
# 1233. Cefonicid - Success getting documents
# 1234. Cefoperazone - Fail
# sequence item 19: expected str instance, NoneType found
# 1235. Cefotetan - Success getting documents
# 1236. Cefoxitin - Success getting documents
# 1237. Ceftizoxime - Fail
# sequence item 3: expected str instance, NoneType found
# 1238. Cefradine - Success getting documents
# 1239. Metocurine - Success getting documents
# 1240. Pancuronium - Success getting documents
# 1241. Pipecuronium - Success getting documents
# 1242. Vecuronium - Success getting documents
# 1243. Cilazapril - Success getting documents
# 1244. Tolevamer - Success getting documents
# 1245. Potassium cation - Success getting documents
# 1246. Quinidine barbiturate - Success getting documents
# 1247. Spirapril - Success getting documents
# 1248. Amobarbital - Success getting documents
# 1249. Butobarbital - Success getting documents
# 1250. Mestranol - Success getting documents
# 1251. Penbutolol - Success getting documents
# 1252. Iohexol - Success getting documents
# 1253. Ephedrine - Fail
# sequence item 38: expected str instance, NoneType found
# 1254. Mephentermine - Success getting documents
# 1255. Procaterol - Success getting documents
# 1256. Rasagiline - Success getting documents
# 1257. Quinupristin - Success getting documents
# 1258. Aluminium - Success getting documents
# 1259. Magnesium oxide - Fail
# sequence item 69: expected str instance, NoneType found
# 1260. Magnesium cation - Success getting documents
# 1261. Cortisone acetate - Success getting documents
# 1262. Ginkgo biloba - Fail
# sequence item 32: expected str instance, NoneType found
# 1263. Glymidine - Success getting documents
# 1264. Sodium bicarbonate - Success getting documents
# 1265. Yohimbine - Success getting documents
# 1266. Bezafibrate - Success getting documents
# 1267. Colchicine - Success getting documents
# 1268. Drospirenone - Success getting documents
# 1269. Digitoxin - Success getting documents
# 1270. Salsalate - Success getting documents
# 1271. Neostigmine - Success getting documents
# 1272. Choline magnesium trisalicylate - Success getting documents
# 1273. Methotrimeprazine - Success getting documents
# 1274. Ginseng - Fail
# sequence item 5: expected str instance, NoneType found
# 1275. Danazol - Success getting documents
# 1276. Clenbuterol - Success getting documents
# 1277. Tiotropium - Success getting documents
# 1278. Ciclesonide - Success getting documents
# 1279. Cefepime - Fail
# sequence item 6: expected str instance, NoneType found
# 1280. Cefacetrile - Success getting documents
# 1281. Ceftibuten - Fail
# sequence item 2: expected str instance, NoneType found
# 1282. Cefpodoxime - Success getting documents
# 1283. Acenocoumarol - Success getting documents
# 1284. Antrafenine - Success getting documents
# 1285. Testosterone propionate - Fail
# sequence item 0: expected str instance, NoneType found
# 1286. Paromomycin - Fail
# sequence item 13: expected str instance, NoneType found
# 1287. Aminophenazone - Success getting documents
# 1288. Ajmaline - Success getting documents
# 1289. Amrinone - Success getting documents
# 1290. Oxybenzone - Fail
# sequence item 13: expected str instance, NoneType found
# 1291. Almitrine - Success getting documents
# 1292. Cholestyramine - Success getting documents
# 1293. Antipyrine - Success getting documents
# 1294. Alfacalcidol - Success getting documents
# 1295. Glutethimide - Success getting documents
# 1296. Phenazopyridine - Success getting documents
# 1297. gamma-Hydroxybutyric acid - Success getting documents
# 1298. Diamorphine - Success getting documents
# 1299. Dichloralphenazone - Success getting documents
# 1300. Etorphine - Success getting documents
# 1301. Difenoxin - Success getting documents
# 1302. Carfentanil - Success getting documents
# 1303. Boldenone - Success getting documents
# 1304. Flunitrazepam - Success getting documents
# 1305. Diprenorphine - Success getting documents
# 1306. Dihydrocodeine - Success getting documents
# 1307. Bromazepam - Success getting documents
# 1308. Clotiazepam - Success getting documents
# 1309. Chloral hydrate - Success getting documents
# 1310. Attapulgite - Success getting documents
# 1311. Kaolin - Fail
# sequence item 0: expected str instance, NoneType found
# 1312. Dextroamphetamine - Success getting documents
# 1313. Metamfetamine - Success getting documents
# 1314. Phendimetrazine - Success getting documents
# 1315. Oxprenolol - Success getting documents
# 1316. Sulfamerazine - Success getting documents
# 1317. Sulfamethazine - Success getting documents
# 1318. Liotrix - Success getting documents
# 1319. Thyroglobulin - Fail
# sequence item 37: expected str instance, NoneType found
# 1320. Ursodeoxycholic acid - Success getting documents
# 1321. Ketazolam - Success getting documents
# 1322. Prazepam - Success getting documents
# 1323. Quazepam - Success getting documents
# 1324. Everolimus - Success getting documents
# 1325. Solifenacin - Success getting documents
# 1326. Iron - Fail
# sequence item 11: expected str instance, NoneType found
# 1327. Zinc - Success getting documents
# 1328. Nitrazepam - Success getting documents
# 1329. Cilastatin - Fail
# sequence item 44: expected str instance, NoneType found
# 1330. Imipenem - Fail
# sequence item 67: expected str instance, NoneType found
# 1331. Probucol - Success getting documents
# 1332. Tiaprofenic acid - Success getting documents
# 1333. Lopinavir - Success getting documents
# 1334. Bacampicillin - Success getting documents
# 1335. Meticillin - Success getting documents
# 1336. Pivampicillin - Success getting documents
# 1337. Pivmecillinam - Success getting documents
# 1338. Tazobactam - Fail
# sequence item 26: expected str instance, NoneType found
# 1339. Ticarcillin - Success getting documents
# 1340. Periciazine - Success getting documents
# 1341. Deferasirox - Success getting documents
# 1342. Valganciclovir - Success getting documents
# 1343. Hydroxychloroquine - Fail
# sequence item 77: expected str instance, NoneType found
# 1344. Amyl Nitrite - Success getting documents
# 1345. Erythrityl tetranitrate - Success getting documents
# 1346. Acepromazine - Success getting documents
# 1347. Alverine - Success getting documents
# 1348. Molindone - Success getting documents
# 1349. Phenindamine - Success getting documents
# 1350. Pheniramine - Success getting documents
# 1351. Pipotiazine - Success getting documents
# 1352. Thiothixene - Success getting documents
# 1353. Zuclopenthixol - Success getting documents
# 1354. Isopropamide - Success getting documents
# 1355. Pargyline - Success getting documents
# 1356. Lincomycin - Fail
# sequence item 45: expected str instance, NoneType found
# 1357. Etoricoxib - Success getting documents
# 1358. 5-O-phosphono-alpha-D-ribofuranosyl diphosphate - Success getting documents
# 1359. Sorbitol - Success getting documents
# 1360. Roflumilast - Success getting documents
# 1361. Rutin - Fail
# sequence item 99: expected str instance, NoneType found
# 1362. Prasterone - Success getting documents
# 1363. Cetrimonium - Success getting documents
# 1364. Camphor - Success getting documents
# 1365. Dalfopristin - Success getting documents
# 1366. Pantothenic acid - Success getting documents
# 1367. Propylene glycol - Success getting documents
# 1368. D-glucose - Fail
# sequence item 10: expected str instance, NoneType found
# 1369. Taurine - Success getting documents
# 1370. Cocarboxylase - Success getting documents
# 1371. Flufenamic acid - Success getting documents
# 1372. Calcipotriol - Success getting documents
# 1373. Isopropyl alcohol - Success getting documents
# 1374. Aminobenzoic acid - Success getting documents
# 1375. Thymol - Fail
# sequence item 42: expected str instance, NoneType found
# 1376. gamma-Aminobutyric acid - Success getting documents
# 1377. Vorinostat - Fail
# sequence item 26: expected str instance, NoneType found
# 1378. Terlipressin - Fail
# sequence item 92: expected str instance, NoneType found
# 1379. Cholic Acid - Success getting documents
# 1380. Nicotinamide - Success getting documents
# 1381. Fusidic acid - Fail
# sequence item 56: expected str instance, NoneType found
# 1382. Sucrose - Success getting documents
# 1383. Pregnenolone - Success getting documents
# 1384. D-Methionine - Success getting documents
# 1385. Piretanide - Success getting documents
# 1386. Oxitriptan - Success getting documents
# 1387. Arsanilic acid - Success getting documents
# 1388. Lauric acid - Fail
# sequence item 12: expected str instance, NoneType found
# 1389. Glycolic acid - Fail
# sequence item 44: expected str instance, NoneType found
# 1390. Pidolic acid - Success getting documents
# 1391. Acetylcholine - Fail
# sequence item 87: expected str instance, NoneType found
# 1392. Flavin adenine dinucleotide - Success getting documents
# 1393. Acetic acid - Success getting documents
# 1394. Propyl alcohol - Success getting documents
# 1395. Stearic acid - Success getting documents
# 1396. Oteracil - Success getting documents
# 1397. Flavin mononucleotide - Success getting documents
# 1398. Phenol - Success getting documents
# 1399. Glutathione disulfide - Success getting documents
# 1400. Brivudine - Success getting documents
# 1401. Hemin - Success getting documents
# 1402. Oxyphenbutazone - Success getting documents
# 1403. Mecobalamin - Success getting documents
# 1404. Ribostamycin - Success getting documents
# 1405. Deoxycholic acid - Success getting documents
# 1406. Tromethamine - Fail
# sequence item 9: expected str instance, NoneType found
# 1407. Doconexent - Success getting documents
# 1408. Propanoic acid - Success getting documents
# 1409. Benzoic acid - Success getting documents
# 1410. Palmitic Acid - Success getting documents
# 1411. Hexamidine - Success getting documents
# 1412. Formaldehyde - Success getting documents
# 1413. Urea - Success getting documents
# 1414. D-Serine - Fail
# sequence item 39: expected str instance, NoneType found
# 1415. Ergosterol - Fail
# sequence item 16: expected str instance, NoneType found
# 1416. Berberine - Success getting documents
# 1417. Pyrophosphoric acid - Success getting documents
# 1418. Fructose - Fail
# sequence item 82: expected str instance, NoneType found
# 1419. Dequalinium - Success getting documents
# 1420. Didecyldimethylammonium - Success getting documents
# 1421. Oleic Acid - Success getting documents
# 1422. Citric acid - Success getting documents
# 1423. Carbocisteine - Success getting documents
# 1424. Taurocholic acid - Success getting documents
# 1425. Lactic acid - Fail
# sequence item 62: expected str instance, NoneType found
# 1426. Lactose - Fail
# sequence item 31: expected str instance, NoneType found
# 1427. Cholesterol - Fail
# sequence item 4: expected str instance, NoneType found
# 1428. Gluconolactone - Success getting documents
# 1429. Latamoxef - Success getting documents
# 1430. Trioxsalen - Success getting documents
# 1431. Thiotepa - Success getting documents
# 1432. Estriol - Success getting documents
# 1433. Estrone sulfate - Success getting documents
# 1434. Quinestrol - Success getting documents
# 1435. Apramycin - Fail
# sequence item 6: expected str instance, NoneType found
# 1436. Carboxin - Success getting documents
# 1437. Hesperidin - Fail
# sequence item 36: expected str instance, NoneType found
# 1438. Iodipamide - Success getting documents
# 1439. Nimesulide - Success getting documents
# 1440. Bifonazole - Success getting documents
# 1441. Benoxaprofen - Success getting documents
# 1442. Bithionol - Success getting documents
# 1443. Clioquinol - Fail
# sequence item 3: expected str instance, NoneType found
# 1444. Dantron - Success getting documents
# 1445. Metamizole - Success getting documents
# 1446. Nialamide - Success getting documents
# 1447. Nomifensine - Success getting documents
# 1448. Oxeladin - Success getting documents
# 1449. Phenolphthalein - Success getting documents
# 1450. Prenylamine - Success getting documents
# 1451. Thenalidine - Success getting documents
# 1452. Urethane - Fail
# sequence item 72: expected str instance, NoneType found
# 1453. Zimelidine - Success getting documents
# 1454. Rapacuronium - Success getting documents
# 1455. Maraviroc - Success getting documents
# 1456. Clofedanol - Success getting documents
# 1457. Cyclandelate - Success getting documents
# 1458. Cyproterone acetate - Success getting documents
# 1459. Debrisoquine - Success getting documents
# 1460. Flunarizine - Success getting documents
# 1461. Fluspirilene - Success getting documents
# 1462. Mepenzolate - Success getting documents
# 1463. Tetrabenazine - Success getting documents
# 1464. Ixabepilone - Success getting documents
# 1465. Celiprolol - Success getting documents
# 1466. Febuxostat - Success getting documents
# 1467. Dronedarone - Success getting documents
# 1468. Nebivolol - Success getting documents
# 1469. Huperzine A - Success getting documents
# 1470. Omacetaxine mepesuccinate - Success getting documents
# 1471. Halofuginone - Success getting documents
# 1472. Nilotinib - Success getting documents
# 1473. Lorcaserin - Success getting documents
# 1474. Vildagliptin - Success getting documents
# 1475. Enoximone - Success getting documents
# 1476. Bepotastine - Success getting documents
# 1477. Pegaptanib - Success getting documents
# 1478. Milnacipran - Success getting documents
# 1479. Lucinactant - Success getting documents
# 1480. Ximelagatran - Success getting documents
# 1481. Nesiritide - Success getting documents
# 1482. Flibanserin - Success getting documents
# 1483. Oxibendazole - Success getting documents
# 1484. Oritavancin - Success getting documents
# 1485. Ceftobiprole - Fail
# sequence item 40: expected str instance, NoneType found
# 1486. Clevidipine - Success getting documents
# 1487. rhThrombin - Success getting documents
# 1488. Permethrin - Success getting documents
# 1489. Afamelanotide - Success getting documents
# 1490. Defibrotide - Success getting documents
# 1491. Ospemifene - Success getting documents
# 1492. Crofelemer - Success getting documents
# 1493. Hemoglobin - Success getting documents
# 1494. Iloperidone - Success getting documents
# 1495. Lofexidine - Success getting documents

# %%
with open("D:/WorkSpace/master_thesis/data_pubmed/documents/approved_documents.pkl", "wb") as fw:
    pickle.dump(documents_100, fw)
