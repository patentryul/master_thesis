# %%
# import
from xml.etree import ElementTree as ET
from xml.etree.ElementTree import Element, dump, ElementTree
import numpy as np

# Use Open source 'pubmed_parser'
import pubmed_parser as pp

# %%
# import glob

# targetPattern = r"pmid/*.txt"
# pmidFile = glob.glob(targetPattern)

# # convert python style path
# for i in range(len(pmidFile)):
#     pmidFile[i] = pmidFile[i].replace('\\', '/')
#     print(pmidFile[i])
# Out:
# pmid/pmid-Dornasealf-set.txt
# pmid/pmid-Lepirudin-set.txt
# pmid/pmid-Ximelagatr-set.txt

# %%
import pickle

with open("D:/WorkSpace/master_thesis/Drug_Bank/result/approved_pmid.pkl", "rb") as fr:
    approved_pmid = pickle.load(fr)

# %%
# Drug bank common name list
import pandas as pd

df = pd.read_csv('D:/WorkSpace/master_thesis/Drug_Bank/drugbank_vocabulary.csv')
drugName = df['Common name']

# %%
import requests
from lxml import etree
from lxml import html

# esearch ================================================================
# # Hyper parameter
# reldate = '3650' # 10 years
# retmax = '20'
# i = 0 # for test

# search_base = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term='
# search_url = search_base + drugName[i] + '[title]&reldate=' + reldate + '&datetype=pdat&retmax=' + retmax +'&usehistory=y'

# # get pmid xml data
# page = requests.get(search_url)
# tree = html.fromstring(page.content)

# # get pmid by drug name
# pmid_list = ''
# for pmid in tree.xpath("//idlist/id"):
#     pmid_list = ",".join(pmid_list)
# esearch ================================================================


# fetch_base = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=' 
# retmode = '&retmode=xml'

documents = dict()
for i in range(len(drugName)):
# for i in range(2):    
    # fetch by pmid
    pmid_list = ",".join(pmid_by_drug[drugName[i]])
#     efetch_url = fetch_base + pmid_list + retmode
    try:
        data = pp.parse_xml_web(pmid_list, sleep=1, save_xml=False)
        title = data['title']
        abstract = data['abstract']
        if title is not None:
#             contents.append((title + ' ' + abstract + ' '))
            documents[drugName[i]] = (title + ' ' + abstract + ' ')
            print(str(i) + '. '  + drugName[i] + ' - Success getting documents'  )
        else:
            print(str(i) + '. - No result')
            
    except Exception as e:
        print(str(i) + '. ' + drugName[i] +' - Fail')
        print(e)
# Out:
# 0. Lepirudin - Success getting documents
# 1. Cetuximab - Success getting documents
# 2. Dornase alfa - Success getting documents
# 3. Denileukin diftitox - Success getting documents
# 4. Etanercept - Success getting documents
# 5. Bivalirudin - Success getting documents
# 6. Leuprolide - Success getting documents
# 7. Peginterferon alfa-2a - Success getting documents
# 8. Alteplase - Success getting documents
# 9. Sermorelin - Success getting documents
# 10. Interferon alfa-n1 - Success getting documents
# 11. Darbepoetin alfa - Success getting documents
# 12. Urokinase - Success getting documents
# 13. Goserelin - Success getting documents
# 14. Reteplase - Success getting documents
# 15. Erythropoietin - Success getting documents
# 16. Salmon calcitonin - Success getting documents
# 17. Interferon alfa-n3 - Success getting documents
# 18. Pegfilgrastim - Success getting documents
# 19. Sargramostim - Success getting documents
# 20. Peginterferon alfa-2b - Success getting documents
# 21. Asparaginase Escherichia coli - Success getting documents
# 22. Thyrotropin alfa - Success getting documents
# 23. Antihemophilic factor, human recombinant - Success getting documents
# 24. Anakinra - Success getting documents
# 25. Gramicidin D - Success getting documents
# 26. Human immunoglobulin G - Success getting documents
# 27. Anistreplase - Success getting documents
# 28. Insulin human - Success getting documents
# 29. Tenecteplase - Success getting documents
# 30. Menotropins - Success getting documents
# 31. Interferon gamma-1b - Success getting documents
# 32. Interferon alfa-2a, Recombinant - Success getting documents
# 33. Desmopressin - Success getting documents
# 34. Coagulation factor VIIa Recombinant Human - Success getting documents
# 35. Oprelvekin - Success getting documents
# 36. Palifermin - Success getting documents
# 37. Glucagon - Success getting documents
# 38. Aldesleukin - Success getting documents
# 39. Botulinum Toxin Type B - Success getting documents
# 40. Omalizumab - Success getting documents
# 41. Lutropin alfa - Success getting documents
# 42. Lyme disease vaccine (recombinant OspA) - Success getting documents
# 43. Insulin lispro - Success getting documents
# 44. Insulin glargine - Success getting documents
# 45. Collagenase clostridium histolyticum - Success getting documents
# 46. Rasburicase - Success getting documents
# 47. Cetrorelix - Success getting documents
# 48. Adalimumab - Success getting documents
# 49. Somatotropin - Success getting documents
# 50. Imiglucerase - Success getting documents
# 51. Abciximab - Success getting documents
# 52. Drotrecogin alfa - Success getting documents
# 53. Gemtuzumab ozogamicin - Success getting documents
# 54. Indium In-111 satumomab pendetide - Success getting documents
# 55. Alpha-1-proteinase inhibitor - Success getting documents
# 56. Pegaspargase - Success getting documents
# 57. Interferon beta-1a - Success getting documents
# 58. Pegademase - Success getting documents
# 59. Albumin human - Success getting documents
# 60. Eptifibatide - Success getting documents
# 61. Infliximab - Success getting documents
# 62. Follitropin - Success getting documents
# 63. Vasopressin - Success getting documents
# 64. Interferon beta-1b - Success getting documents
# 65. Interferon alfacon-1 - Success getting documents
# 66. Hyaluronidase (ovine) - Success getting documents
# 67. Insulin pork - Success getting documents
# 68. Trastuzumab - Success getting documents
# 69. Rituximab - Success getting documents
# 70. Basiliximab - Success getting documents
# 71. Muromonab - Success getting documents
# 72. Digoxin Immune Fab (Ovine) - Success getting documents
# 73. Ibritumomab tiuxetan - Fail
# sequence item 5: expected str instance, NoneType found
# 74. Daptomycin - Success getting documents
# 75. Tositumomab - Success getting documents
# 76. Pegvisomant - Success getting documents
# 77. Botulinum toxin type A - Success getting documents
# 78. Pancrelipase - Success getting documents
# 79. Streptokinase - Success getting documents
# 80. Alemtuzumab - Success getting documents
# 81. Alglucerase - Success getting documents
# 82. Capromab pendetide - Success getting documents
# 83. Laronidase - Success getting documents
# 84. Cyclosporine - Success getting documents
# 85. Alefacept - Fail
# sequence item 2: expected str instance, NoneType found
# 86. Felypressin - Success getting documents
# 87. Urofollitropin - Success getting documents
# 88. Efalizumab - Success getting documents
# 89. Choriogonadotropin alfa - Success getting documents
# 90. Antithymocyte immunoglobulin (rabbit) - Success getting documents
# 91. Filgrastim - Success getting documents
# 92. Coagulation Factor IX (Recombinant) - Success getting documents
# 93. Becaplermin - Success getting documents
# 94. Agalsidase beta - Success getting documents
# 95. Octreotide - Success getting documents
# 96. Interferon alfa-2b - Success getting documents
# 97. Abarelix - Success getting documents
# 98. Oxytocin - Success getting documents
# 99. Natalizumab - Success getting documents
# 100. Enfuvirtide - Success getting documents
# 101. Palivizumab - Success getting documents
# 102. Daclizumab - Fail
# sequence item 4: expected str instance, NoneType found
# 103. Bevacizumab - Success getting documents
# 104. Technetium Tc-99m arcitumomab - Success getting documents
# 105. Pyridoxal phosphate - Fail
# sequence item 9: expected str instance, NoneType found
# 106. Cyanocobalamin - Success getting documents
# 107. Tetrahydrofolic acid - Success getting documents
# 108. Histidine - Success getting documents
# 109. Ademetionine - Success getting documents
# 110. Pyruvic acid - Success getting documents
# 111. Phenylalanine - Fail
# sequence item 2: expected str instance, NoneType found
# 112. Biotin - Success getting documents
# 113. Choline - Fail
# sequence item 3: expected str instance, NoneType found
# 114. L-Lysine - Success getting documents
# 115. Arginine - Success getting documents
# 116. Ascorbic acid - Success getting documents
# 117. Spermine - Success getting documents
# 118. Aspartic acid - Success getting documents
# 119. Ornithine - Success getting documents
# 120. L-Glutamine - Success getting documents
# 121. Adenosine phosphate - Success getting documents
# 122. alpha-Linolenic acid - Success getting documents
# 123. Serine - Success getting documents
# 124. Methionine - Success getting documents
# 125. Tyrosine - Success getting documents
# 126. Calcitriol - Success getting documents
# 127. Lutein - Success getting documents
# 128. Cystine - Success getting documents
# 129. Succinic acid - Fail
# sequence item 19: expected str instance, NoneType found
# 130. Riboflavin - Success getting documents
# 131. N-Acetylglucosamine - Fail
# sequence item 0: expected str instance, NoneType found
# 132. Glutamic acid - Success getting documents
# 133. Glutathione - Fail
# sequence item 6: expected str instance, NoneType found
# 134. Phosphatidyl serine - Success getting documents
# 135. Glycine - Success getting documents
# 136. Calcifediol - Success getting documents
# 137. Pyridoxal - Success getting documents
# 138. Creatine - Success getting documents
# 139. Leucine - Fail
# sequence item 11: expected str instance, NoneType found
# 140. Tryptophan - Success getting documents
# 141. Cysteine - Success getting documents
# 142. Thiamine - Success getting documents
# 143. Ergocalciferol - Success getting documents
# 144. Dihomo-gamma-linolenic acid - Success getting documents
# 145. Citrulline - Success getting documents
# 146. Threonine - Success getting documents
# 147. NADH - Success getting documents
# 148. Folic acid - Success getting documents
# 149. Icosapent - Success getting documents
# 150. Alanine - Success getting documents
# 151. Valine - Success getting documents
# 152. Vitamin A - Success getting documents
# 153. Vitamin E - Success getting documents
# 154. Pyridoxine - Success getting documents
# 155. Lipoic acid - Success getting documents
# 156. Isoleucine - Success getting documents
# 157. Aspartame - Success getting documents
# 158. Cholecalciferol - Success getting documents
# 159. Menadione - Success getting documents
# 160. ATP - Success getting documents
# 161. Proline - Success getting documents
# 162. Adenine - Success getting documents
# 163. Asparagine - Success getting documents
# 164. Pravastatin - Success getting documents
# 165. Fluvoxamine - Success getting documents
# 166. Valsartan - Success getting documents
# 167. Ramipril - Success getting documents
# 168. Masoprocol - Success getting documents
# 169. Flunisolide - Success getting documents
# 170. Baclofen - Success getting documents
# 171. Amphetamine - Success getting documents
# 172. Pentagastrin - Success getting documents
# 173. Nicotine - Success getting documents
# 174. Cevimeline - Success getting documents
# 175. Lorazepam - Success getting documents
# 176. Esmolol - Success getting documents
# 177. Bortezomib - Success getting documents
# 178. Ethchlorvynol - Success getting documents
# 179. Carbidopa - Success getting documents
# 180. Phentermine - Success getting documents
# 181. Indecainide - Success getting documents
# 182. Tramadol - Success getting documents
# 183. Vidarabine - Success getting documents
# 184. Betaxolol - Success getting documents
# 185. Fluconazole - Fail
# sequence item 9: expected str instance, NoneType found
# 186. Troglitazone - Success getting documents
# 187. Oseltamivir - Success getting documents
# 188. Erythromycin - Success getting documents
# 189. Hydroxocobalamin - Success getting documents
# 190. Caffeine - Success getting documents
# 191. Succinylcholine - Success getting documents
# 192. Sildenafil - Success getting documents
# 193. Dofetilide - Success getting documents
# 194. Pyrimethamine - Fail
# sequence item 14: expected str instance, NoneType found
# 195. Reserpine - Fail
# sequence item 4: expected str instance, NoneType found
# 196. Azithromycin - Success getting documents
# 197. Ticlopidine - Success getting documents
# 198. Trospium - Success getting documents
# 199. Adapalene - Success getting documents
# 200. Midodrine - Success getting documents
# 201. Remikiren - Success getting documents
# 202. Pantoprazole - Success getting documents
# 203. Torasemide - Success getting documents
# 204. Citalopram - Success getting documents
# 205. Eletriptan - Success getting documents
# 206. Bethanidine - Success getting documents
# 207. Moxifloxacin - Success getting documents
# 208. Oxyphenonium - Success getting documents
# 209. Nelfinavir - Success getting documents
# 210. Isoetharine - Success getting documents
# 211. Glimepiride - Success getting documents
# 212. Diflorasone - Success getting documents
# 213. Indinavir - Success getting documents
# 214. Gadodiamide - Success getting documents
# 215. Guanadrel - Success getting documents
# 216. Lovastatin - Success getting documents
# 217. Enflurane - Success getting documents
# 218. Cefotiam - Success getting documents
# 219. Pregabalin - Success getting documents
# 220. Temazepam - Success getting documents
# 221. Methyclothiazide - Success getting documents
# 222. Aminosalicylic acid - Success getting documents
# 223. Reboxetine - Success getting documents
# 224. Milrinone - Success getting documents
# 225. Pipobroman - Success getting documents
# 226. Butabarbital - Success getting documents
# 227. Nevirapine - Success getting documents
# 228. Oxiconazole - Success getting documents
# 229. Alclometasone - Success getting documents
# 230. Butalbital - Success getting documents
# 231. Cladribine - Success getting documents
# 232. Ranolazine - Success getting documents
# 233. Mesalazine - Success getting documents
# 234. Benzatropine - Success getting documents
# 235. Ziprasidone - Success getting documents
# 236. Methysergide - Success getting documents
# 237. Cabergoline - Success getting documents
# 238. Idoxuridine - Success getting documents
# 239. Dapsone - Success getting documents
# 240. Terconazole - Success getting documents
# 241. Phenytoin - Success getting documents
# 242. Medrysone - Success getting documents
# 243. Doxycycline - Success getting documents
# 244. Diethylstilbestrol - Success getting documents
# 245. Lymecycline - Success getting documents
# 246. Clotrimazole - Success getting documents
# 247. Calcium acetate - Success getting documents
# 248. Sulfanilamide - Success getting documents
# 249. Cycloserine - Success getting documents
# 250. Anagrelide - Success getting documents
# 251. Carmustine - Fail
# sequence item 9: expected str instance, NoneType found
# 252. Sulfisoxazole - Success getting documents
# 253. Metoprolol - Success getting documents
# 254. Crotamiton - Success getting documents
# 255. Dicoumarol - Success getting documents
# 256. Cefmenoxime - Success getting documents
# 257. Ropinirole - Success getting documents
# 258. Chlorotrianisene - Success getting documents
# 259. Isradipine - Success getting documents
# 260. Diatrizoate - Success getting documents
# 261. Betazole - Success getting documents
# 262. Topiramate - Success getting documents
# 263. Cefmetazole - Fail
# sequence item 5: expected str instance, NoneType found
# 264. Olmesartan - Success getting documents
# 265. Amsacrine - Success getting documents
# 266. Theophylline - Success getting documents
# 267. Argatroban - Success getting documents
# 268. Liothyronine - Success getting documents
# 269. Disopyramide - Success getting documents
# 270. Lidocaine - Success getting documents
# 271. Pamidronic acid - Success getting documents
# 272. Clemastine - Fail
# sequence item 4: expected str instance, NoneType found
# 273. Acarbose - Success getting documents
# 274. Venlafaxine - Success getting documents
# 275. Conjugated estrogens - Success getting documents
# 276. Travoprost - Success getting documents
# 277. Amcinonide - Success getting documents
# 278. Atomoxetine - Success getting documents
# 279. Bleomycin - Success getting documents
# 280. Chlorambucil - Success getting documents
# 281. Etomidate - Success getting documents
# 282. Raltitrexed - Success getting documents
# 283. Etonogestrel - Success getting documents
# 284. Morphine - Success getting documents
# 285. Ropivacaine - Success getting documents
# 286. Bupivacaine - Success getting documents
# 287. Dapiprazole - Success getting documents
# 288. Penciclovir - Fail
# sequence item 8: expected str instance, NoneType found
# 289. Tenofovir disoproxil - Success getting documents
# 290. Flucloxacillin - Success getting documents
# 291. Tranexamic acid - Success getting documents
# 292. Ertapenem - Success getting documents
# 293. Desogestrel - Success getting documents
# 294. Mitomycin - Success getting documents
# 295. Talbutal - Success getting documents
# 296. Bexarotene - Success getting documents
# 297. Ibutilide - Success getting documents
# 298. Vindesine - Success getting documents
# 299. Chlorthalidone - Success getting documents
# 300. Ethoxzolamide - Success getting documents
# 301. Pentobarbital - Fail
# sequence item 13: expected str instance, NoneType found
# 302. Valproic acid - Success getting documents
# 303. Capreomycin - Fail
# sequence item 17: expected str instance, NoneType found
# 304. Zolmitriptan - Success getting documents
# 305. Acetaminophen - Success getting documents
# 306. Gefitinib - Success getting documents
# 307. Codeine - Success getting documents
# 308. Piperacillin - Success getting documents
# 309. Dihydroergotamine - Fail
# sequence item 1: expected str instance, NoneType found
# 310. Amitriptyline - Success getting documents
# 311. Floxuridine - Success getting documents
# 312. Tolcapone - Success getting documents
# 313. Fluorometholone - Success getting documents
# 314. Nitroprusside - Success getting documents
# 315. Calcium glucoheptonate - Success getting documents
# 316. Hydromorphone - Success getting documents
# 317. Indomethacin - Success getting documents
# 318. Ethambutol - Success getting documents
# 319. Metformin - Success getting documents
# 320. Ipratropium - Success getting documents
# 321. Methadone - Fail
# sequence item 10: expected str instance, NoneType found
# 322. Olanzapine - Success getting documents
# 323. Atenolol - Success getting documents
# 324. Nitrofural - Success getting documents
# 325. Pimecrolimus - Success getting documents
# 326. Omeprazole - Success getting documents
# 327. Pyrazinamide - Success getting documents
# 328. Metixene - Success getting documents
# 329. Cetirizine - Success getting documents
# 330. Terfenadine - Success getting documents
# 331. Diltiazem - Success getting documents
# 332. Protriptyline - Success getting documents
# 333. Aminohippuric acid - Success getting documents
# 334. Alfuzosin - Success getting documents
# 335. Trimethadione - Success getting documents
# 336. Nitisinone - Success getting documents
# 337. Clobazam - Success getting documents
# 338. Minoxidil - Success getting documents
# 339. Megestrol acetate - Success getting documents
# 340. Tioguanine - Success getting documents
# 341. Methylergometrine - Success getting documents
# 342. Buclizine - Success getting documents
# 343. Aztreonam - Fail
# sequence item 9: expected str instance, NoneType found
# 344. Chlorzoxazone - Success getting documents
# 345. Aminoglutethimide - Success getting documents
# 346. Mefloquine - Success getting documents
# 347. Sulfadiazine - Success getting documents
# 348. Sapropterin - Success getting documents
# 349. Vinorelbine - Success getting documents
# 350. Anidulafungin - Success getting documents
# 351. Clozapine - Success getting documents
# 352. Sucralfate - Success getting documents
# 353. Grepafloxacin - Success getting documents
# 354. Doxylamine - Success getting documents
# 355. Levonorgestrel - Success getting documents
# 356. Norepinephrine - Success getting documents
# 357. Cidofovir - Success getting documents
# 358. Mirtazapine - Success getting documents
# 359. Meprobamate - Success getting documents
# 360. Thiethylperazine - Success getting documents
# 361. Timolol - Success getting documents
# 362. Treprostinil - Success getting documents
# 363. Colestipol - Success getting documents
# 364. Trihexyphenidyl - Success getting documents
# 365. Palonosetron - Success getting documents
# 366. Dydrogesterone - Success getting documents
# 367. Mexiletine - Success getting documents
# 368. Dexrazoxane - Success getting documents
# 369. Amlodipine - Success getting documents
# 370. Tacrine - Success getting documents
# 371. Oxyphencyclimine - Success getting documents
# 372. Triamterene - Success getting documents
# 373. Valrubicin - Success getting documents
# 374. Procyclidine - Success getting documents
# 375. Phenylephrine - Success getting documents
# 376. Carbimazole - Success getting documents
# 377. Digoxin - Success getting documents
# 378. Sulpiride - Success getting documents
# 379. Profenamine - Success getting documents
# 380. Nimodipine - Success getting documents
# 381. Beclomethasone dipropionate - Success getting documents
# 382. Carisoprodol - Success getting documents
# 383. Progesterone - Success getting documents
# 384. Phenylpropanolamine - Success getting documents
# 385. Sorafenib - Success getting documents
# 386. Zoledronic acid - Success getting documents
# 387. Griseofulvin - Success getting documents
# 388. Nisoldipine - Success getting documents
# 389. Eszopiclone - Success getting documents
# 390. Ceruletide - Success getting documents
# 391. Alprazolam - Success getting documents
# 392. Dexbrompheniramine - Success getting documents
# 393. Gentian violet cation - Success getting documents
# 394. Ardeparin - Success getting documents
# 395. Loxapine - Success getting documents
# 396. Remoxipride - Success getting documents
# 397. Mupirocin - Success getting documents
# 398. Carbamoylcholine - Success getting documents
# 399. Rosiglitazone - Success getting documents
# 400. Pramipexole - Success getting documents
# 401. Acetohexamide - Success getting documents
# 402. Ampicillin - Fail
# sequence item 14: expected str instance, NoneType found
# 403. Metocurine iodide - Success getting documents
# 404. Phenoxymethylpenicillin - Success getting documents
# 405. Secobarbital - Success getting documents
# 406. Miglustat - Success getting documents
# 407. Promazine - Success getting documents
# 408. Spironolactone - Success getting documents
# 409. Methylphenidate - Success getting documents
# 410. Methocarbamol - Success getting documents
# 411. Hyoscyamine - Success getting documents
# 412. Zolpidem - Success getting documents
# 413. Famciclovir - Success getting documents
# 414. Triprolidine - Success getting documents
# 415. Streptozocin - Fail
# sequence item 5: expected str instance, NoneType found
# 416. Carboprost tromethamine - Success getting documents
# 417. Cefpiramide - Success getting documents
# 418. Lindane - Success getting documents
# 419. Trifluridine - Success getting documents
# 420. Prochlorperazine - Success getting documents
# 421. Cyproheptadine - Success getting documents
# 422. Nitric Oxide - Success getting documents
# 423. Bendroflumethiazide - Success getting documents
# 424. Allopurinol - Success getting documents
# 425. Ceftazidime - Success getting documents
# 426. Cerivastatin - Success getting documents
# 427. Trimethoprim - Fail
# sequence item 6: expected str instance, NoneType found
# 428. Gemcitabine - Success getting documents
# 429. Entecavir - Success getting documents
# 430. Betamethasone - Success getting documents
# 431. Teniposide - Success getting documents
# 432. Epirubicin - Fail
# sequence item 14: expected str instance, NoneType found
# 433. Chloramphenicol - Success getting documents
# 434. Loracarbef - Success getting documents
# 435. Lansoprazole - Fail
# sequence item 15: expected str instance, NoneType found
# 436. Dipivefrin - Success getting documents
# 437. Droperidol - Success getting documents
# 438. Levothyroxine - Success getting documents
# 439. Framycetin - Success getting documents
# 440. Clomocycline - Success getting documents
# 441. Meperidine - Success getting documents
# 442. Loratadine - Success getting documents
# 443. Cefalotin - Success getting documents
# 444. Prazosin - Fail
# sequence item 14: expected str instance, NoneType found
# 445. Imipramine - Success getting documents
# 446. Acitretin - Success getting documents
# 447. Verteporfin - Success getting documents
# 448. Nabumetone - Success getting documents
# 449. Methscopolamine bromide - Success getting documents
# 450. Metharbital - Success getting documents
# 451. Sodium tetradecyl sulfate - Success getting documents
# 452. Ketorolac - Success getting documents
# 453. Picrotoxin - Success getting documents
# 454. Enoxacin - Success getting documents
# 455. Quinine - Success getting documents
# 456. Tenoxicam - Success getting documents
# 457. Dronabinol - Success getting documents
# 458. Montelukast - Success getting documents
# 459. Fluoxetine - Success getting documents
# 460. Hexylcaine - Success getting documents
# 461. Methohexital - Success getting documents
# 462. Chlordiazepoxide - Success getting documents
# 463. Duloxetine - Success getting documents
# 464. Chlorpromazine - Success getting documents
# 465. Rimantadine - Success getting documents
# 466. Amikacin - Success getting documents
# 467. Lenalidomide - Success getting documents
# 468. Raloxifene - Success getting documents
# 469. Celecoxib - Fail
# sequence item 0: expected str instance, NoneType found
# 470. Gallamine triethiodide - Success getting documents
# 471. Brimonidine - Success getting documents
# 472. Dicloxacillin - Success getting documents
# 473. Nabilone - Success getting documents
# 474. Pefloxacin - Success getting documents
# 475. Altretamine - Success getting documents
# 476. Sotalol - Success getting documents
# 477. Buspirone - Success getting documents
# 478. Miglitol - Success getting documents
# 479. Fosinopril - Success getting documents
# 480. Cefotaxime - Success getting documents
# 481. Entacapone - Success getting documents
# 482. Zidovudine - Success getting documents
# 483. Darifenacin - Success getting documents
# 484. Oxycodone - Success getting documents
# 485. Phenindione - Success getting documents
# 486. Flutamide - Success getting documents
# 487. Tolmetin - Success getting documents
# 488. Cimetidine - Fail
# sequence item 13: expected str instance, NoneType found
# 489. Haloperidol - Success getting documents
# 490. Ritonavir - Success getting documents
# 491. Levallorphan - Success getting documents
# 492. Tridihexethyl - Success getting documents
# 493. Nitazoxanide - Success getting documents
# 494. Triflupromazine - Success getting documents
# 495. Dextrothyroxine - Success getting documents
# 496. Acetyldigitoxin - Success getting documents
# 497. Vancomycin - Success getting documents
# 498. Aminocaproic acid - Success getting documents
# 499. Dextromethorphan - Fail
# sequence item 5: expected str instance, NoneType found
# 500. Cisplatin - Success getting documents
# 501. Bentoquatam - Success getting documents
# 502. Anisotropine methylbromide - Success getting documents
# 503. Albendazole - Success getting documents
# 504. Trandolapril - Success getting documents
# 505. Caspofungin - Success getting documents
# 506. Carteolol - Success getting documents
# 507. Bentiromide - Success getting documents
# 508. Alitretinoin - Success getting documents
# 509. Metolazone - Success getting documents
# 510. Tolnaftate - Success getting documents
# 511. Oxaliplatin - Success getting documents
# 512. Cinchocaine - Success getting documents
# 513. Lercanidipine - Fail
# sequence item 3: expected str instance, NoneType found
# 514. Foscarnet - Success getting documents
# 515. Erlotinib - Success getting documents
# 516. Cyclophosphamide - Success getting documents
# 517. Mephenytoin - Success getting documents
# 518. Rofecoxib - Success getting documents
# 519. Chlormerodrin - Success getting documents
# 520. Cefdinir - Success getting documents
# 521. Guanidine - Success getting documents
# 522. Ciprofloxacin - Success getting documents
# 523. Gadoversetamide - Success getting documents
# 524. Toremifene - Success getting documents
# 525. Nortriptyline - Success getting documents
# 526. Vincristine - Success getting documents
# 527. Benazepril - Success getting documents
# 528. Amoxapine - Success getting documents
# 529. Fluorouracil - Success getting documents
# 530. Pyridostigmine - Success getting documents
# 531. Adinazolam - Success getting documents
# 532. Desoximetasone - Success getting documents
# 533. Azelaic acid - Success getting documents
# 534. Zafirlukast - Success getting documents
# 535. Propylthiouracil - Success getting documents
# 536. Acetohydroxamic acid - Success getting documents
# 537. Pentostatin - Success getting documents
# 538. Methoxsalen - Success getting documents
# 539. Piroxicam - Success getting documents
# 540. Lamotrigine - Success getting documents
# 541. Perflutren - Success getting documents
# 542. Hydroxyzine - Success getting documents
# 543. Zanamivir - Success getting documents
# 544. Bosentan - Fail
# sequence item 2: expected str instance, NoneType found
# 545. Tigecycline - Fail
# sequence item 5: expected str instance, NoneType found
# 546. Doxapram - Success getting documents
# 547. Benzthiazide - Success getting documents
# 548. Methotrexate - Success getting documents
# 549. Carbamazepine - Success getting documents
# 550. Cisatracurium - Success getting documents
# 551. Succimer - Success getting documents
# 552. Cephalexin - Success getting documents
# 553. Cinnarizine - Success getting documents
# 554. Fondaparinux - Success getting documents
# 555. Vinblastine - Success getting documents
# 556. Propranolol - Success getting documents
# 557. Atropine - Success getting documents
# 558. Fenoprofen - Success getting documents
# 559. Fenfluramine - Success getting documents
# 560. Clonidine - Success getting documents
# 561. Sulfamethizole - Success getting documents
# 562. Valaciclovir - Success getting documents
# 563. Carbenicillin - Success getting documents
# 564. Mazindol - Success getting documents
# 565. Valdecoxib - Success getting documents
# 566. Lactulose - Success getting documents
# 567. Voriconazole - Fail
# sequence item 6: expected str instance, NoneType found
# 568. Levocarnitine - Success getting documents
# 569. Enalapril - Success getting documents
# 570. Nizatidine - Success getting documents
# 571. Diclofenac - Fail
# sequence item 7: expected str instance, NoneType found
# 572. Cinalukast - Success getting documents
# 573. Fluticasone propionate - Success getting documents
# 574. Lisuride - Success getting documents
# 575. Doxazosin - Success getting documents
# 576. Fluocinolone acetonide - Success getting documents
# 577. Piperazine - Success getting documents
# 578. Ethosuximide - Success getting documents
# 579. Amiloride - Success getting documents
# 580. Oxytetracycline - Success getting documents
# 581. Ulobetasol - Success getting documents
# 582. Gadoteridol - Success getting documents
# 583. Labetalol - Success getting documents
# 584. Thiopental - Success getting documents
# 585. Monobenzone - Success getting documents
# 586. Linezolid - Success getting documents
# 587. Ivermectin - Success getting documents
# 588. Medroxyprogesterone acetate - Success getting documents
# 589. Cisapride - Success getting documents
# 590. Sulindac - Success getting documents
# 591. Cyclothiazide - Success getting documents
# 592. Nafcillin - Success getting documents
# 593. Chloroquine - Success getting documents
# 594. Ethionamide - Success getting documents
# 595. Metaraminol - Success getting documents
# 596. Butorphanol - Success getting documents
# 597. Bisoprolol - Success getting documents
# 598. Amodiaquine - Success getting documents
# 599. Furazolidone - Success getting documents
# 600. Rifabutin - Success getting documents
# 601. Candoxatril - Success getting documents
# 602. Paramethadione - Success getting documents
# 603. Demeclocycline - Success getting documents
# 604. Imatinib - Success getting documents
# 605. Triamcinolone - Success getting documents
# 606. Oxandrolone - Success getting documents
# 607. Nicardipine - Success getting documents
# 608. Fluphenazine - Success getting documents
# 609. Testosterone - Success getting documents
# 610. Efavirenz - Success getting documents
# 611. Bacitracin - Success getting documents
# 612. Niacin - Success getting documents
# 613. Clorazepic acid - Success getting documents
# 614. Guanabenz - Success getting documents
# 615. Alendronic acid - Success getting documents
# 616. Clofarabine - Success getting documents
# 617. Docosanol - Success getting documents
# 618. Dexmedetomidine - Success getting documents
# 619. Sulfacetamide - Success getting documents
# 620. Prednisone - Success getting documents
# 621. Clofibrate - Success getting documents
# 622. Astemizole - Success getting documents
# 623. Inulin - Success getting documents
# 624. Butoconazole - Success getting documents
# 625. Adenosine - Success getting documents
# 626. Simvastatin - Success getting documents
# 627. Pemetrexed - Success getting documents
# 628. Mebendazole - Success getting documents
# 629. Gonadorelin - Success getting documents
# 630. Dyclonine - Success getting documents
# 631. Nystatin - Success getting documents
# 632. Dextropropoxyphene - Success getting documents
# 633. Mitotane - Success getting documents
# 634. Stavudine - Success getting documents
# 635. Leucovorin - Success getting documents
# 636. Dyphylline - Success getting documents
# 637. Pentazocine - Success getting documents
# 638. Magnesium sulfate - Success getting documents
# 639. Latanoprost - Success getting documents
# 640. Estrone - Success getting documents
# 641. Trazodone - Success getting documents
# 642. Mecamylamine - Success getting documents
# 643. Sevelamer - Success getting documents
# 644. Acamprosate - Success getting documents
# 645. Metaxalone - Success getting documents
# 646. Verapamil - Fail
# sequence item 12: expected str instance, NoneType found
# 647. Trimethobenzamide - Success getting documents
# 648. Flumethasone - Success getting documents
# 649. Sulfametopyrazine - Success getting documents
# 650. Nilutamide - Fail
# sequence item 8: expected str instance, NoneType found
# 651. Nafarelin - Success getting documents
# 652. Epinephrine - Success getting documents
# 653. Sumatriptan - Success getting documents
# 654. Pirenzepine - Success getting documents
# 655. Cefixime - Success getting documents
# 656. Chlorpropamide - Success getting documents
# 657. Aprepitant - Success getting documents
# 658. Galantamine - Success getting documents
# 659. Tamoxifen - Fail
# sequence item 19: expected str instance, NoneType found
# 660. Benzyl benzoate - Success getting documents
# 661. Isoflurophate - Success getting documents
# 662. Losartan - Success getting documents
# 663. Thioridazine - Success getting documents
# 664. Moricizine - Success getting documents
# 665. Amphotericin B - Fail
# sequence item 16: expected str instance, NoneType found
# 666. Warfarin - Success getting documents
# 667. Midazolam - Success getting documents
# 668. Tobramycin - Success getting documents
# 669. Trovafloxacin - Success getting documents
# 670. Pentosan polysulfate - Success getting documents
# 671. Fludrocortisone - Success getting documents
# 672. Mycophenolate mofetil - Success getting documents
# 673. Cephaloglycin - Success getting documents
# 674. Flurazepam - Success getting documents
# 675. Moexipril - Success getting documents
# 676. Phentolamine - Success getting documents
# 677. Fluorescein - Fail
# sequence item 11: expected str instance, NoneType found
# 678. Daunorubicin - Success getting documents
# 679. Furosemide - Success getting documents
# 680. Ergotamine - Fail
# sequence item 1: expected str instance, NoneType found
# 681. Tizanidine - Success getting documents
# 682. Nitrofurantoin - Success getting documents
# 683. Nicergoline - Success getting documents
# 684. Eplerenone - Success getting documents
# 685. Amprenavir - Success getting documents
# 686. Icodextrin - Success getting documents
# 687. Methazolamide - Success getting documents
# 688. Naltrexone - Success getting documents
# 689. Delavirdine - Success getting documents
# 690. Tamsulosin - Success getting documents
# 691. Porfimer sodium - Success getting documents
# 692. Sufentanil - Fail
# sequence item 0: expected str instance, NoneType found
# 693. Lamivudine - Success getting documents
# 694. Ibandronate - Success getting documents
# 695. Diethylcarbamazine - Success getting documents
# 696. Flurbiprofen - Success getting documents
# 697. Oxacillin - Success getting documents
# 698. Apomorphine - Success getting documents
# 699. Paroxetine - Success getting documents
# 700. Nedocromil - Success getting documents
# 701. Norethisterone - Success getting documents
# 702. Adefovir dipivoxil - Success getting documents
# 703. Azatadine - Success getting documents
# 704. Clodronic acid - Success getting documents
# 705. Procaine - Success getting documents
# 706. Lisinopril - Success getting documents
# 707. Methoxamine - Success getting documents
# 708. Imiquimod - Success getting documents
# 709. Homatropine methylbromide - Success getting documents
# 710. Trimipramine - Success getting documents
# 711. Nitroglycerin - Success getting documents
# 712. Rocuronium - Success getting documents
# 713. Thiabendazole - Success getting documents
# 714. Nateglinide - Success getting documents
# 715. Atracurium besylate - Success getting documents
# 716. Pralidoxime - Success getting documents
# 717. Risperidone - Success getting documents
# 718. Naftifine - Fail
# sequence item 2: expected str instance, NoneType found
# 719. Esomeprazole - Success getting documents
# 720. Meclizine - Success getting documents
# 721. Pentamidine - Success getting documents
# 722. Hetacillin - Success getting documents
# 723. Riluzole - Success getting documents
# 724. Hydrocortisone - Success getting documents
# 725. Mannitol - Success getting documents
# 726. Gadobenic acid - Success getting documents
# 727. Zileuton - Success getting documents
# 728. Modafinil - Success getting documents
# 729. Deferoxamine - Success getting documents
# 730. Scopolamine - Fail
# sequence item 7: expected str instance, NoneType found
# 731. Carbinoxamine - Success getting documents
# 732. Etodolac - Success getting documents
# 733. Prilocaine - Success getting documents
# 734. Epinastine - Success getting documents
# 735. Tranylcypromine - Success getting documents
# 736. Isoflurane - Success getting documents
# 737. Ethotoin - Success getting documents
# 738. Tretinoin - Success getting documents
# 739. Hexachlorophene - Success getting documents
# 740. Dolasetron - Success getting documents
# 741. Clopidogrel - Success getting documents
# 742. Tetracycline - Success getting documents
# 743. Meropenem - Success getting documents
# 744. Potassium chloride - Success getting documents
# 745. Irinotecan - Fail
# sequence item 1: expected str instance, NoneType found
# 746. Methimazole - Success getting documents
# 747. Mometasone - Success getting documents
# 748. Metyrosine - Success getting documents
# 749. Clavulanic acid - Success getting documents
# 750. Benzquinamide - Success getting documents
# 751. Olopatadine - Success getting documents
# 752. Hydrocortamate - Success getting documents
# 753. Alprostadil - Success getting documents
# 754. Clidinium - Success getting documents
# 755. Malathion - Success getting documents
# 756. Etoposide - Success getting documents
# 757. Hydroflumethiazide - Success getting documents
# 758. Tirofiban - Success getting documents
# 759. Oxcarbazepine - Success getting documents
# 760. Propiomazine - Success getting documents
# 761. Roxithromycin - Success getting documents
# 762. Nalidixic acid - Success getting documents
# 763. Phenelzine - Success getting documents
# 764. Propantheline - Success getting documents
# 765. Estradiol - Success getting documents
# 766. Mefenamic acid - Success getting documents
# 767. Cryptenamine - Success getting documents
# 768. Marimastat - Success getting documents
# 769. Acyclovir - Success getting documents
# 770. Naproxen - Success getting documents
# 771. Gadopentetic acid - Success getting documents
# 772. Perindopril - Success getting documents
# 773. Uracil mustard - Success getting documents
# 774. Tripelennamine - Success getting documents
# 775. Haloprogin - Success getting documents
# 776. Primidone - Success getting documents
# 777. Sulfasalazine - Success getting documents
# 778. Candesartan cilexetil - Success getting documents
# 779. Tolazoline - Success getting documents
# 780. Gentamicin - Success getting documents
# 781. Tazarotene - Success getting documents
# 782. Fenoldopam - Success getting documents
# 783. Halazepam - Success getting documents
# 784. Alfentanil - Success getting documents
# 785. Colistin - Success getting documents
# 786. Dicyclomine - Success getting documents
# 787. Minaprine - Success getting documents
# 788. Pentoxifylline - Success getting documents
# 789. Proparacaine - Success getting documents
# 790. Indapamide - Success getting documents
# 791. Tropicamide - Success getting documents
# 792. Biperiden - Success getting documents
# 793. Ribavirin - Success getting documents
# 794. Phenylbutazone - Success getting documents
# 795. Fentanyl - Success getting documents
# 796. Meloxicam - Success getting documents
# 797. Sodium lauryl sulfate - Success getting documents
# 798. Orciprenaline - Success getting documents
# 799. Rosoxacin - Success getting documents
# 800. Propofol - Success getting documents
# 801. Acetazolamide - Fail
# sequence item 7: expected str instance, NoneType found
# 802. Tadalafil - Success getting documents
# 803. Carprofen - Success getting documents
# 804. Disulfiram - Success getting documents
# 805. Ethynodiol diacetate - Success getting documents
# 806. Enprofylline - Success getting documents
# 807. Levomenthol - Success getting documents
# 808. Natamycin - Success getting documents
# 809. Cinoxacin - Success getting documents
# 810. Fosfomycin - Fail
# sequence item 16: expected str instance, NoneType found
# 811. Diazepam - Success getting documents
# 812. Phenmetrazine - Success getting documents
# 813. Trifluoperazine - Success getting documents
# 814. Phensuximide - Success getting documents
# 815. Cefaclor - Success getting documents
# 816. Mifepristone - Success getting documents
# 817. Brompheniramine - Success getting documents
# 818. Loperamide - Fail
# sequence item 16: expected str instance, NoneType found
# 819. Progabide - Success getting documents
# 820. Clocortolone - Success getting documents
# 821. Tolazamide - Success getting documents
# 822. Hydroxypropyl cellulose - Success getting documents
# 823. Dobutamine - Success getting documents
# 824. Oxazepam - Success getting documents
# 825. Donepezil - Success getting documents
# 826. Nalbuphine - Success getting documents
# 827. Clofazimine - Fail
# sequence item 16: expected str instance, NoneType found
# 828. Flurandrenolide - Success getting documents
# 829. Cysteamine - Success getting documents
# 830. Levamisole - Success getting documents
# 831. Methylphenobarbital - Success getting documents
# 832. Perphenazine - Success getting documents
# 833. Dacarbazine - Success getting documents
# 834. Pseudoephedrine - Success getting documents
# 835. Temozolomide - Fail
# sequence item 2: expected str instance, NoneType found
# 836. Levorphanol - Success getting documents
# 837. Aminolevulinic acid - Success getting documents
# 838. Chlorphenesin - Success getting documents
# 839. Terbinafine - Success getting documents
# 840. Drostanolone - Success getting documents
# 841. Penicillamine - Success getting documents
# 842. Prednisolone - Success getting documents
# 843. Diflunisal - Success getting documents
# 844. Vardenafil - Success getting documents
# 845. Ranitidine - Success getting documents
# 846. Tacrolimus - Success getting documents
# 847. Benzphetamine - Success getting documents
# 848. Alprenolol - Success getting documents
# 849. Ritodrine - Success getting documents
# 850. Benzonatate - Success getting documents
# 851. Dorzolamide - Success getting documents
# 852. Suprofen - Success getting documents
# 853. Terbutaline - Success getting documents
# 854. Conivaptan - Success getting documents
# 855. Loteprednol etabonate - Success getting documents
# 856. Guaifenesin - Success getting documents
# 857. Flupentixol - Success getting documents
# 858. Eprosartan - Success getting documents
# 859. Sirolimus - Success getting documents
# 860. Chlorhexidine - Success getting documents
# 861. Emtricitabine - Success getting documents
# 862. Chlorothiazide - Success getting documents
# 863. Quinapril - Success getting documents
# 864. Clomifene - Success getting documents
# 865. Isosorbide dinitrate - Success getting documents
# 866. Risedronic acid - Success getting documents
# 867. Pemirolast - Success getting documents
# 868. Omapatrilat - Success getting documents
# 869. Bumetanide - Success getting documents
# 870. Mechlorethamine - Success getting documents
# 871. Granisetron - Success getting documents
# 872. Dienestrol - Success getting documents
# 873. Sulfapyridine - Success getting documents
# 874. Oxybuprocaine - Success getting documents
# 875. Iron Dextran - Success getting documents
# 876. Testolactone - Success getting documents
# 877. Benzylpenicilloyl polylysine - Success getting documents
# 878. Rimexolone - Success getting documents
# 879. Triazolam - Success getting documents
# 880. Ethanol - Success getting documents
# 881. Remifentanil - Success getting documents
# 882. Didanosine - Fail
# sequence item 0: expected str instance, NoneType found
# 883. Bitolterol - Success getting documents
# 884. Methdilazine - Success getting documents
# 885. Etacrynic acid - Success getting documents
# 886. Ondansetron - Success getting documents
# 887. Bimatoprost - Success getting documents
# 888. Tiagabine - Success getting documents
# 889. Cocaine - Success getting documents
# 890. Quinidine - Success getting documents
# 891. Zonisamide - Success getting documents
# 892. Paricalcitol - Success getting documents
# 893. Tinidazole - Success getting documents
# 894. Repaglinide - Fail
# sequence item 17: expected str instance, NoneType found
# 895. Anileridine - Success getting documents
# 896. Phenformin - Success getting documents
# 897. Amantadine - Success getting documents
# 898. Metronidazole - Fail
# sequence item 9: expected str instance, NoneType found
# 899. Dinoprostone - Success getting documents
# 900. Almotriptan - Success getting documents
# 901. Spectinomycin - Success getting documents
# 902. Ketotifen - Success getting documents
# 903. Buprenorphine - Success getting documents
# 904. Levosimendan - Success getting documents
# 905. Ceforanide - Success getting documents
# 906. Cyclobenzaprine - Success getting documents
# 907. Phenoxybenzamine - Success getting documents
# 908. Etretinate - Success getting documents
# 909. Famotidine - Success getting documents
# 910. Azacitidine - Success getting documents
# 911. Misoprostol - Success getting documents
# 912. Colesevelam - Success getting documents
# 913. Metacycline - Success getting documents
# 914. Tipranavir - Success getting documents
# 915. Mesoridazine - Success getting documents
# 916. Maprotiline - Success getting documents
# 917. Oxymetazoline - Success getting documents
# 918. Salicylic acid - Success getting documents
# 919. Diethylpropion - Success getting documents
# 920. Salmeterol - Success getting documents
# 921. Meclofenamic acid - Success getting documents
# 922. Methantheline - Success getting documents
# 923. Hexafluronium - Success getting documents
# 924. Cycrimine - Success getting documents
# 925. Zalcitabine - Success getting documents
# 926. Demecarium - Success getting documents
# 927. Acetylsalicylic acid - Success getting documents
# 928. Phenprocoumon - Success getting documents
# 929. Fulvestrant - Success getting documents
# 930. Mezlocillin - Success getting documents
# 931. Felbamate - Success getting documents
# 932. Fexofenadine - Success getting documents
# 933. Isoniazid - Success getting documents
# 934. Naratriptan - Success getting documents
# 935. Rizatriptan - Success getting documents
# 936. Dirithromycin - Success getting documents
# 937. Netilmicin - Success getting documents
# 938. Hydrocodone - Success getting documents
# 939. Norgestimate - Success getting documents
# 940. Carboplatin - Fail
# sequence item 5: expected str instance, NoneType found
# 941. Methylprednisolone - Success getting documents
# 942. Pindolol - Success getting documents
# 943. Mepivacaine - Success getting documents
# 944. Zaleplon - Success getting documents
# 945. Bromfenac - Success getting documents
# 946. Apraclonidine - Success getting documents
# 947. Ethiodized oil - Success getting documents
# 948. Telmisartan - Success getting documents
# 949. Desloratadine - Success getting documents
# 950. Methyldopa - Success getting documents
# 951. Alosetron - Success getting documents
# 952. Dactinomycin - Success getting documents
# 953. Selenium Sulfide - Success getting documents
# 954. Azelastine - Success getting documents
# 955. Ezetimibe - Success getting documents
# 956. Edetic acid - Success getting documents
# 957. Dipyridamole - Success getting documents
# 958. Telithromycin - Fail
# sequence item 1: expected str instance, NoneType found
# 959. Ethinylestradiol - Success getting documents
# 960. Lomefloxacin - Success getting documents
# 961. Cyclopentolate - Success getting documents
# 962. Ramelteon - Success getting documents
# 963. Physostigmine - Success getting documents
# 964. Isotretinoin - Success getting documents
# 965. Formoterol - Success getting documents
# 966. Nandrolone phenpropionate - Success getting documents
# 967. Dimenhydrinate - Success getting documents
# 968. Glycopyrronium - Success getting documents
# 969. Cytarabine - Success getting documents
# 970. Dopamine - Success getting documents
# 971. Rivastigmine - Success getting documents
# 972. Exemestane - Fail
# sequence item 18: expected str instance, NoneType found
# 973. Oxaprozin - Success getting documents
# 974. Methyl aminolevulinate - Success getting documents
# 975. Azathioprine - Success getting documents
# 976. Neomycin - Fail
# sequence item 15: expected str instance, NoneType found
# 977. Auranofin - Success getting documents
# 978. Gabapentin - Success getting documents
# 979. Doxorubicin - Fail
# sequence item 8: expected str instance, NoneType found
# 980. Frovatriptan - Success getting documents
# 981. Hydrochlorothiazide - Success getting documents
# 982. Cyclacillin - Success getting documents
# 983. Salbutamol - Success getting documents
# 984. Levobupivacaine - Success getting documents
# 985. Cromoglicic acid - Success getting documents
# 986. Ganciclovir - Success getting documents
# 987. Hydroxyurea - Success getting documents
# 988. Letrozole - Fail
# sequence item 16: expected str instance, NoneType found
# 989. Tioconazole - Success getting documents
# 990. Busulfan - Fail
# sequence item 8: expected str instance, NoneType found
# 991. Ketoprofen - Success getting documents
# 992. Edrophonium - Success getting documents
# 993. Metyrapone - Success getting documents
# 994. Cinacalcet - Success getting documents
# 995. Clobetasol propionate - Success getting documents
# 996. Balsalazide - Success getting documents
# 997. Sulfamethoxazole - Fail
# sequence item 5: expected str instance, NoneType found
# 998. Glyburide - Success getting documents
# 999. Minocycline - Success getting documents
# 1000. Guanfacine - Success getting documents
# 1001. Bethanechol - Success getting documents
# 1002. Isosorbide mononitrate - Success getting documents
# ...
# 13312. Cetrelimab - Success getting documents
# 13313. ILS-920 - Success getting documents
# 13314. Disaccharide tripeptide glycerol dipalmitoyl - Success getting documents
# 13315. Bfpet F-18 - Success getting documents
# 13316. CYC-065 - Success getting documents
# 13317. Giripladib - Success getting documents
# 13318. Fialuridine - Success getting documents
# 13319. Vesencumab - Success getting documents
# 13320. Thioglycolic acid - Success getting documents
# 13321. Elgemtumab - Success getting documents
# 13322. M-2698 - Success getting documents
# 13323. Pinatuzumab vedotin - Success getting documents
# 13324. AVI-7537 - Success getting documents
# 13325. Mosunetuzumab - Success getting documents
# 13326. BMS-986158 - Success getting documents
# 13327. Glucoraphanin - Success getting documents
# 13328. Rocacetrapib - Success getting documents
# 13329. Artemin - Success getting documents
# 13330. Navoximod - Success getting documents
# 13331. GSK-3117391 - Success getting documents
# 13332. Lulizumab pegol - Success getting documents
# 13333. Trilaciclib - Success getting documents
# 13334. Lorukafusp alfa - Success getting documents
# 13335. Elexacaftor - Success getting documents
# 13336. Iodohippuric acid - Success getting documents
# 13337. Vidofludimus - Success getting documents
# 13338. Setogepram - Success getting documents
# 13339. Acumapimod - Success getting documents
# 13340. Citarinostat - Success getting documents
# 13341. PF-05105679 - Success getting documents
# 13342. SOBI-003 - Success getting documents
# 13343. Technetium Tc-99m epratuzumab - Success getting documents
# 13344. Naratuximab emtansine - Success getting documents
# 13345. Cenersen - Success getting documents
# 13346. Vericiguat - Success getting documents
# 13347. Snubh-nm-333 F-18 - Success getting documents
# 13348. Norleucine - Success getting documents
# 13349. AGG-523 - Success getting documents
# 13350. Yersinia pestis 195/p antigen (formaldehyde inactivated) - Success getting documents
# 13351. Fucoxanthin - Success getting documents
# 13352. PT2977 - Success getting documents
# 13353. Urolithin A - Success getting documents
# 13354. Benzhydrocodone - Success getting documents
# 13355. Tallimustine - Success getting documents
# 13356. Cinoxate - Success getting documents
# 13357. Iscotrizinol - Success getting documents
# 13358. Octyl triazone - Success getting documents
# 13359. Minretumomab - Success getting documents
# 13360. ZW-25 - Success getting documents
# 13361. ZW-49 - Success getting documents
# 13362. Haemagglutinin-strain B (Victoria) - Success getting documents
# 13363. Haemagglutinin-strain B (Yamagata) - Success getting documents
# 13364. Haemagglutinin-strain A(H3N2) - Success getting documents
# 13365. Haemagglutinin-strain A(H1N1) - Success getting documents
# 13366. Alloin - Success getting documents
# 13367. Frangula purshiana bark - Success getting documents
# 13368. Zirconium chloride hydroxide - Success getting documents
# 13369. Resorcinol monoacetate - Success getting documents
# 13370. Fish liver oil - Success getting documents
# 13371. Haemagglutinin-strain B - Success getting documents
# 13372. Modified vaccinia ankara - Success getting documents
# 13373. VIBRIO CHOLERAE INABA 6973 E1 TOR BIOTYPE, FORMALIN INACTIVATED - Success getting documents
# 13374. VIBRIO CHOLERAE INABA 48 CLASSICAL BIOTYPE, HEAT INACTIVATED - Success getting documents
# 13375. VIBRIO CHOLERAE OGAWA 50 CLASSICAL BIOTYPE, HEAT INACTIVATED - Success getting documents
# 13376. VIBRIO CHOLERAE OGAWA 50 CLASSICAL BIOTYPE, FORMALIN INACTIVATED - Success getting documents
# 13377. Echinacoside - Success getting documents
# 13378. Mexazolam - Success getting documents
# 13379. Zuranolone - Success getting documents
# 13380. Oxazolam - Success getting documents
# 13381. Eticlopride - Success getting documents
# 13382. Cambinol - Success getting documents
# 13383. Edotreotide gallium Ga-68 - Success getting documents
# 13384. Rocaglamide - Success getting documents
# 13385. Didesmethylrocaglamide - Success getting documents
# 13386. Smallpox and Monkeypox Vaccine, Live, Non-replicating - Success getting documents
# 13387. BOS172722 - Success getting documents
# 13388. Cerdulatinib - Success getting documents
# 13389. Influenza A virus A/Brisbane/02/2018 IVR-190 (H1N1) antigen (propiolactone inactivated) - Success getting documents
# 13390. Influenza A virus A/Kansas/14/2017 X-327 (H3N2) antigen (propiolactone inactivated) - Success getting documents
# 13391. Baccharis sarothroides whole - Success getting documents
# 13392. Amaranthus hybridus pollen - Success getting documents
# 13393. Acacia dealbata pollen - Success getting documents
# 13394. Influenza A virus A/Idaho/07/2018 (H1N1) antigen (MDCK cell derived, propiolactone inactivated - Success getting documents
# 13395. Influenza A virus A/Indiana/08/2018 (H3N2) antigen (MDCK cell derived, propiolactone inactivated) - Success getting documents
# 13396. Influenza B virus B/Singapore/INFTT-16-0610/2016 antigen (MDCK cell derived, propiolactone inactivated) - Success getting documents
# 13397. Influenza B virus B/Iowa/06/2017 antigen (MDCK cell derived, propiolactone inactivated) - Success getting documents
# 13398. Alnus serrulata pollen - Success getting documents
# 13399. Prosopis velutina seed - Success getting documents
# 13400. Gibberella fujikuroi - Success getting documents
# 13401. Mucor circinelloides f. circinelloides - Success getting documents
# 13402. Influenza A virus A/Switzerland/3330/2017 (H1N1) live (attenuated) antigen - Success getting documents
# 13403. Influenza A virus A/Kansas/14/2017 (H3N2) live (attenuated) antigen - Success getting documents
# 13404. Influenza A virus A/Brisbane/02/2018 IVR-190 (H1N1) antigen (formaldehyde inactivated) - Success getting documents
# 13405. Influenza A virus A/Kansas/14/2017 X-327 (H3N2) antigen (formaldehyde inactivated) - Success getting documents
# 13406. Influenza A virus A/Brisbane/02/2018 (H1N1) recombinant hemagglutinin antigen - Success getting documents
# 13407. Influenza A virus A/Kansas/14/2017 (H3N2) recombinant hemagglutinin antigen - Success getting documents
# 13408. Influenza A virus A/Brisbane/02/2018 IVR-190 (H1N1) antigen (UV, formaldehyde inactivated) - Success getting documents
# 13409. Influenza A virus A/Kansas/14/2017 X-327 (H3N2) antigen (UV, formaldehyde inactivated) - Success getting documents
# 13410. Cyd dengue virus serotype 1 live (attenuated) antigen - Success getting documents
# 13411. Cyd dengue virus serotype 2 live (attenuated) antigen - Success getting documents
# 13412. Cyd dengue virus serotype 3 live (attenuated) antigen - Success getting documents
# 13413. Cyd dengue virus serotype 4 live (attenuated) antigen - Success getting documents
# 13414. Mucor circinelloides f. lusitanicus - Success getting documents
# 13415. Eurotium amstelodami - Success getting documents
# 13416. Umirolimus - Success getting documents
# 13417. Onasemnogene abeparvovec - Success getting documents
# 13418. Leucanthemum vulgare pollen - Success getting documents
# 13419. Trifolium pratense pollen - Success getting documents
# 13420. Silk sericin - Success getting documents
# 13421. Madecassoside - Success getting documents
# 13422. Calcium sulfate - Success getting documents
# 13423. Colchiceine - Success getting documents
# 13424. Cuprous chloride - Success getting documents
# 13425. Ferric chloride - Success getting documents
# 13426. Eucalyptus gum - Success getting documents
# 13427. Sea scallop - Success getting documents
# 13428. Northern brown shrimp - Success getting documents
# 13429. Rainbow trout - Fail
# sequence item 5: expected str instance, NoneType found
# 13430. Yellowfin tuna - Success getting documents
# 13431. Atlantic mackerel - Success getting documents
# 13432. Pacific ocean perch - Success getting documents
# 13433. Myristica fragrans fruit - Success getting documents
# 13434. Pisum sativum whole - Success getting documents
# 13435. Skim milk - Success getting documents
# 13436. Black sea bass - Success getting documents
# 13437. Channel catfish - Success getting documents
# 13438. Atlantic halibut - Success getting documents
# 13439. Pradefovir - Success getting documents
# 13440. Leptazoline A - Success getting documents
# 13441. Leptazoline B - Success getting documents
# 13442. Leptazoline C - Fail
# sequence item 7: expected str instance, NoneType found
# 13443. Leptazoline D - Success getting documents
# 13444. Magnesium malate - Success getting documents
# 13445. Zinc glycinate citrate - Success getting documents
# 13446. 24-Homo-1,25-dihydroxyvitamin D3 - Success getting documents
# 13447. Imalumab - Success getting documents
# 13448. Zenocutuzumab - Success getting documents
# 13449. Reloxaliase - Success getting documents
# 13450. Valoctocogene roxaparvovec - Success getting documents
# 13451. Influenza A virus A/North carolina/04/2016 (H3N2) hemagglutinin antigen (MDCK cell derived, propiolactone inactivated) - Success getting documents
# 13452. Influenza B virus B/Iowa/06/2017 hemagglutinin antigen (MDCK cell derived, propiolactone inactivated) - Success getting documents
# 13453. Influenza B virus B/Singapore/INFTT-16-0610/2016 hemagglutinin antigen (MDCK cell derived, propiolactone inactivated) - Success getting documents
# 13454. Cilazaprilat - Success getting documents
# 13455. Prednisolone acetate - Success getting documents
# 13456. PCLX-001 - Success getting documents
# 13457. MRTX849 - Success getting documents
# 13458. AMG-510 - Success getting documents
# 13459. FLX475 - Success getting documents
# 13460. (12R)-12-hydroxyeicosapentaenoic acid - Success getting documents
# 13461. CTX001 - Success getting documents
# 13462. alpha-Pinene - Success getting documents
# 13463. beta-Pinene - Fail
# sequence item 13: expected str instance, NoneType found
# 13464. Padeliporfin - Success getting documents
# 13465. Ethyl salicylate - Success getting documents
# 13466. Desfesoterodine - Success getting documents
# 13467. Cryptotanshinone - Success getting documents
# 13468. Climbazole - Success getting documents
# 13469. Chrysin - Success getting documents
# 13470. Echinomycin - Success getting documents
# 13471. Fluazuron - Success getting documents
# 13472. Luteolin - Success getting documents
# 13473. ORG-31710 - Success getting documents
# 13474. Patulin - Success getting documents
# 13475. Antimony potassium tartrate - Success getting documents
# 13476. Ursolic acid - Success getting documents
# 13477. Zingerone - Success getting documents
# 13478. beta-Apopicropodophyllin - Success getting documents
# 13479. Atrial natriuretic peptide - Success getting documents
# 13480. Cucurbita pepo subsp. ovifera whole - Success getting documents
# 13481. Golodirsen - Success getting documents
# 13482. Brilliant blue G - Success getting documents
# 13483. Ebola Zaire vaccine (live, attenuated) - Success getting documents
# 13484. Aminopromazine - Success getting documents
# 13485. Aminopentamide - Success getting documents
# 13486. Ferric maltol - Success getting documents
# 13487. MIV-711 - Success getting documents
# 13488. NNZ-2591 - Success getting documents
# 13489. Cashew fruit - Success getting documents
# 13490. Coffea arabica seed, roasted - Success getting documents
# 13491. Lactuca sativa whole - Success getting documents
# 13492. Field mushroom - Success getting documents
# 13493. White mustard seed - Success getting documents
# 13494. Hydrolyzed soy protein - Success getting documents
# 13495. Theobroma cacao whole - Success getting documents
# 13496. JPC-3210 - Fail
# sequence item 0: expected str instance, NoneType found
# 13497. (4-(trifluoromethoxy)phenyl)urea - Fail
# sequence item 0: expected str instance, NoneType found
# 13498. Muskmelon - Success getting documents
# 13499. American hazelnut - Success getting documents
# 13500. Musa acuminata fruit - Success getting documents
# 13501. Previtamin D(3) - Success getting documents
# 13502. Fennel - Success getting documents
# 13503. REC-994 - Success getting documents
# 13504. Ferric derisomaltose - Success getting documents
# 13505. (5E,7E,9)-decatrien-2-one - Success getting documents
# 13506. (5Z,7E,9)-decatrien-2-one - Success getting documents
# 13507. Influenza B virus B/Washington/02/2019 antigen (formaldehyde inactivated) - Success getting documents
# 13508. Influenza A virus A/South australia/34/2019 IVR-197 (H3N2) antigen (formaldehyde inactivated) - Success getting documents
# 13509. Triazavirin - Success getting documents
# 13510. TMC-310911 - Success getting documents
# 13511. Halicin - Success getting documents
# 13512. Spesolimab - Success getting documents
# 13513. Dostarlimab - Success getting documents
# 13514. Inolimomab - Success getting documents
# 13515. Garadacimab - Success getting documents
# 13516. Glumetinib - Success getting documents
# 13517. Edodekin alfa - Success getting documents
# 13518. Zalifrelimab - Success getting documents
# 13519. Pabinafusp alfa - Success getting documents
# 13520. Temelimab - Success getting documents
# 13521. Omburtamab - Success getting documents
# 13522. Zilucoplan - Success getting documents
# 13523. Fluzoparib - Success getting documents
# 13524. Brensocatib - Success getting documents
# 13525. AMG-337 - Success getting documents
# 13526. CDC-801 - Success getting documents
# 13527. Droloxifene - Success getting documents
# 13528. Molidustat - Success getting documents
# 13529. N-(2-Aminoethyl)-1-aziridineethanamine - Success getting documents
# 13530. Ochromycinone - Success getting documents
# 13531. Dihydromyricetin - Success getting documents
# 13532. Fasitibant - Success getting documents
# 13533. Ketodarolutamide - Success getting documents
# 13534. Calcium oxide - Success getting documents
# 13535. Carbomer - Success getting documents
# 13536. Efpeglenatide - Success getting documents
# 13537. Valomaciclovir stearate - Success getting documents
# 13538. Ravidasvir - Success getting documents
# 13539. Islatravir - Success getting documents
# 13540. mRNA-1273 - Success getting documents
# 13541. Ad5-nCoV - Success getting documents
# 13542. AZD1222 - Success getting documents
# 13543. Ala-geninthiocin - Success getting documents
# 13544. 2-chloro-4,5-dimethylphenol - Success getting documents
# 13545. alpha,alpha-Dibromo-D-camphor - Success getting documents
# 13546. N4-Hydroxycytidine - Success getting documents
# 13547. EIDD-2801 - Success getting documents
# 13548. Myristyl glyceryl ether - Success getting documents
# 13549. Grapefruit oil - Success getting documents
# 13550. Vitamin K7 - Success getting documents
# 13551. SEP-363856 - Success getting documents
# 13552. Iodopropynyl butylcarbamate - Success getting documents
# 13553. Bacillus amyloliquefaciens - Success getting documents
# 13554. Silver oxide - Success getting documents
# 13555. Fezolinetant - Success getting documents
# 13556. Gusacitinib - Success getting documents
# 13557. Besifovir - Success getting documents
# 13558. Rilematovir - Success getting documents
# 13559. Lenacapavir - Success getting documents
# 13560. Sisunatovir - Success getting documents
# 13561. Baloxavir - Success getting documents
# 13562. Balstilimab - Success getting documents
# 13563. Polyaminopropyl biguanide - Success getting documents
# 13564. Calcium undecylenate - Success getting documents
# 13565. Aluminum subacetate - Success getting documents
# 13566. Neisseria meningitidis group A capsular polysaccharide tetanus toxoid conjugate antigen - Success getting documents
# 13567. Neisseria meningitidis group C capsular polysaccharide tetanus toxoid conjugate antigen - Success getting documents
# 13568. Neisseria meningitidis group Y capsular polysaccharide tetanus toxoid conjugate antigen - Success getting documents
# 13569. Neisseria meningitidis group W-135 capsular polysaccharide tetanus toxoid conjugate antigen - Success getting documents
# 13570. 2,3-dichloro-5,6-dicyanobenzoquinone - Success getting documents
# 13571. Selpercatinib - Success getting documents
# 13572. GS-441524 - Success getting documents
# 13573. Tridecactide - Success getting documents
# 13574. Vazegepant - Success getting documents
# 13575. Azoximer bromide - Success getting documents
# 13576. Fluoroestradiol F-18 - Success getting documents
# 13577. Anti-SARS-CoV-2 REGN-COV2 - Success getting documents
# 13578. COVID-19 convalescent plasma - Success getting documents
# 13579. INO-4800 - Success getting documents

# %%
with open("D:/WorkSpace/master_thesis/data_pubmed/documents/result_documents.pkl", "wb") as fw:
    pickle.dump(documents, fw)
