# %%
# import cell
import nltk
from nltk.corpus import stopwords
import re
import pandas as pd
import pickle

# %%
# conda info --env
# Out:
# # conda environments:
# #
# base                  *  C:\Users\paten\anaconda3
# my-rdkit-env             C:\Users\paten\anaconda3\envs\my-rdkit-env
# py37                     C:\Users\paten\anaconda3\envs\py37
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# 유사도 확인 함수
import numpy as np

def most_similar(doc_id,similarity_matrix,matrix):
    print (f'Document: {documents_df.iloc[doc_id]["documents"]}')
    print ('\n')
    print ('Similar Documents:')
    if matrix=='Cosine Similarity':
        similar_ix=np.argsort(similarity_matrix[doc_id])[::-1]
    elif matrix=='Euclidean Distance':
        similar_ix=np.argsort(similarity_matrix[doc_id])
    for ix in similar_ix:
        if ix==doc_id:
            continue
        print('\n')
        print (f'Document: {documents_df.iloc[ix]["documents"]}')
        print (f'{matrix} : {similarity_matrix[doc_id][ix]}')

# %%
# Load documents 

# Drug bank complete slim data
drugbank_approved_df = pd.read_csv('D:/WorkSpace/master_thesis/Drug_Bank/result/drugbank_approved.tsv', sep='\t')
drugName = drugbank_approved_df['name']

# Drugbank vocabulary data
drugbank_voca_df = pd.read_csv('D:/WorkSpace/master_thesis/Drug_Bank/drugbank_vocabulary.csv')

# documents data (title, abstracts)
with open('D:/WorkSpace/master_thesis/data_pubmed/documents/approved_documents.pkl', 'rb') as f:
    documents = pickle.load(f)

# %%
print('Approved Drug: {}'.format(len(drugbank_approved_df)))
# len(drugbank_voca_df)
print('number of scraped Documents: {}'.format(len(documents)))
# Out:
# Approved Drug: 4270
# number of scraped Documents: 4027

# %%
# convert from dictionary to data_frame 
documents_df = pd.DataFrame(list(documents.items()), columns=['drugName', 'documents'])


# Documents 소문자 변환
for i in range(len(documents_df)):
    documents_df.documents[i] = df_documents.documents[i].lower()


# Remove stopwords from nltk
stop_words_l = stopwords.words('english')
documents_df['documents_cleaned'] = documents_df.documents.apply(lambda x: " ".join(re.sub(r'[^a-zA-Z]',' ',w).lower() for w in x.split() if re.sub(r'[^a-zA-Z]',' ',w).lower() not in stop_words_l) )

# %%
# using base BERT
from sentence_transformers import SentenceTransformer
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')

document_embeddings = sbert_model.encode(documents_df['documents_cleaned'])

# %%
biobert_model = SentenceTransformer('')

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances

pairwise_similarities=cosine_similarity(document_embeddings)
pairwise_differences=euclidean_distances(document_embeddings)

most_similar(0,pairwise_similarities,'Cosine Similarity')
most_similar(0,pairwise_differences,'Euclidean Distance')
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
#
#
# Document:
# Cosine Similarity : -0.021146124228835106
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Document: changing wheat bran structural properties by extrusion-cooking on a pilot and industrial scale: a comparative study. combination of extrusion and fermentation with  influence of durum wheat bran particle size on phytochemical content and on leavened bread baking quality. immunomodulatory effects of wheat bran arabinoxylan on raw264.7 macrophages via the nf-κb signaling pathway using rna-seq analysis. fortification of yellow alkaline noodles with wheat bran and the impact on physical and sensorial properties. a wheat bran inducible expression system for the efficient production of α-l-arabinofuranosidase in bacillus subtilis. conversion of wheat bran to xylanases and dye adsorbent by  efficiency of twin-screw extrusion of biodegradable poly (butylene succinate)-wheat bran blend. effects of different solid-state fermentation ratios of s. cerevisiae and l. plantarum on physico-chemical properties of wheat bran and the quality of whole wheat bread. digestibility, lactation performance, plasma metabolites, ruminal fermentation, and bacterial communities in holstein cows fed a fermented corn gluten-wheat bran mixture as a substitute for soybean meal. the effect of xylooligosaccharide, xylan, and whole wheat bran on the human gut bacteria. preparative separation of high-purity trans- and cis-ferulic acid from wheat bran by ph-zone-refining counter-current chromatography. effects of wheat bran and  the effect of wet milling and cryogenic milling on the structure and physicochemical properties of wheat bran. pilot-scale ohmic heating-assisted extraction of wheat bran bioactive compounds: effects of the extract on corn oil stability. preparation and characterization of ph-responsive microgel using arabinoxylan from wheat bran for bsa delivery. regression-derived ileal endogenous amino acid losses in broiler chickens and cannulated pigs fed corn fiber, wheat bran, and pectin. effects of wheat bran applied to maternal diet on the intestinal architecture and immune gene expression in suckling piglets. saccharomyces cerevisiae and phytase co-fermentation wheat bran on growth, antioxidation, immunity and intestinal morphology in broilers. a double-blind, placebo-controlled randomized trial of skin-lightening cream containing lycopene and wheat bran extract on melasma. extrusion-cooking can be used to change the techno-functional and nutrition-related properties of wheat bran. in this study, pilot-scale (bc21) and industrial-scale (bc45) twin-screw extrusion-cooking using different types of extrusion (single-pass, double-pass and acid extrusion-cooking) and process parameters (temperature, moisture) were compared for their impact on wheat bran. when applying the same process settings, the higher strong water-binding capacity, extract viscosity and extractability displayed by bran extruded using the industrial set-up reflected a more considerable wheat bran structure degradation compared to pilot-scale extrusion-cooking. this was attributed to the overall higher specific mechanical energy (sme), pressure and product temperature that were reached inside the industrial extruder. when changing the type of extrusion-cooking from single-pass to double-pass and acid extrusion-cooking, wheat bran physicochemical characteristics evolved in the same direction, irrespective of extruder scale. the differences in bran characteristics were, however, smaller on industrial-scale. results show that the differentiating power of the latter can be increased by decreasing the moisture content and increasing product temperature, beyond what is possible in the pilot-scale extruder. this was confirmed by using a bc72 industrial-scale extruder at low moisture content. in conclusion, the extruder scale mainly determines the sme that can be reached and determines the potential to modify wheat bran. processed wheat bran (w) is of great importance for food and feed. consequently, the biosafety of w should be evaluated and improved with valorisation strategies.  ...
# Euclidean Distance : 15.224271774291992
#
#
# ...
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.670719146728516
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715
#
#
# Document:
# Euclidean Distance : 22.67072105407715

# %%
len(documents)
# documents_df
# Out:
# 6

# %%
# pairwise_similarities
# document_embeddings
pairwise_similarities_test = cosine_similarity(document_embeddings)
print(pairwise_similarities_test)
print()
print(pairwise_similarities)
# Out:
# [[1.0000001  0.8365411  0.61181045 0.4764783  0.6589275  0.81594574]
#  [0.8365411  1.         0.67819023 0.5372207  0.7253677  0.78296375]
#  [0.61181045 0.67819023 0.99999994 0.6800262  0.6249758  0.71018046]
#  [0.4764783  0.5372207  0.6800262  1.0000001  0.5375689  0.6229849 ]
#  [0.6589275  0.7253677  0.6249758  0.5375689  1.0000002  0.78826356]
#  [0.81594574 0.78296375 0.71018046 0.6229849  0.78826356 0.99999994]]
#
# [[1.0000001  0.8365411  0.61181045 0.4764783  0.6589275  0.81594574]
#  [0.8365411  1.         0.67819023 0.5372207  0.7253677  0.78296375]
#  [0.61181045 0.67819023 0.99999994 0.6800262  0.6249758  0.71018046]
#  [0.4764783  0.5372207  0.6800262  1.0000001  0.5375689  0.6229849 ]
#  [0.6589275  0.7253677  0.6249758  0.5375689  1.0000002  0.78826356]
#  [0.81594574 0.78296375 0.71018046 0.6229849  0.78826356 0.99999994]]

# %%
import gensim
import sklearn
import nltk # 영어 자연어 처리
from nltk import RegexpTokenizer
from nltk.corpus import stopwords
import numpy as np
import torch

print('gensim  version = {}'.format(gensim.__version__))
print('pytorch version = {}'.format(torch.__version__))
print('sklearn version = {}'.format(sklearn.__version__))
print('nltk  version = {}'.format(nltk.__version__))
# Out:
# gensim  version = 3.8.3
# pytorch version = 1.7.1
# sklearn version = 0.23.1
# nltk  version = 3.5

# %%
# load pickle data
import pickle
import pandas as pd


# Drug bank complete slim data
drugbank_approved_df = pd.read_csv('D:/WorkSpace/master_thesis/Drug_Bank/result/drugbank_approved.tsv', sep='\t')
drugName = drugbank_approved_df['name']

# Drugbank vocabulary data
drugbank_voca_df = pd.read_csv('D:/WorkSpace/master_thesis/Drug_Bank/drugbank_vocabulary.csv')

# documents data (title, abstracts)
with open('D:/WorkSpace/master_thesis/data_pubmed/documents/approved_documents.pkl', 'rb') as f:
    documents = pickle.load(f)

# %%
# # drugbank_approved_df.name # column 명을 속성으로 접근
# # drugbank_approved_df.loc[0] # index명으로 접근

# # drug name으로 index 지정: set_index /reset_index
# test_df = drugbank_approved_df.set_index('name')
# # drugbank_approved_df.loc[0]
# print(test_df.loc['Lepirudin'])
# print()
# print(drugbank_approved_df.loc[0])

# %% [markdown]
# 파이썬 데이터프레임 접근 방법
# https://m.blog.naver.com/PostView.nhn?blogId=rian4u&logNo=221399141190&proxyReferer=https:%2F%2Fwww.google.com%2F

# %%
drugbank_approved_df.head()
# Out:
#   drugbank_id                 name     type                    groups  \
# 0     DB00001            Lepirudin  biotech                  approved
# 1     DB00002            Cetuximab  biotech                  approved
# 2     DB00003         Dornase alfa  biotech                  approved
# 3     DB00004  Denileukin diftitox  biotech  approved|investigational
# 4     DB00005           Etanercept  biotech  approved|investigational
#
#   atc_codes                                            targets  \
# 0   B01AE02                                        Prothrombin
# 1   L01XC06  Epidermal growth factor receptor|Low affinity ...
# 2   R05CB13                                                DNA
# 3   L01XX29  Interleukin-2 receptor subunit alpha|Interleuk...
# 4   L04AB01  Tumor necrosis factor|High affinity immunoglob...
#
#                                           categories inchikey inchi  \
# 0  Amino Acids, Peptides, and Proteins|Anticoagul...      NaN   NaN
# 1  Amino Acids, Peptides, and Proteins|Antibodies...      NaN   NaN
# 2  Amino Acids, Peptides, and Proteins|Cough and ...      NaN   NaN
# 3  ADP Ribose Transferases|Amino Acids, Peptides,...      NaN   NaN
# 4  Agents reducing cytokine levels|Amino Acids, P...      NaN   NaN
#
#                                          description
# 0  Lepirudin is identical to natural hirudin exce...
# 1  Cetuximab is an epidermal growth factor recept...
# 2  Dornase alfa is a biosynthetic form of human d...
# 3  A recombinant DNA-derived cytotoxic protein co...
# 4  Dimeric fusion protein consisting of the extra...

# %%
# input data 결정
print(len(drugbank_approved_df))
print(len(documents))

doc_list = documents.keys()
print(doc_list)
# Out:
# 4270
# 4027
# dict_keys(['Lepirudin', 'Cetuximab', 'Dornase alfa', 'Denileukin diftitox', 'Etanercept', 'Bivalirudin', 'Leuprolide', 'Peginterferon alfa-2a', 'Alteplase', 'Sermorelin', 'Interferon alfa-n1', 'Darbepoetin alfa', 'Urokinase', 'Goserelin', 'Reteplase', 'Erythropoietin', 'Salmon calcitonin', 'Interferon alfa-n3', 'Pegfilgrastim', 'Sargramostim', 'Peginterferon alfa-2b', 'Asparaginase Escherichia coli', 'Thyrotropin alfa', 'Antihemophilic factor, human recombinant', 'Anakinra', 'Gramicidin D', 'Human immunoglobulin G', 'Anistreplase', 'Insulin human', 'Tenecteplase', 'Menotropins', 'Interferon gamma-1b', 'Interferon alfa-2a, Recombinant', 'Desmopressin', 'Coagulation factor VIIa Recombinant Human', 'Oprelvekin', 'Palifermin', 'Glucagon', 'Aldesleukin', 'Botulinum Toxin Type B', 'Omalizumab', 'Lutropin alfa', 'Lyme disease vaccine (recombinant OspA)', 'Insulin lispro', 'Insulin glargine', 'Collagenase clostridium histolyticum', 'Rasburicase', 'Cetrorelix', 'Adalimumab', 'Somatotropin', 'Imiglucerase', 'Abciximab', 'Drotrecogin alfa', 'Gemtuzumab ozogamicin', 'Alpha-1-proteinase inhibitor', 'Pegaspargase', 'Interferon beta-1a', 'Pegademase', 'Albumin human', 'Eptifibatide', 'Infliximab', 'Follitropin', 'Vasopressin', 'Interferon beta-1b', 'Interferon alfacon-1', 'Hyaluronidase (ovine)', 'Insulin pork', 'Trastuzumab', 'Rituximab', 'Basiliximab', 'Muromonab', 'Digoxin Immune Fab (Ovine)', 'Daptomycin', 'Tositumomab', 'Pegvisomant', 'Botulinum toxin type A', 'Pancrelipase', 'Streptokinase', 'Alemtuzumab', 'Alglucerase', 'Capromab pendetide', 'Laronidase', 'Cyclosporine', 'Urofollitropin', 'Efalizumab', 'Choriogonadotropin alfa', 'Antithymocyte immunoglobulin (rabbit)', 'Filgrastim', 'Coagulation Factor IX (Recombinant)', 'Becaplermin', 'Agalsidase beta', 'Octreotide', 'Interferon alfa-2b', 'Abarelix', 'Oxytocin', 'Natalizumab', 'Enfuvirtide', 'Palivizumab', 'Bevacizumab', 'Cyanocobalamin', 'Ademetionine', 'Pyruvic acid', 'Biotin', 'L-Lysine', 'Aspartic acid', 'Ornithine', 'L-Glutamine', 'Adenosine phosphate', 'alpha-Linolenic acid', 'Methionine', 'Tyrosine', 'Calcitriol', 'Lutein', 'Cystine', 'Riboflavin', 'Glutamic acid', 'Glycine', 'Calcifediol', 'Creatine', 'Tryptophan', 'Cysteine', 'Thiamine', 'Ergocalciferol', 'Threonine', 'NADH', 'Folic acid', 'Icosapent', 'Valine', 'Vitamin A', 'Vitamin E', 'Pyridoxine', 'Lipoic acid', 'Cholecalciferol', 'Menadione', 'Adenine', 'Asparagine', 'Pravastatin', 'Fluvoxamine', 'Valsartan', 'Ramipril', 'Masoprocol', 'Flunisolide', 'Baclofen', 'Amphetamine', 'Pentagastrin', 'Nicotine', 'Cevimeline', 'Lorazepam', 'Esmolol', 'Bortezomib', 'Ethchlorvynol', 'Carbidopa', 'Phentermine', 'Indecainide', 'Tramadol', 'Vidarabine', 'Betaxolol', 'Troglitazone', 'Oseltamivir', 'Erythromycin', 'Hydroxocobalamin', 'Caffeine', 'Succinylcholine', 'Sildenafil', 'Dofetilide', 'Azithromycin', 'Ticlopidine', 'Trospium', 'Adapalene', 'Midodrine', 'Pantoprazole', 'Torasemide', 'Citalopram', 'Eletriptan', 'Bethanidine', 'Moxifloxacin', 'Oxyphenonium', 'Nelfinavir', 'Isoetharine', 'Glimepiride', 'Diflorasone', 'Indinavir', 'Gadodiamide', 'Guanadrel', 'Lovastatin', 'Enflurane', 'Cefotiam', 'Pregabalin', 'Temazepam', 'Aminosalicylic acid', 'Reboxetine', 'Milrinone', 'Pipobroman', 'Butabarbital', 'Nevirapine', 'Oxiconazole', 'Alclometasone', 'Butalbital', 'Cladribine', 'Ranolazine', 'Mesalazine', 'Benzatropine', 'Ziprasidone', 'Methysergide', 'Cabergoline', 'Idoxuridine', 'Dapsone', 'Terconazole', 'Phenytoin', 'Medrysone', 'Doxycycline', 'Diethylstilbestrol', 'Lymecycline', 'Clotrimazole', 'Calcium acetate', 'Sulfanilamide', 'Cycloserine', 'Anagrelide', 'Sulfisoxazole', 'Metoprolol', 'Crotamiton', 'Dicoumarol', 'Cefmenoxime', 'Ropinirole', 'Isradipine', 'Diatrizoate', 'Betazole', 'Topiramate', 'Olmesartan', 'Amsacrine', 'Theophylline', 'Argatroban', 'Liothyronine', 'Disopyramide', 'Lidocaine', 'Pamidronic acid', 'Acarbose', 'Venlafaxine', 'Conjugated estrogens', 'Travoprost', 'Amcinonide', 'Atomoxetine', 'Bleomycin', 'Chlorambuci ...

# %% [markdown]
# * 전처리 파트 =========================================================================================

# %%
# 소문자 통일
for key in documents.keys():
    documents[key] = documents[key].lower()

# %%
# 의약품 용어 통일 - 단어내 띄어쓰기 처리
# 결과에 크게 영향을 미치지 않을 것으로 예상하고 일단 SKip
# documents['Dornase alfa'] = documents['Dornase alfa'].replace('dornase alfa', 'dornase-alfa')

# %%
# 최초 1회 수행
# import nltk
# nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\paten\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Remove stopwords
from nltk.corpus import stopwords

# stopwords for english
listStopWords = stopwords.words('english')

# %%
# Tokenize (소문자로 통합)
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer  
from nltk.tokenize import TreebankWordTokenizer
# token_Dornasealf = word_tokenize(doc_Dornasealf)
# token_Lepirudin = word_tokenize(doc_Lepirudin)
# toekn_Ximelagatr = word_tokenize(doc_Ximelagatr)

# token_Dornasealf = WordPunctTokenizer().tokenize(doc_Dornasealf)
# token_Lepirudin = WordPunctTokenizer().tokenize(doc_Lepirudin)
# toekn_Ximelagatr = WordPunctTokenizer().tokenize(doc_Ximelagatr)


tokenizer = TreebankWordTokenizer()
token_doc = dict()
for key in documents.keys():
     token_doc[key] = tokenizer.tokenize(documents[key])

# token_Dornasealf = tokenizer.tokenize(doc_Dornasealf)
# token_Lepirudin = tokenizer.tokenize(doc_Lepirudin)
# toekn_Ximelagatr = tokenizer.tokenize(doc_Ximelagatr)

# %%
# token_doc =  [token_Dornasealf, token_Lepirudin, toekn_Ximelagatr]
#Stopwords 제거
token_wo_stopword = dict()
token_wo_stopword_list = [[word for word in token_doc[key] if not word in listStopWords] for key in token_doc.keys()]

drug_keys = token_doc.keys()
for i, key in enumerate(drug_keys):
    token_wo_stopword[key] = token_wo_stopword_list[i]

# %%
# Stemming(어간 추출)
from nltk.stem import PorterStemmer

pst = PorterStemmer()
token_stemmed = [[pst.stem(word) for word in token_wo_stopword[key]] for key in token_wo_stopword.keys()]

drug_keys = token_wo_stopword.keys()
token_result = dict()
for i, key in enumerate(drug_keys):
    token_result[key] = token_stemmed[i]

# %% [markdown]
# * 전처리 파트 =========================================================================================

# %%
from sklearn.cluster import KMeans
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

texts_and_tags = [
    (documents[key], [key]) for key in documents.keys()
]

TRAIN_documents = [TaggedDocument(words=text, tags=tags) for text, tags in texts_and_tags]

# %%
import time

start_time = time.time()

# Doc2Vec Training
model = Doc2Vec(TRAIN_documents, vector_size=5, window=3, epochs=40, min_count=0, workers=4)

print("running time: ", time.time() - start_time)
model.save('doc2vec_approved.model')
# Out:
# running time:  267.9928960800171

# %%
model.docvecs.most_similar('Lepirudin')
# Out:
# [('Eteplirsen', 0.9998279809951782),
#  ('Everolimus', 0.999125063419342),
#  ('Felis catus skin', 0.9987452626228333),
#  ('Icosapent ethyl', 0.9983333945274353),
#  ('Citicoline', 0.997514545917511),
#  ('Dactinomycin', 0.9970820546150208),
#  ('Levobunolol', 0.997021496295929),
#  ('Avelumab', 0.9969208240509033),
#  ('Netupitant', 0.9966803789138794),
#  ('Tobramycin', 0.9965447187423706)]

# %%
from scipy import spatial

dor_lepi = spatial.distance.cosine(model.docvecs['Dornase alfa'], model.docvecs['Lepirudin'])
dor_xime = spatial.distance.cosine(model.docvecs['Dornase alfa'], model.docvecs['Ximelagatran'])
lepi_xime = spatial.distance.cosine(model.docvecs['Lepirudin'], model.docvecs['Ximelagatran'])

print('Dornase_Lepirudin: ', dor_lepi)
print('Dornase_Ximelagatran: ', dor_xime)
print('Lepirudin_Ximelagatran: ', lepi_xime)
# Out:
# Dornase_Lepirudin:  0.03801298141479492
# Dornase_Ximelagatran:  1.1024495959281921
# Lepirudin_Ximelagatran:  0.9245570600032806

# %%
lepirudin_abstracts = documents['Lepirudin']

doc_vec = model.infer_vector(lepirudin_abstracts.lower().split(" "))

# word2vec
print("== word similarity")
print(model.wv.similar_by_vector(doc_vec))

# doc2vec
print("== document similarity")
doc_sim_list = model.docvecs.most_similar(positive=[doc_vec], topn=len(model.docvecs))
for doc_id, sim in doc_sim_list:
    print(f"Document {doc_id} - similarity: {sim:.5f}")

print("== complete")
# Out:
# == word similarity
# [('﹤', 0.8980783224105835), ('･', 0.8068166971206665), ('⟶', 0.8016313910484314), ('̂', 0.7972032427787781), ('ⅹ', 0.7858506441116333), ('Ρ', 0.7693530321121216), ('͘', 0.7562497854232788), ('ű', 0.7532801032066345), ('·', 0.7370501160621643), ('w', 0.7352657318115234)]
# == document similarity
# Document (2S)-2-(1H-indol-3-yl)pentanoic acid - similarity: 0.98621
# Document Benorilate - similarity: 0.98586
# Document Maclura tricuspidata whole - similarity: 0.98072
# Document (5Z)-12-CHLORO-13,15-DIHYDROXY-4,7,8,9-TETRAHYDRO-2-BENZOXACYCLOTRIDECINE-1,10(3H,11H)-DIONE - similarity: 0.98010
# Document N-((1R,2S)-2-(5-CHLORO-1H-INDOLE-2-CARBOXAMIDO)CYCLOHEXYL)-5-METHYL-4,5,6,7-TETRAHYDROTHIAZOLO[5,4-C]PYRIDINE-2-CARBOXAMIDE - similarity: 0.97496
# Document 5-(HEXAHYDRO-2-OXO-1H-THIENO[3,4-D]IMIDAZOL-6-YL)PENTANAL - similarity: 0.97391
# Document Caprylic alcohol - similarity: 0.97388
# Document 1-[2-DEOXYRIBOFURANOSYL]-2,4-DIFLUORO-5-METHYL-BENZENE-5'MONOPHOSPHATE - similarity: 0.96908
# Document 6-(3-BROMO-2-NAPHTHYL)-1,3,5-TRIAZINE-2,4-DIAMINE - similarity: 0.96676
# Document (1R,2R,3R,4S,5R)-4-(BENZYLAMINO)-5-(METHYLTHIO)CYCLOPENTANE-1,2,3-TRIOL - similarity: 0.96562
# Document Methylbenactyzium - similarity: 0.96447
# Document CPD 923 - similarity: 0.96394
# Document (1S)-1-CYCLOPROPYL-2-[(2S)-4-(2,5-DIFLUOROPHENYL)-2-PHENYL-2,5-DIHYDRO-1H-PYRROL-1-YL]-2-OXOETHANAMINE - similarity: 0.95858
# Document Fluorescin - similarity: 0.95790
# Document 7-amino-2-tert-butyl-4-(4-pyrimidin-2-ylpiperazin-1-yl)pyrido[2,3-d]pyrimidine-6-carboxamide - similarity: 0.95756
# Document 8-bromo-4-(2-chlorophenyl)-N-(2-hydroxyethyl)-6-methyl-1,3-dioxo-1,2,3,6-tetrahydropyrrolo[3,4-e]indole-7-carboxamide - similarity: 0.95546
# Document Neisseria meningitidis group w-135 capsular polysaccharide diphtheria toxoid conjugate antigen - similarity: 0.95022
# Document Emeramide - similarity: 0.94897
# Document PF-03635659 - similarity: 0.94892
# Document Merotocin - similarity: 0.94594
# Document 2-(4-ETHYLPIPERAZIN-1-YL)-4-(PHENYLAMINO)PYRAZOLO[1,5-A][1,3,5]TRIAZINE-8-CARBONITRILE - similarity: 0.94571
# Document phenyl ethenesulfonate - similarity: 0.94441
# Document Salix nigra pollen - similarity: 0.94421
# Document O-[2-(1,3-dioxo-1,3-dihydro-2H-isoindol-2-yl)ethyl] (4-chlorophenyl)thiocarbamate - similarity: 0.94356
# Document Phalaris minor pollen - similarity: 0.94293
# Document Amperozide - similarity: 0.94173
# Document Quercus agrifolia pollen - similarity: 0.94173
# Document Somatorelin - similarity: 0.94036
# Document 1-(PHENYLMETHYL)CYCLOPENTYL[(1S)-1-FORMYLPENTYL]CARBAMATE - similarity: 0.93950
# Document Ambrosia deltoidea pollen - similarity: 0.93949
# Document Pinus virginiana pollen - similarity: 0.93756
# Document Hexapropymate - similarity: 0.93738
# Document Streptococcus pneumoniae type 20 capsular polysaccharide antigen - similarity: 0.93601
# Document Streptococcus pneumoniae type 19f capsular polysaccharide diphtheria crm197 protein conjugate antigen - similarity: 0.93436
# Document Quercus virginiana pollen - similarity: 0.93401
# Document N-[(BENZYLOXY)CARBONYL]-L-CYSTEINYLGLYCINE - similarity: 0.93301
# Document 1-((2-HYDROXYETHOXY)METHYL)-5-(3-(BENZYLOXY)BENZYL)PYRIMIDINE-2,4(1H,3H)-DIONE - similarity: 0.93139
# Document 6-CHLORO-4-(CYCLOHEXYLOXY)-3-ISOPROPYLQUINOLIN-2(1H)-ONE - similarity: 0.93138
# Document Oxidronic acid - similarity: 0.92966
# Document Influenza A virus A/Texas/50/2012 X-223 (H3N2) antigen (propiolactone inactivated) - similarity: 0.92875
# Document Quinbolone - similarity: 0.92796
# Document 3-(1-Aminoethyl)Nonanedioic Acid - similarity: 0.92719
# Document 4-methyl-7,8-dihydro-5H-thiopyrano[4,3-d]pyrimidin-2-amine - similarity: 0.92691
# Document (5R)-2-[(2-Fluorophenyl)amino]-5-isopropyl-1,3-thiazol-4(5H)-one - similarity: 0.92629
# Document 4-[(1S,2R,5S)-4,4,8-TRIMETHYL-3-OXABICYCLO[3.3.1]NON-7-EN-2-YL]PHENOL - similarity: 0.92615
# Document N-Succinyl Phenylglycine - similarity: 0.92539
# Document Aureobasidium pullulans var. pullutans - similarity: 0.92491
# Document 1-Naphthylamine-5-sulfonic acid - similarity: 0.92458
# Document 2-(1,3-benzodioxol-5-yl)-5-[(3-fluoro-4-methoxybenzyl)sulfanyl]-1,3,4-oxadiazole - similarity: 0.92341
# Document Epomediol - similarity: 0.92274
# Document Ibuproxam - similarity: 0.92247
# Document 1-{[(1E)-(3-HYDROXY-2-METHYL-5-{[(TRIHYDROXY-LAMBDA^5^-PHOSPHANYL)OXY]METHYL}PYRIDIN-4-YL)METHYLIDENE]AMINO}UNDECAN-2-ONE - similarity: 0.92163
# Document Pleospora herbarum - similarity: 0.92059
# Document Hydrocortisone phosphate - similarity: 0.91959
# Document 1,1,1-TRIFLUORO-3-((N-ACETYL)-L-LEUCYLAMIDO)-4-PHENYL-BUTAN-2-ONE(N-ACETYL-L-LEUCYL-L-PHENYLALANYL TRIFLUOROMETHYL KETONE) - similarity: 0.91827
# Document 2-((3'-TERTBUTYL-4'-HYDROXYPHENYL)AZO)BENZOIC ACID - similarity: 0.91817
# Document Dimetacrine - similarity: 0.91722
# Document 2,6-dimethyl-4-[(E)-2-phenylethenyl]phenol - similarity: 0.91669
# Document (S)-5-(7-(4-(4-Ethyl-4,5-dihydro-2-oxazolyl)phenoxy)heptyl)-3-methylisoxazole - similarity: 0.91560
# Document N-ISOBUTYL-N-[4-METHOXYPHENYLSULFONYL]GLYCYL HYDROXAMIC ACID - similarity: 0.91551
# Document ZW-25 - similarity: 0.91514
# Document Corylus americana pollen - similarity: 0.91440
# Document Etafedrine - similarity: 0.91382
# Document AZD-7295 - similarity: 0.91362
# Document N-[4-(2-CHLOROPHENYL)-1,3-DIOXO-1,2,3,6-TETRAHYDROPYRROLO[3,4-C]CARBAZOL-9-YL]FORMAMIDE - similarity: 0.91336
# Document Stibophen - similarity: 0.91180
# Document Streptococcus pneumoniae type 3 capsular polysaccharide antigen - similarity: 0.91107
# Document (2R)-2-AMINO-3,3,3-TRIFLUORO-N-HYDROXY-2-{[(4-PHENOXYPHENYL)SULFONYL]METHYL}PROPANAMIDE - similarity: 0.91102
# Document Burixafor - similarity: 0.91038
# Document Tenonitrozole - similarity: 0.90974
# Document Mimopezil - similarity: 0.90954
# Document Aleplasinin - similarity: 0.90924
# Document (2R)-3-(phosphonooxy)propane-1,2-diyl diheptanoate - similarity: 0.90861
# Document 2-(1H-pyrrol-1-ylcarbonyl)benzene-1,3,5-triol - similarity: 0.90800
# Document ABL-001 - similarity: 0.90782
# Document N-Acetyl-L-Citrulline - similarity: 0.90688
# Document 4-[(5-methoxy-2-methylphenoxy)methyl]pyridine - similarity: 0.90667
# Document Ceforanide - similarity: 0.90666
# Document Ferrous aspartate - similarity: 0.90565
# Document {1-[(3-Hydroxy-Methyl-5-Phosphonooxy-Methyl-Pyridin-4-Ylmethyl)-Amino]-Ethyl}-Phosphonic Acid - similarity: 0.90411
# Document 3'-THIO-THYMIDINE-5'-PHOSPHATE - similarity: 0.90380
# Document Nalpha-(2-Naphthylsulfonylglycyl)-3-Amidino-D,L-Phenylalanine-Isopropylester - similarity: 0.90348
# Document Prostalene - similarity: 0.90276
# Document MK-0777 - similarity: 0.90267
# Document 2-(methylsulfanyl)-5-(thiophen-2-ylmethyl)-1H-imidazol-4-ol - similarity: 0.90252
# Document Azidocillin - similarity: 0.90163
# Document N-Carboxymethionine - similarity: 0.90161
# Document Influenza B virus B/Utah/9/2014 antigen (MDCK cell derived, propiolactone inactivated) - similarity: 0.90140
# Document MPI-674 - similarity: 0.90096
# Document Nagrestipen - similarity: 0.90065
# Document 3-DIPHENOL-6-NITRO-3H-BENZO[DE]ISOCHROMEN-1-ONE - similarity: 0.90018
# Document BI-K0376 - similarity: 0.90013
# Document Swertia japonica whole flowering - similarity: 0.89979
# Document Streptococcus pneumoniae type 19a capsular polysaccharide antigen - similarity: 0.89952
# Document (2S)-2-AMINO-1-(5-TERT-BUTYL-1,3,4-OXADIAZOL-2-YL)PROPAN-1-ONE - similarity: 0.89942
# Document LY-3039478 - similarity: 0.89751
# Document 4-({[(4-METHYLPIPERAZIN-1-YL)AMINO]CARBONOTHIOYL}AMINO)BENZENESULFONAMIDE - similarity: 0.89712
# Document (1R,3R)-5-[(2E)-3-{(1S,3R)-2,2,3-trimethyl-3-[6,6,6-trifluoro-5-hydroxy-5-(trifluoromethyl)hex-3-yn-1-yl]cyclopentyl}prop-2-en-1-ylidene]cyclohexane-1,3-diol - similarity: 0.89649
# Document Agatolimod - similarity: 0.89647
# Document Mucor circinelloides f. lusitanicus - similarity: 0.89554
# Document Coleneuramide - similarity: 0.89481
# Document Sp-722 - similarity: 0.89478
# Document Aceclidine - similarity: 0.89389
# Document (3R)-3-hydroxy-2,2-dimethyl-4-oxo-4-({3-oxo-3-[(2-sulfanylethyl)amino]propyl}amino)butyl 2,2-dimethylpropanoate - similarity: 0.89387
# Document RP01 - similarity: 0.89303
# Document Dexelvucitabine - similarity: 0.89300
# Document Ruplizumab - similarity: 0.89234
# Document Aluminum acetate - similarity: 0.89174
# Document (1r)-4-[(1e,3e,5e,7z,9e,11z,13e,15e)-17-Hydroxy-3,7,12,16-Tetramethylheptadeca-1,3,5,7,9,11,13,15-Octaen-1-Yl]-3,5,5-Trimethylcyclohex-3-En-1-Ol - similarity: 0.89168
# Document AZD-2066 - similarity: 0.89161
# Document Cirazoline - similarity: 0.89121
# Document Benzoctamine - similarity: 0.89114
# Document Seliforant - similarity: 0.89103
# Document Fraxinus americana pollen - similarity: 0.89063
# Document CYCLOHEXYL-NORSTATINE - similarity: 0.88787
# Document 2-(3'-Methoxyphenyl) Benzimidazole-4-Carboxamide - similarity: 0.88753
# Document N-cyclohexyltaurine - similarity: 0.88670
# Document N-[(4-HYDROXY-8-IODOISOQUINOLIN-3-YL)CARBONYL]GLYCINE - similarity: 0.88559
# Document Medifoxamine - similarity: 0.88452
# Document 2',5'-DIDEOXY-ADENOSINE 3'-MONOPHOSPHATE - similarity: 0.88244
# Document Bambermycins - similarity: 0.88200
# Document Corticorelin ovine triflutate - similarity: 0.88172
# Document 1-[1-(3-aminophenyl)-3-tert-butyl-1H-pyrazol-5-yl]-3-phenylurea - similarity: 0.88117
# Document 2-((3'-METHYL-4'-HYDROXYPHENYL)AZO)BENZOIC ACID - similarity: 0.88078
# Document Foreskin fibroblast (neonatal) - similarity: 0.88064
# Document Equine Botulinum Neurotoxin C Immune FAB2 - similarity: 0.87977
# Document R-95845 - similarity: 0.87971
# Document ethyl 2-amino-4-hydroxypyrimidine-5-carboxylate - similarity: 0.87920
# Document Alnus rubra pollen - similarity: 0.87899
# Document Fraxinus pennsylvanica pollen - similarity: 0.87851
# Document Chlorophetanol - similarity: 0.87837
# Document Periciazine - similarity: 0.87827
# Document (5R)-4-HYDROXY-3,5-DIMETHYL-5-[(1E,3E)-2-METHYLPENTA-1,3-DIENYL]THIOPHEN-2(5H)-ONE - similarity: 0.87757
# Document Bimiralisib - similarity: 0.87707
# Document GSK-424887 - similarity: 0.87604
# Document 3-{ISOPROPYL[(TRANS-4-METHYLCYCLOHEXYL)CARBONYL]AMINO}-5-PHENYLTHIOPHENE-2-CARBOXYLIC ACID - similarity: 0.87453
# Document Peg-100 stearate - similarity: 0.87395
# Document Epetraborole - similarity: 0.87312
# Document Carya ovata pollen - similarity: 0.87304
# Document Alizapride - similarity: 0.87251
# Document 2,2-Dichloro-1-methanesulfinyl-3-methyl-cyclopropanecarboxylic acid [1-(4-bromo-phenyl)-ethyl]-amide - similarity: 0.87239
# Document Vanillyl butyl ether - similarity: 0.87180
# Document 2-(2-Hydroxy-5-Methoxy-Phenyl)-1h-Benzoimidazole-5-Carboxamidine - similarity: 0.87135
# Document Oxidized coenzyme A - similarity: 0.87117
# Document Edetate sodium - similarity: 0.87090
# Document Rocacetrapib - similarity: 0.87058
# Document N-(4-carbamimidoylbenzyl)-1-(4-methylpentanoyl)-L-prolinamide - similarity: 0.87050
# Document (1R,2R,3S,4R,6S)-3,4,6-Trihydroxy-5-{[(S)-hydroxy(3-hydroxy-2-oxopropoxy)phosphoryl]oxy}-1,2-cyclohexanediyl bis[dihydrogen (phosphate)] - similarity: 0.87039
# Document Streptococcus pneumoniae type 4 capsular polysaccharide antigen - similarity: 0.86987
# Document Nicomorphine - similarity: 0.86974
# Document Doxefazepam - similarity: 0.86953
# Document Thienylfentanyl - similarity: 0.86942
# Document Z-160 - similarity: 0.86936
# Document Clonixin - similarity: 0.86890
# Document Pearl (hyriopsis cumingii) - similarity: 0.86873
# Document (3Z,6S)-6-Chloro-1-(2-{[(5-chloro-1-benzothiophen-3-yl)methyl]amino}ethyl)-3-({2-[(2R)-2-piperidinyl]ethyl}imino)-2-piperazinol - similarity: 0.86840
# Document [[(3R,4R,5S,6R)-3-(butanoylamino)-4,5-dihydroxy-6-(hydroxymethyl)oxan-2-ylidene]amino] N-phenylcarbamate - similarity: 0.86788
# Document 2-(4-HYDROXY-3-NITROPHENYL)ACETIC ACID - similarity: 0.86698
# Document Briakinumab - similarity: 0.86652
# Document Meriones unguiculatus skin - similarity: 0.86596
# Document 4-[3-(4-FLUOROPHENYL)-1H-PYRAZOL-4-YL]PYRIDINE - similarity: 0.86573
# Document Acacia baileyana pollen - similarity: 0.86567
# Document (3Z)-N,N-DIMETHYL-2-OXO-3-(4,5,6,7-TETRAHYDRO-1H-INDOL-2-YLMETHYLIDENE)-2,3-DIHYDRO-1H-INDOLE-5-SULFONAMIDE - similarity: 0.86557
# Document SGS-742 - similarity: 0.86535
# Document (3R,4S)-1-[(4-amino-5H-pyrrolo[3,2-d]pyrimidin-7-yl)methyl]-4-[(butylsulfanyl)methyl]pyrrolidin-3-ol - similarity: 0.86441
# Document Carbromal - similarity: 0.86433
# Document Dimethylaminopropionylphenothiazine - similarity: 0.86426
# Document (4Z)-6-bromo-4-({[4-(pyrrolidin-1-ylmethyl)phenyl]amino}methylidene)isoquinoline-1,3(2H,4H)-dione - similarity: 0.86380
# Document Alclofenac - similarity: 0.86375
# Document Serlopitant - similarity: 0.86303
# Document ginkgolide-J - similarity: 0.86215
# Document Iodide I-131 - similarity: 0.86193
# Document 1-[2-(S)-AMINO-3-BIPHENYL-4-YL-PROPIONYL]-PYRROLIDINE-2-(S)-CARBONITRILE - similarity: 0.86174
# Document Methoserpidine - similarity: 0.86142
# Document Influenza A virus A/Indiana/08/2018 (H3N2) antigen (MDCK cell derived, propiolactone inactivated) - similarity: 0.86123
# Document Sutilain - similarity: 0.86092
# Document 4-tert-butyl-N'-[(1E)-(3,5-dibromo-2,4-dihydroxyphenyl)methylidene]benzohydrazide - similarity: 0.86016
# Document (R)-1-(4-(4-(Hydroxymethyl)-1,3,2-dioxaborolan-2-YL)phenyl)guanidine - similarity: 0.85979
# Document (3R)-3-[(1,2,3,4-tetrahydroisoquinolin-7-yloxy)methyl]-2,3-dihydrothieno[2,3-f][1,4]oxazepin-5-amine - similarity: 0.85918
# Document 2-(Thiomethylene)-4-Methylpentanoic Acid - similarity: 0.85760
# Document BENZYL 6-BENZYL-5,7-DIOXO-6,7-DIHYDRO-5H-[1,3]THIAZOLO[3,2-C]PYRIMIDINE-2-CARBOXYLATE - similarity: 0.85742
# Document Bamet-UD2 - similarity: 0.85714
# Document Fluocortin - similarity: 0.85569
# Document 3-(2,6-difluorophenyl)-2-(methylthio)quinazolin-4(3H)-one - similarity: 0.85560
# Document Beta vulgaris pollen - similarity: 0.85542
# Document Proquazone - similarity: 0.85455
# Document 4-[(4-Imidazo[1,2-a]Pyridin-3-Ylpyrimidin-2-Yl)Amino]Benzenesulfonamide - similarity: 0.85324
# Document Inarigivir soproxil - similarity: 0.85216
# Document 3-{[(4-methylphenyl)sulfonyl]amino}propyl pyridin-4-ylcarbamate - similarity: 0.85215
# Document Cidoxepin - similarity: 0.85190
# Document Helianthus annuus pollen - similarity: 0.85093
# Document Mardepodect - similarity: 0.85066
# Document (4R)-4-(3-butoxy-4-methoxybenzyl)imidazolidin-2-one - similarity: 0.85053
# Document VSF-173 - similarity: 0.85042
# Document (2S)-1-[4-({4-[(2,5-Dichlorophenyl)amino]-2-pyrimidinyl}amino)phenoxy]-3-(dimethylamino)-2-propanol - similarity: 0.84973
# Document Aranidipine - similarity: 0.84871
# Document (3R,4S)-1-[(4-amino-5H-pyrrolo[3,2-d]pyrimidin-7-yl)methyl]-4-[(benzylsulfanyl)methyl]pyrrolidin-3-ol - similarity: 0.84861
# Document 5-(5-CHLORO-2,4-DIHYDROXYPHENYL)-N-ETHYL-4-(4-METHOXYPHENYL)-1H-PYRAZOLE-3-CARBOXAMIDE - similarity: 0.84855
# Document Tedatioxetine - similarity: 0.84848
# Document Bambusa vulgaris top - similarity: 0.84844
# Document (3,3-dimethylpiperidin-1-yl)(6-(3-fluoro-4-methylphenyl)pyridin-2-yl)methanone - similarity: 0.84803
# Document Mitazalimab - similarity: 0.84772
# Document Methyl undecenoyl leucinate - similarity: 0.84749
# Document Betula pendula tar oil - similarity: 0.84748
# Document AZD-1236 - similarity: 0.84732
# Document Ecamsule - similarity: 0.84686
# Document N-oxo-2-[(4-phenylphenyl)sulfonylamino]ethanamide - similarity: 0.84541
# Document Falnidamol - similarity: 0.84532
# Document 3-fluoro-N-[3-(1H-tetrazol-5-yl)phenyl]benzamide - similarity: 0.84518
# Document Mirfentanil - similarity: 0.84514
# Document Diphenadione - similarity: 0.84506
# Document MK-1454 - similarity: 0.84474
# Document Fluprednidene - similarity: 0.84455
# Document Decyl formate - similarity: 0.84414
# Document L-aminocarnityl-succinyl-leucyl-argininal-diethylacetal - similarity: 0.84400
# Document CP-547632 - similarity: 0.84351
# Document N'-(6-aminopyridin-3-yl)-N-(2-cyclopentylethyl)-4-methyl-benzene-1,3-dicarboxamide - similarity: 0.84343
# Document Interferon alfa-2c - similarity: 0.84321
# Document Melaleuca quinquenervia pollen - similarity: 0.84319
# Document GW-870086 - similarity: 0.84309
# Document Etrasimod - similarity: 0.84288
# Document PMP-hydroxyisoxazole, pyridoxamine-5-phosphate-hydroxyisoxazole - similarity: 0.84249
# Document AER001 - similarity: 0.84220
# Document Dexamethasone isonicotinate - similarity: 0.84181
# Document LX-2931 - similarity: 0.84107
# Document Pegpleranib - similarity: 0.83981
# Document N~4~-methyl-N~4~-(3-methyl-1H-indazol-6-yl)-N~2~-(3,4,5-trimethoxyphenyl)pyrimidine-2,4-diamine - similarity: 0.83975
# Document [2(Formyl-Hydroxy-Amino)-Ethyl]-Phosphonic Acid - similarity: 0.83974
# Document 1-(2-{[(6-amino-2-methylpyridin-3-yl)methyl]amino}ethyl)-6-chloro-3-[(2,2-difluoro-2-pyridin-2-ylethyl)amino]-1,4-dihydropyrazin-2-ol - similarity: 0.83949
# Document Elismetrep - similarity: 0.83931
# Document Streptococcus pneumoniae type 5 capsular polysaccharide antigen - similarity: 0.83912
# Document (S)-2-METHYL-1-[(4-METHYL-5-ISOQUINOLINE)SULFONYL]-HOMOPIPERAZINE - similarity: 0.83907
# Document 6-methyl-5-[3-methyl-3-(3,4,5-trimethoxyphenyl)but-1-yn-1-yl]pyrimidine-2,4-diamine - similarity: 0.83883
# Document Bacillus calmette-guerin substrain connaught live antigen - similarity: 0.83834
# Document 6-phenyl-4(R)-(7-phenyl-heptanoylamino)-hexanoic acid - similarity: 0.83833
# Document Larix occidentalis pollen - similarity: 0.83767
# Document Cefaloridine - similarity: 0.83767
# Document 4-{[5-(CYCLOHEXYLAMINO)[1,2,4]TRIAZOLO[1,5-A]PYRIMIDIN-7-YL]AMINO}BENZENESULFONAMIDE - similarity: 0.83733
# Document (2S,3S)-4-cyclopropyl-3-{(3R,5R)-3-[2-fluoro-4-(methylsulfonyl)phenyl]-1,2,4-oxadiazolidin-5-yl}-1-[(3S)-3-fluoropyrrolidin-1-yl]-1-oxobutan-2-amine - similarity: 0.83692
# Document Diridavumab - similarity: 0.83691
# Document (2S,3R,4S,5S)-3,4-Dihydroxy-2-[(methylsulfanyl)methyl]-5-(4-oxo-4,5-dihydro-1H-pyrrolo[3,2-d]pyrimidin-7-yl)pyrrolidinium - similarity: 0.83682
# Document Artemisia californica pollen - similarity: 0.83642
# Document Cetrelimab - similarity: 0.83628
# Document [4-({4-[(5-cyclopropyl-1H-pyrazol-3-yl)amino]-6-(methylamino)pyrimidin-2-yl}amino)phenyl]acetonitrile - similarity: 0.83624
# Document Carbomer homopolymer type C - similarity: 0.83622
# Document 4-{2,4-Bis[(3-Nitrobenzoyl)Amino]Phenoxy}Phthalic Acid - similarity: 0.83619
# Document Urea C-14 - similarity: 0.83583
# Document Rilematovir - similarity: 0.83582
# Document Influenza A virus A/Victoria/361/2011 (H3N2) live (attenuated) antigen - similarity: 0.83581
# Document Ibopamine - similarity: 0.83565
# Document ALPHA-(2,6-DICHLOROPHENYL)-ALPHA-(2-ACETYL-5-METHYLANILINO)ACETAMIDE - similarity: 0.83561
# Document N-{3-[(E)-(tert-butoxyimino)methyl]-4-chlorophenyl}-2-methylfuran-3-carbimidothioic acid - similarity: 0.83549
# Document 2-{2-[(3,5-dimethylphenyl)amino]pyrimidin-4-yl}-N-[(1S)-2-hydroxy-1-methylethyl]-4-methyl-1,3-thiazole-5-carboxamide - similarity: 0.83544
# Document Streptococcus pneumoniae type 19f capsular polysaccharide antigen - similarity: 0.83526
# Document 1-DECYL-3-TRIFLUORO ETHYL-SN-GLYCERO-2-PHOSPHOMETHANOL - similarity: 0.83490
# Document DG031 - similarity: 0.83454
# Document Tyropanoic acid - similarity: 0.83430
# Document Ferrous cysteine glycinate - similarity: 0.83428
# Document VLTS-589 - similarity: 0.83380
# Document Bis(5-Amidino-2-Benzimidazolyl)Methane Ketone Hydrate - similarity: 0.83370
# Document N-(2-AMINOETHYL)-P-CHLOROBENZAMIDE - similarity: 0.83365
# Document 5-(3-HYDROXYPHENYL)ISOTHIAZOL-3(2H)-ONE 1,1-DIOXIDE - similarity: 0.83336
# Document 3-({[(1Z)-(2-methoxyphenyl)methylidene]amino}oxy)propanoic acid - similarity: 0.83336
# Document Demoxytocin - similarity: 0.83310
# Document (4-fluorophenyl)(pyridin-4-yl)methanone - similarity: 0.83291
# Document (4-ETHYLPHENYL)SULFAMIC ACID - similarity: 0.83247
# Document Chrysonilia sitophila - similarity: 0.83244
# Document Penicillium glaucum - similarity: 0.83222
# Document Pancrelipase protease - similarity: 0.83130
# Document Aurotioprol - similarity: 0.83064
# Document 5-[(4-AMINOCYCLOHEXYL)AMINO]-7-(PROPAN-2-YLAMINO)PYRAZOLO[1,5-A]PYRIMIDINE-3-CARBONITRILE - similarity: 0.83060
# Document Demecarium - similarity: 0.83008
# Document N,N'-DIPHENYLPYRAZOLO[1,5-A][1,3,5]TRIAZINE-2,4-DIAMINE - similarity: 0.82996
# Document Ponazuril - similarity: 0.82911
# Document PF-00489791 - similarity: 0.82901
# Document Estradiol hemisuccinate - similarity: 0.82892
# Document (3R,4R)-1-{6-[3-(METHYLSULFONYL)PHENYL]PYRIMIDIN-4-YL}-4-(2,4,5-TRIFLUOROPHENYL)PIPERIDIN-3-AMINE - similarity: 0.82866
# Document (1-Methyl-1h-Imidazol-2-Yl)-(3-Methyl-4-{3-[(Pyridin-3-Ylmethyl)-Amino]-Propoxy}-Benzofuran-2-Yl)-Methanone - similarity: 0.82858
# Document Reversin 121 - similarity: 0.82848
# Document Dusigitumab - similarity: 0.82834
# Document Tymazoline - similarity: 0.82825
# Document N-[4-(benzyloxy)phenyl]glycinamide - similarity: 0.82825
# Document Mitoglitazone - similarity: 0.82824
# Document Methotrimeprazine - similarity: 0.82818
# Document [4-(1,3,2-Dioxaborolan-2-Yloxy)Methyl]Benzamidine - similarity: 0.82814
# Document N-{5-[4-(4-METHYLPIPERAZIN-1-YL)PHENYL]-1H-PYRROLO[2,3-B]PYRIDIN-3-YL}NICOTINAMIDE - similarity: 0.82797
# Document VTP-194204 - similarity: 0.82781
# Document Penthienate - similarity: 0.82769
# Document 2-[4-(2H-1,4-BENZOTHIAZINE-3-YL)-PIPERAZINE-1-LY]-1,3-THIAZOLE-4-CARBOXYLIC ACID ETHYLESTER - similarity: 0.82766
# Document Holcus lanatus pollen - similarity: 0.82763
# Document 2-{5-[3-(7-PROPYL-3-TRIFLUOROMETHYLBENZO[D]ISOXAZOL-6-YLOXY)PROPOXY]INDOL-1-YL}ETHANOIC ACID - similarity: 0.82754
# Document CGI-1842 - similarity: 0.82707
# Document Phanquinone - similarity: 0.82703
# Document (2-BROMOETHYL)(2-'FORMYL-4'-AMINOPHENYL) ACETATE - similarity: 0.82661
# Document OC-459 - similarity: 0.82641
# Document Deoxyepinephrine - similarity: 0.82539
# Document Sodium phosphate, monobasic - similarity: 0.82532
# Document ALPHA-HYDROXYFARNESYLPHOSPHONIC ACID - similarity: 0.82507
# Document SC-236 - similarity: 0.82501
# Document DL-dimyristoylphosphatidylglycerol - similarity: 0.82500
# Document Influenza A virus A/Victoria/210/2009 X-187 (H3N2) antigen (propiolactone inactivated) - similarity: 0.82484
# Document Coblopasvir - similarity: 0.82473
# Document [N-(3-dibenzylcarbamoyl-oxiranecarbonyl)-hydrazino]-acetic acid - similarity: 0.82469
# Document 4-[[(1E)-2-(4-CHLOROPHENYL)ETHENYL]SULFONYL]-1-[[1-(4-PYRIDINYL)-4-PIPERIDINYL]METHYL]PIPERAZINONE - similarity: 0.82454
# Document (1S)-1,2,3,4-TETRAHYDRO-BENZO[C]PHENANTHRENE-2,3,4-TRIOL - similarity: 0.82446
# Document N-(4-chlorobenzyl)-N-methylbenzene-1,4-disulfonamide - similarity: 0.82414
# Document Clopenthixol - similarity: 0.82410
# Document Glepaglutide - similarity: 0.82372
# Document Procyclidine - similarity: 0.82340
# Document Lapyrium - similarity: 0.82334
# Document Aniracetam - similarity: 0.82330
# Document Equine Botulinum Neurotoxin A Immune FAB2 - similarity: 0.82325
# Document Emfilermin - similarity: 0.82324
# Document Influenza A virus A/Switzerland/9715293/2013 (H3N2) live (attenuated) antigen - similarity: 0.82317
# Document (17beta)-17-(cyanomethyl)-2-methoxyestra-1(10),2,4-trien-3-yl sulfamate - similarity: 0.82279
# Document SRP 299 - similarity: 0.82266
# Document Lucatumumab - similarity: 0.82259
# Document Triaziquone - similarity: 0.82211
# Document Niaprazine - similarity: 0.82207
# Document Navicixizumab - similarity: 0.82183
# Document 2-AMINO-6-(3,5-DIMETHYLPHENYL)SULFONYLBENZONITRILE - similarity: 0.82178
# Document 2-(3-NITROPHENYL)ACETIC ACID - similarity: 0.82166
# Document Blosozumab - similarity: 0.82056
# Document Quercus muehlenbergii pollen - similarity: 0.82051
# Document Streptococcus pneumoniae type 9n capsular polysaccharide antigen - similarity: 0.82007
# Document Quercetin-3'-O-phosphate - similarity: 0.81988
# Document AVAC - similarity: 0.81972
# Document Bentoquatam - similarity: 0.81967
# Document HOMOPHENYLALANINYLMETHANE - similarity: 0.81947
# Document DLO6002 - similarity: 0.81903
# Document Influenza B virus B/Hubei-Wujiagang/158/2009 BX-39 hemagglutinin antigen (propiolactone inactivated) - similarity: 0.81891
# Document WNT-974 - similarity: 0.81890
# Document 4-{4-[(5-hydroxy-2-methylphenyl)amino]quinolin-7-yl}-1,3-thiazole-2-carbaldehyde - similarity: 0.81860
# Document 3-{[(1R)-1-phenylethyl]amino}-4-(pyridin-4-ylamino)cyclobut-3-ene-1,2-dione - similarity: 0.81825
# Document R-428 - similarity: 0.81797
# Document Ditazole - similarity: 0.81790
# Document CGS-27023 - similarity: 0.81747
# Document Quinonoid 7,8-Tetrahydrobiopterin - similarity: 0.81724
# Document Avoralstat - similarity: 0.81696
# Document Retaspimycin - similarity: 0.81639
# Document Funapide - similarity: 0.81622
# Document Calcium glubionate anhydrous - similarity: 0.81607
# Document Futuximab - similarity: 0.81589
# Document 3-{[4-(but-2-yn-1-yloxy)phenyl]sulfonyl}propane-1-thiol - similarity: 0.81581
# Document Norgestrienone - similarity: 0.81571
# Document Quercus kelloggii pollen - similarity: 0.81563
# Document ILS-920 - similarity: 0.81549
# Document TAFA-93 - similarity: 0.81510
# Document Influenza A virus A/California/7/2009 X-181 (H1N1) antigen (UV, formaldehyde inactivated) - similarity: 0.81380
# Document Brotizolam - similarity: 0.81356
# Document 4-{5-[(Z)-(2-IMINO-4-OXO-1,3-THIAZOLIDIN-5-YLIDENE)METHYL]FURAN-2-YL}-2-(TRIFLUOROMETHYL)BENZENESULFONAMIDE - similarity: 0.81339
# Document Nicofetamide - similarity: 0.81299
# Document 7-(5-DEOXY-BETA-D-RIBOFURANOSYL)-5-IODO-7H-PYRROLO[2,3-D]PYRIMIDIN-4-AMINE - similarity: 0.81292
# Document K-134 - similarity: 0.81277
# Document Bibenzonium - similarity: 0.81272
# Document N-[4-(AMINOSULFONYL)PHENYL]-2-MERCAPTOBENZAMIDE - similarity: 0.81245
# Document 2',5'-Dideoxyuridine - similarity: 0.81228
# Document Streptococcus pneumoniae type 14 capsular polysaccharide diphtheria crm197 protein conjugate antigen - similarity: 0.81218
# Document Bumadizone - similarity: 0.81218
# Document Influenza A virus A/California/7/2009 (H1N1) recombinant hemagglutinin antigen - similarity: 0.81215
# Document JE-2147 - similarity: 0.81213
# Document Haloxon - similarity: 0.81183
# Document 6-(N-Phenylcarbamyl)-2-Naphthalenecarboxamidine - similarity: 0.81177
# Document (METHYLPYRIDAZINE PIPERIDINE BUTYLOXYPHENYL)ETHYLACETATE - similarity: 0.81171
# Document Salix lasiolepis pollen - similarity: 0.81088
# Document N,N,N-Trimethyl-2-(phosphonooxy)ethanaminium - similarity: 0.81057
# Document Ipamorelin - similarity: 0.80980
# Document AC-430 - similarity: 0.80973
# Document O-(((1R)-((N-(PHENYL-METHOXY-CARBONYL)-ALANYL)-AMINO)METHYL)HYDROXYPHOSPHINYL)3-L-PHENYLLACTATE - similarity: 0.80961
# Document Thonzylamine - similarity: 0.80957
# Document Trimegestone - similarity: 0.80955
# Document Pleospora tarda - similarity: 0.80955
# Document 3-(1H-indol-3-yl)-4-(1-{2-[(2S)-1-methylpyrrolidinyl]ethyl}-1H-indol-3-yl)-1H-pyrrole-2,5-dione - similarity: 0.80953
# Document Ethyl Isocyanide - similarity: 0.80923
# Document Polysorbate 20 - similarity: 0.80891
# Document Casopitant - similarity: 0.80891
# Document THIENO[3,2-B]PYRIDINE-2-SULFONIC ACID [1-(1-AMINO-ISOQUINOLIN-7-YLMETHYL)-2-OXO-PYRROLDIN-3-YL]-AMIDE - similarity: 0.80872
# Document Propyliodone - similarity: 0.80854
# Document Venison - similarity: 0.80839
# Document Metahexamide - similarity: 0.80837
# Document Black-eyed pea - similarity: 0.80807
# Document Streptococcus pneumoniae type 15b capsular polysaccharide antigen - similarity: 0.80800
# Document ATU-027 - similarity: 0.80796
# Document 4-[4-(4-Fluorophenyl)-2-[4-[(R)-methylsulfinyl]phenyl]-1H-imidazol-5-yl]pyridine - similarity: 0.80763
# Document Candoxatrilat - similarity: 0.80750
# Document N-[3-(Dimethylamino)Propyl]-2-({[4-({[4-(Formylamino)-1-Methyl-1h-Pyrrol-2-Yl]Carbonyl}Amino)-1-Methyl-1h-Pyrrol-2-Yl]Carbonyl}Amino)-5-Isopropyl-1,3-Thiazole-4-Carboxamide - similarity: 0.80701
# Document 3-(heptyloxy)benzoic acid - similarity: 0.80673
# Document Jaspisamide A - similarity: 0.80649
# Document Benzododecinium - similarity: 0.80561
# Document Idarucizumab - similarity: 0.80518
# Document 3,20-Pregnanedione - similarity: 0.80504
# Document Fosamprenavir - similarity: 0.80491
# Document Acetarsol - similarity: 0.80473
# Document N-[2-Hydroxy-2-(8-Isopropyl-6,9-Dioxo-2-Oxa-7,10-Diaza-Bicyclo[11.2.2]Heptadeca-1(16),13(17),14-Trien-11-Yl)-Ethyl]-N-(3-Methyl-Butyl)-Benzenesulfonamide,Inhibitor 3 - similarity: 0.80436
# Document 4-[3-(1,4-diazepan-1-ylcarbonyl)-4-fluorobenzyl]phthalazin-1(2H)-one - similarity: 0.80428
# Document 1-ethyl-N-(phenylmethyl)-4-(tetrahydro-2H-pyran-4-ylamino)-1H-pyrazolo[3,4-b]pyridine-5-carboxamide - similarity: 0.80420
# Document Tenoxicam - similarity: 0.80398
# Document Albusomatropin - similarity: 0.80324
# Document Canakinumab - similarity: 0.80310
# Document (1R)-1-(2-thienylacetylamino)-1-phenylmethylboronic acid - similarity: 0.80305
# Document Pinazepam - similarity: 0.80291
# Document 9-amino-n-[3-(dimethylamino)propyl]acridine-4-carboxamide - similarity: 0.80274
# Document 1-(1-HYDROXY-2,2,6,6-TETRAMETHYLPIPERIDIN-4-YL)PYRROLIDINE-2,5-DIONE - similarity: 0.80270
# Document 4-chloro-6-{5-[(2-morpholin-4-ylethyl)amino]-1,2-benzisoxazol-3-yl}benzene-1,3-diol - similarity: 0.80258
# Document Bevantolol - similarity: 0.80198
# Document Mirikizumab - similarity: 0.80191
# Document 3-chloro-5-[2-chloro-5-(1H-indazol-3-ylmethoxy)phenoxy]benzonitrile - similarity: 0.80128
# Document Oblimersen - similarity: 0.80112
# Document Populus alba pollen - similarity: 0.80097
# Document N-Heptylformamide - similarity: 0.80091
# Document Evolocumab - similarity: 0.80089
# Document Drisapersen - similarity: 0.80085
# Document Human papillomavirus type 33 L1 capsid protein antigen - similarity: 0.80077
# Document GSK-2330672 - similarity: 0.80069
# Document Calcium sulfide - similarity: 0.80066
# Document 8,9,10-trihydroxy-7-hydroxymethyl-3-methyl-6-oxa-1,3-diaza-spiro[4.5]decane-2,4-dione - similarity: 0.80032
# Document 1-biphenyl-2-ylmethanamine - similarity: 0.80022
# Document Fagus grandifolia pollen - similarity: 0.80010
# Document Influenza A virus A/California/7/2009 X-179A (H1N1) antigen (UV, formaldehyde inactivated) - similarity: 0.80001
# Document 4-(2-HYDROXY-4-FLUOROPHENYLTHIO)-BUTYLPHOSPHONIC ACID - similarity: 0.79998
# Document 5'-S-ethyl-5'-thioadenosine - similarity: 0.79954
# Document lambda-bis(2,2'-bipyridine)-(5-methyl-2-2'-bipyridine)-C9-adamantane ruthenium (II) - similarity: 0.79939
# Document (3R,5Z,8S,9S,11E)-8,9,16-TRIHYDROXY-14-METHOXY-3-METHYL-3,4,9,10-TETRAHYDRO-1H-2-BENZOXACYCLOTETRADECINE-1,7(8H)-DIONE - similarity: 0.79909
# Document Gemeprost - similarity: 0.79904
# Document Phoenix dactylifera pollen - similarity: 0.79897
# Document Brilaroxazine - similarity: 0.79825
# Document Ifetroban - similarity: 0.79816
# Document Vantictumab - similarity: 0.79813
# Document Tradipitant - similarity: 0.79805
# Document 3,5-diiodothyropropionic acid - similarity: 0.79764
# Document Fosfructose - similarity: 0.79732
# Document (3R)-3-HYDROXYDODECANOIC ACID - similarity: 0.79727
# Document 5-bromo-N-(3-chloro-2-(4-(prop-2-ynyl)piperazin-1-yl)phenyl)furan-2-carboxamide - similarity: 0.79717
# Document Interferon alfa-n3 - similarity: 0.79694
# Document Sulfaisodimidine - similarity: 0.79692
# Document Juniperus californica pollen - similarity: 0.79659
# Document Rhus Glabra Pollen - similarity: 0.79639
# Document 5-(4-FLUOROPHENYL)-3-{[(4-METHYLPHENYL)SULFONYL]AMINO}THIOPHENE-2-CARBOXYLIC ACID - similarity: 0.79616
# Document Radavirsen - similarity: 0.79602
# Document Ketorolac - similarity: 0.79595
# Document Upadacitinib - similarity: 0.79582
# Document Hydroxyaminovaline - similarity: 0.79564
# Document N-{(1S,2R)-1-BENZYL-3-[(CYCLOPROPYLMETHYL)(2-FURYLSULFONYL)AMINO]-2-HYDROXYPROPYL}-N'-METHYLSUCCINAMIDE - similarity: 0.79557
# Document PARA-NITROPHENYL 1-THIO-BETA-D-GLUCOPYRANOSIDE - similarity: 0.79519
# Document Sotagliflozin - similarity: 0.79497
# Document N-(2-AMINOETHYL)-2-{3-CHLORO-4-[(4-ISOPROPYLBENZYL)OXY]PHENYL} ACETAMIDE - similarity: 0.79463
# Document 1-(2-HYDROXYETHYLOXYMETHYL)-6-PHENYL THIOTHYMINE - similarity: 0.79457
# Document Golodirsen - similarity: 0.79385
# Document (2S)-2-(1H-indol-3-yl)hexanoic acid - similarity: 0.79373
# Document 4-(1,3-BENZODIOXOL-5-YLOXY)-2-[4-(1H-IMIDAZOL-1-YL)PHENOXY]PYRIMIDINE - similarity: 0.79365
# Document (3S)-1-(2-hydroxyphenyl)-5-oxopyrrolidine-3-carboxylic acid - similarity: 0.79341
# Document Metipranolol - similarity: 0.79324
# Document Trefentanil - similarity: 0.79315
# Document Pyrrobutamine - similarity: 0.79299
# Document Taprenepag - similarity: 0.79297
# Document Tezepelumab - similarity: 0.79270
# Document 2-[4-({[(3,5-DICHLOROPHENYL)AMINO]CARBONYL}AMINO)PHENOXY]-2-METHYLPROPANOIC ACID - similarity: 0.79252
# Document D-phenylalanyl-N-{4-[amino(iminio)methyl]benzyl}-L-prolinamide - similarity: 0.79227
# Document Frovatriptan - similarity: 0.79217
# Document N~2~-[(BENZYLOXY)CARBONYL]-N-[(1S,2S)-2-HYDROXY-1-(4-HYDROXYBENZYL)PROPYL]-L-LEUCINAMIDE - similarity: 0.79202
# Document Methoxyphenamine - similarity: 0.79150
# Document 4-Carbamoyl-4-{[6-(Difluoro-Phosphono-Methyl)-Naphthalene-2-Carbonyl]-Amino}-Butyric Acid - similarity: 0.79145
# Document Beinaglutide - similarity: 0.79134
# Document Setrusumab - similarity: 0.79103
# Document Mebanazine - similarity: 0.79103
# Document Rimazolium - similarity: 0.79087
# Document Eniluracil - similarity: 0.79081
# Document Atecegatran metoxil - similarity: 0.79075
# Document Guaiazulen - similarity: 0.79051
# Document (S)-oct-1-en-3-ol - similarity: 0.79018
# Document Vinbarbital - similarity: 0.79015
# Document Evinacumab - similarity: 0.78999
# Document (S)-N-(4-carbamimidoylbenzyl)-1-(3-cyclohexylpropanoyl)pyrrolidine-2-carboxamide - similarity: 0.78985
# Document Triazolam - similarity: 0.78896
# Document Trigonellamide - similarity: 0.78836
# Document RPI-78M - similarity: 0.78831
# Document Delavirdine - similarity: 0.78829
# Document Guselkumab - similarity: 0.78824
# Document 8-chlorotheophylline - similarity: 0.78807
# Document Rezatomidine - similarity: 0.78767
# Document 5-Chloro-N-{(3S)-1-[(2S)-1-(4-morpholinyl)-1-oxo-2-propanyl]-2-oxo-3-pyrrolidinyl}-1H-indole-2-sulfonamide - similarity: 0.78763
# Document Celtis occidentalis pollen - similarity: 0.78736
# Document Podophyllin - similarity: 0.78732
# Document Dodecyl-Alpha-D-Maltoside - similarity: 0.78716
# Document N-[(1S)-1-(aminocarbonyl)-4-(ethanimidoylamino)butyl]benzamide - similarity: 0.78710
# Document Aluminum zirconium trichlorohydrex gly - similarity: 0.78705
# Document PSN9301 - similarity: 0.78686
# Document Lenzilumab - similarity: 0.78682
# Document (5Z)-3-(4-CHLOROPHENYL)-4-HYDROXY-5-(1-NAPHTHYLMETHYLENE)FURAN-2(5H)-ONE - similarity: 0.78682
# Document Abarelix - similarity: 0.78676
# Document 2-(2-chloropyridin-4-yl)-4-methyl-1H-isoindole-1,3(2H)-dione - similarity: 0.78675
# Document Fenprostalene - similarity: 0.78661
# Document Disperse Blue 106 - similarity: 0.78660
# Document CE-326597 - similarity: 0.78651
# Document Ancestim - similarity: 0.78641
# Document Trichophyton mentagrophytes - similarity: 0.78639
# Document (2E,4E)-11-METHOXY-3,7,11-TRIMETHYLDODECA-2,4-DIENOIC ACID - similarity: 0.78615
# Document Neisseria meningitidis group y capsular oligosaccharide diphtheria crm197 protein conjugate antigen - similarity: 0.78611
# Document Clobetasone - similarity: 0.78605
# Document Gantacurium - similarity: 0.78582
# Document Propicillin - similarity: 0.78565
# Document Stavudine triphosphate - similarity: 0.78560
# Document Technetium Tc-99m disofenin - similarity: 0.78524
# Document Enokizumab - similarity: 0.78483
# Document N-(4-ACETYLPHENYL)-5-(5-CHLORO-2,4-DIHYDROXYPHENYL)-1H-PYRAZOLE-4-CARBOXAMIDE - similarity: 0.78480
# Document 2-(6-CHLORO-3-{[2,2-DIFLUORO-2-(1-OXIDO-2-PYRIDINYL)ETHYL]AMINO}-2-OXO-1(2H)-PYRAZINYL)-N-[(2-FLUOROPHENYL)METHYL]ACETAMIDE - similarity: 0.78474
# Document MVA3000 - similarity: 0.78468
# Document N-(4-{[(3S)-3-(dimethylamino)pyrrolidin-1-yl]carbonyl}phenyl)-5-fluoro-4-[2-methyl-1-(1-methylethyl)-1H-imidazol-5-yl]pyrimidin-2-amine - similarity: 0.78461
# Document 2-(3-METHYLPHENYL)-1H-INDOLE-5-CARBOXIMIDAMIDE - similarity: 0.78461
# Document GSK-364735 - similarity: 0.78458
# Document (2R,4S)-2-[(1R)-1-{[(2Z)-2-(2-Amino-1,3-thiazol-4-yl)-2-(methoxyimino)acetyl]amino}-2-oxoethyl]-5,5-dimethyl-1,3-thiazolidine-4-carboxylic acid - similarity: 0.78445
# Document 4-Hydroxy-3-Methyl Butyl Diphosphate - similarity: 0.78445
# Document 2-(4-HYDROXY-5-PHENYL-1H-PYRAZOL-3-YL)-1H-BENZOIMIDAZOLE-5-CARBOXAMIDINE - similarity: 0.78435
# Document 6,11-DIHYDRO-11-ETHYL-6-METHYL-9-NITRO-5H-PYRIDO[2,3-B][1,5]BENZODIAZEPIN-5-ONE - similarity: 0.78430
# Document Polysorbate 80 - similarity: 0.78402
# Document Balaglitazone - similarity: 0.78377
# Document Promegestone - similarity: 0.78336
# Document Anileridine - similarity: 0.78315
# Document Beclamide - similarity: 0.78313
# Document Stannsoporfin - similarity: 0.78303
# Document Tetrazepam - similarity: 0.78261
# Document Epicillin - similarity: 0.78238
# Document LCB01-0371 - similarity: 0.78210
# Document (3E)-3-[(phenylamino)methylidene]dihydrofuran-2(3H)-one - similarity: 0.78207
# Document 5'-O-(L-Prolylsulfamoyl)adenosine - similarity: 0.78202
# Document N-Methyl-Pyridoxal-5'-Phosphate - similarity: 0.78193
# Document {4-Amino-2-[(4-methoxyphenyl)amino]-1,3-thiazol-5-yl}(4-methoxyphenyl)methanone - similarity: 0.78162
# Document Pacritinib - similarity: 0.78160
# Document RUS 3108 - similarity: 0.78155
# Document Ponezumab - similarity: 0.78120
# Document Benzilone - similarity: 0.78117
# Document Manganese gluconate - similarity: 0.78106
# Document 4-HYDROXYBENZALDEHYDE O-(CYCLOHEXYLCARBONYL)OXIME - similarity: 0.78091
# Document Ornipressin - similarity: 0.78085
# Document Triticum aestivum pollen - similarity: 0.78084
# Document {3-[3-(3,4-Dimethoxy-Phenyl)-1-(1-{1-[2-(3,4,5-Trimethoxy-Phenyl)-Butyryl]-Piperidin-2yl}-Vinyloxy)-Propyl]-Phenoxy}-Acetic Acid - similarity: 0.78078
# Document N-(indole-3-acetyl)-L-aspartic acid - similarity: 0.78076
# Document Triazavirin - similarity: 0.78063
# Document Patent Blue - similarity: 0.78061
# Document 2-{[(4-CHLOROPHENOXY)ACETYL]AMINO}BENZOIC ACID - similarity: 0.78058
# Document Tramazoline - similarity: 0.78055
# Document N,N-Bis(3-(D-gluconamido)propyl)deoxycholamide - similarity: 0.78053
# Document GPI-0100 - similarity: 0.78052
# Document Repifermin - similarity: 0.78032
# Document Drometrizole trisiloxane - similarity: 0.78011
# Document Flumethasone - similarity: 0.77996
# Document Lintuzumab - similarity: 0.77979
# Document SLV319 - similarity: 0.77975
# Document Albaconazole - similarity: 0.77946
# Document +/-METHYL 4-(AMINOIMINOMETHYL)-BETA-[3- INH (AMINOIMINO)PHENYL]BENZENE PENTANOATE - similarity: 0.77932
# Document Lebrikizumab - similarity: 0.77931
# Document Amineptine - similarity: 0.77892
# Document 1,3-bis-([3-[3-[3-(4-{3-[3-nitro-5-(galactopyranosyloxy)-benzoylamino]-propyl}-piperazin-1-yl)-propylamino-3,4-dioxo-cyclobutenyl]-amino-propoxy-ethoxy-ethoxy]-propyl-]amino-carbonyloxy)-2-amino-propane - similarity: 0.77874
# Document Magnesium levulinate - similarity: 0.77860
# Document Dicoria canescens pollen - similarity: 0.77836
# Document 4-{5-[(Z)-(2-IMINO-4-OXO-1,3-THIAZOLIDIN-5-YLIDENE)METHYL]FURAN-2-YL}BENZENESULFONAMIDE - similarity: 0.77834
# Document Netazepide - similarity: 0.77827
# Document Belapectin - similarity: 0.77820
# Document 5-(5-CHLORO-2-THIENYL)-N-{(3S)-1-[(1S)-1-METHYL-2-MORPHOLIN-4-YL-2-OXOETHYL]-2-OXOPYRROLIDIN-3-YL}-1H-1,2,4-TRIAZOLE-3-SULFONAMIDE - similarity: 0.77812
# Document {4-[2,2-BIS(5-METHYL-1,2,4-OXADIAZOL-3-YL)-3-PHENYLPROPYL]PHENYL}SULFAMIC ACID - similarity: 0.77745
# Document Taranabant - similarity: 0.77739
# Document Ozarelix - similarity: 0.77734
# Document FR117016 - similarity: 0.77717
# Document Sugammadex - similarity: 0.77689
# Document Sirukumab - similarity: 0.77660
# Document Veralipride - similarity: 0.77641
# Document {(2S)-1-[N-(tert-butoxycarbonyl)glycyl]pyrrolidin-2-yl}methyl (3-chlorophenyl)acetate - similarity: 0.77603
# Document 11-[(MERCAPTOCARBONYL)OXY]UNDECANOIC ACID - similarity: 0.77546
# Document Ustekinumab - similarity: 0.77540
# Document Aminomethylcyclohexane - similarity: 0.77535
# Document Apilimod - similarity: 0.77487
# Document 5'-FLUORO-2',5'-DIDEOXYADENOSINE - similarity: 0.77484
# Document IQP-0528 - similarity: 0.77455
# Document R673 - similarity: 0.77438
# Document Leronlimab - similarity: 0.77407
# Document Valethamate - similarity: 0.77374
# Document Heptulose-2-Phosphate - similarity: 0.77373
# Document Tildrakizumab - similarity: 0.77369
# Document Ozanimod - similarity: 0.77347
# Document Acetone Cyanohydrin - similarity: 0.77324
# Document Polyestradiol phosphate - similarity: 0.77318
# Document GSI-136 - similarity: 0.77310
# Document Quaternium-15 - similarity: 0.77300
# Document Tomuzotuximab - similarity: 0.77292
# Document N-cyclopropyl-2',6-dimethyl-4'-(5-methyl-1,3,4-oxadiazol-2-yl)biphenyl-3-carboxamide - similarity: 0.77268
# Document Butorphanol - similarity: 0.77249
# Document Brodalumab - similarity: 0.77209
# Document Heterotheca inuloides flower - similarity: 0.77206
# Document PD-166326 - similarity: 0.77205
# Document Etilamfetamine - similarity: 0.77194
# Document 7-[(3-CHLOROBENZYL)OXY]-2-OXO-2H-CHROMENE-4-CARBALDEHYDE - similarity: 0.77171
# Document Fosifloxuridine nafalbenamide - similarity: 0.77168
# Document Paramethasone acetate - similarity: 0.77154
# Document Maribavir - similarity: 0.77136
# Document 17-METHYL-17-ALPHA-DIHYDROEQUILENIN - similarity: 0.77133
# Document Pexelizumab - similarity: 0.77128
# Document AT3022 - similarity: 0.77089
# Document Racemethionine - similarity: 0.77036
# Document 3-{3-[(DIMETHYLAMINO)METHYL]-1H-INDOL-7-YL}PROPAN-1-OL - similarity: 0.77030
# Document Ganetespib - similarity: 0.77022
# Document 7-amino-2-tert-butyl-4-{[2-(1H-imidazol-4-yl)ethyl]amino}pyrido[2,3-d]pyrimidine-6-carboxamide - similarity: 0.77022
# Document Estradiol acetate - similarity: 0.77015
# Document Eribaxaban - similarity: 0.76969
# Document Momelotinib - similarity: 0.76967
# Document Sepranolone - similarity: 0.76950
# Document GTI 2040 - similarity: 0.76903
# Document Prenylamine - similarity: 0.76896
# Document Penbutolol - similarity: 0.76878
# Document Stypocaulon scoparium - similarity: 0.76849
# Document Hydroquinone - similarity: 0.76827
# Document Oxilofrine - similarity: 0.76817
# Document PG-701 - similarity: 0.76810
# Document Chloroprocaine - similarity: 0.76786
# Document Vunakizumab - similarity: 0.76770
# Document Hydroxyprogesterone caproate - similarity: 0.76744
# Document (2Z)-2-cyano-N-(2,2'-dichlorobiphenyl-4-yl)-3-hydroxybut-2-enamide - similarity: 0.76729
# Document 3,6,9,12,15-PENTAOXATRICOSAN-1-OL - similarity: 0.76720
# Document Clofenotane - similarity: 0.76691
# Document Azidamfenicol - similarity: 0.76681
# Document Levonorgestrel - similarity: 0.76592
# Document Telbivudine - similarity: 0.76579
# Document Surinabant - similarity: 0.76577
# Document 1-((1R,2S)-1-{2-[2-(4-CHLOROPHENYL)-1,3-BENZOXAZOL-7-YL]ETHYL}-2-HYDROXYPROPYL)-1H-IMIDAZOLE-4-CARBOXAMIDE - similarity: 0.76564
# Document Uprifosbuvir - similarity: 0.76543
# Document TP-271 - similarity: 0.76521
# Document 3-(1H-indol-3-yl)-4-{1-[2-(1-methylpyrrolidin-2-yl)ethyl]-1H-indol-3-yl}-1H-pyrrole-2,5-dione - similarity: 0.76515
# Document Pegzilarginase - similarity: 0.76508
# Document 2-[(4-fluorophenyl)sulfonylamino]-N-oxo-ethanamide - similarity: 0.76458
# Document Nickel sulfate - similarity: 0.76444
# Document Fosdevirine - similarity: 0.76439
# Document Lumacaftor - similarity: 0.76431
# Document 2-AMINO-N,N-BIS(PHENYLMETHYL)-1,3-OXAZOLE-5-CARBOXAMIDE - similarity: 0.76427
# Document Morphine glucuronide - similarity: 0.76415
# Document Valrocemide - similarity: 0.76415
# Document Dimetindene - similarity: 0.76412
# Document ADP-597 - similarity: 0.76395
# Document Trospium - similarity: 0.76372
# Document Temsirolimus - similarity: 0.76372
# Document 2-(cycloheptylmethyl)-1,1-dioxido-1-benzothiophen-6-yl sulfamate - similarity: 0.76352
# Document Diclazuril - similarity: 0.76342
# Document Ralinepag - similarity: 0.76330
# Document MK-0736 - similarity: 0.76301
# Document 3-{[4-([amino(imino)methyl]aminosulfonyl)anilino]methylene}-2-oxo-2,3-dihydro-1H-indole - similarity: 0.76295
# Document Aflibercept - similarity: 0.76264
# Document Buckwheat - similarity: 0.76260
# Document Human Varicella-Zoster Immune Globulin - similarity: 0.76251
# Document 3-(2-aminoquinazolin-6-yl)-1-(3,3-dimethylindolin-6-yl)-4-methylpyridin-2(1H)-one - similarity: 0.76219
# Document MBX-8025 - similarity: 0.76207
# Document Dithioerythritol - similarity: 0.76201
# Document Hetacillin - similarity: 0.76186
# Document Tanomastat - similarity: 0.76166
# Document Adapalene - similarity: 0.76152
# Document Pipamperone - similarity: 0.76116
# Document Indium cation In-111 - similarity: 0.76097
# Document Manitimus - similarity: 0.76067
# Document Prethcamide - similarity: 0.76063
# Document Morniflumate - similarity: 0.76057
# Document 4-[[(2S)-2-[[(2S)-3-Carboxy-2-hydroxypropanoyl]amino]-4-methylpentanoyl]amino]butyl-(diaminomethylidene)azanium - similarity: 0.76048
# Document (R)-pyridin-4-yl[4-(2-pyrrolidin-1-ylethoxy)phenyl]methanol - similarity: 0.76047
# Document Acetaminophen - similarity: 0.76044
# Document (5R)-5-(4-{[(2R)-6-HYDROXY-2,5,7,8-TETRAMETHYL-3,4-DIHYDRO-2H-CHROMEN-2-YL]METHOXY}BENZYL)-1,3-THIAZOLIDINE-2,4-DIONE - similarity: 0.76042
# Document PI-88 - similarity: 0.76039
# Document 3-({4-[(1E)-3-morpholin-4-yl-3-oxoprop-1-en-1-yl]-2,3-bis(trifluoromethyl)phenyl}sulfanyl)aniline - similarity: 0.76005
# Document 9-Butyl-8-(3-Methoxybenzyl)-9h-Purin-6-Amine - similarity: 0.76000
# Document Pimethixene - similarity: 0.75999
# Document Anecortave acetate - similarity: 0.75994
# Document 2-(4-CARCOXY-5-ISOPROPYLTHIAZOLYL)BENZOPIPERIDINE - similarity: 0.75994
# Document Mepartricin - similarity: 0.75981
# Document Clefamide - similarity: 0.75940
# Document Loteprednol - similarity: 0.75928
# Document Oxatomide - similarity: 0.75906
# Document ISOQUINOLINE-5-SULFONIC ACID (2-(2-(4-CHLOROBENZYLOXY)ETHYLAMINO)ETHYL)AMIDE - similarity: 0.75904
# Document Bimekizumab - similarity: 0.75894
# Document Acacia longifolia pollen - similarity: 0.75885
# Document Fluprednisolone - similarity: 0.75885
# Document Pipecuronium - similarity: 0.75882
# Document Tralokinumab - similarity: 0.75880
# Document Losmapimod - similarity: 0.75861
# Document 9-(4-hydroxybutyl)-N2-phenylguanine - similarity: 0.75838
# Document Echinacea angustifolia root - similarity: 0.75832
# Document Difelikefalin - similarity: 0.75813
# Document Bouteloua gracilis pollen - similarity: 0.75803
# Document Hydrocortisone probutate - similarity: 0.75800
# Document MK-0767 - similarity: 0.75752
# Document Tetracaine - similarity: 0.75730
# Document [(3R,4S,5S,7R)-4,8-DIHYDROXY-3,5,7-TRIMETHYL-2-OXOOCTYL]PHOSPHONIC ACID - similarity: 0.75717
# Document Resorcinol monoacetate - similarity: 0.75680
# Document (2R)-2-(5-CHLORO-2-THIENYL)-N-{(3S)-1-[(1S)-1-METHYL-2-MORPHOLIN-4-YL-2-OXOETHYL]-2-OXOPYRROLIDIN-3-YL}PROPENE-1-SULFONAMIDE - similarity: 0.75679
# Document Narlaprevir - similarity: 0.75674
# Document 1-[4-(2-oxo-2-phenylethyl)phenyl]guanidine - similarity: 0.75657
# Document Hydrocortisone succinate - similarity: 0.75632
# Document DP-b99 - similarity: 0.75624
# Document Amatuximab - similarity: 0.75619
# Document (1S)-1-(1H-INDOL-3-YLMETHYL)-2-(2-PYRIDIN-4-YL-[1,7]NAPHTYRIDIN-5-YLOXY)-EHYLAMINE - similarity: 0.75607
# Document Crotamiton - similarity: 0.75601
# Document NAP-226-90 - similarity: 0.75568
# Document Dapaconazole - similarity: 0.75532
# Document Alprenolol - similarity: 0.75503
# Document Dexchlorpheniramine maleate - similarity: 0.75491
# Document Insulin glargine - similarity: 0.75484
# Document S-[(1-Hydroxy-2,2,5,5-tetramethyl-4-phenyl-2,5-dihydro-1H-pyrrol-3-yl)methyl] methanesulfonothioate - similarity: 0.75484
# Document Azeliragon - similarity: 0.75427
# Document Levallorphan - similarity: 0.75425
# Document Osocimab - similarity: 0.75421
# Document 2-Amino-6-Chloropyrazine - similarity: 0.75419
# Document Efrotomycin - similarity: 0.75410
# Document Tilletia caries - similarity: 0.75392
# Document dimethyl (1R,4S)-5,6-bis(4-hydroxyphenyl)-7-oxabicyclo[2.2.1]hepta-2,5-diene-2,3-dicarboxylate - similarity: 0.75392
# Document CA4P - similarity: 0.75388
# Document 4-(2-{[4-{[3-(4-Chlorophenyl)Propyl]Sulfanyl}-6-(1-Piperazinyl)-1,3,5-Triazin-2-Yl]Amino}Ethyl)Phenol - similarity: 0.75387
# Document Trichlormethiazide - similarity: 0.75385
# Document Ralimetinib - similarity: 0.75350
# Document 1-[(2S)-4-(5-phenyl-1H-pyrazolo[3,4-b]pyridin-4-yl)morpholin-2-yl]methanamine - similarity: 0.75340
# Document Pinus monticola pollen - similarity: 0.75328
# Document 5-methyl-2'-fluoroarauracil F-18 - similarity: 0.75324
# ...
# Document Nanaomycin D - similarity: -0.40922
# Document 1,4:3,6-Dianhydro-2-O-(3-carbamimidoylphenyl)-5-O-(4-carbamimidoylphenyl)-D-glucitol - similarity: -0.40943
# Document Nitroaspirin - similarity: -0.41061
# Document 2-(2f-Benzothiazolyl)-5-Styryl-3-(4f-Phthalhydrazidyl)Tetrazolium Chloride - similarity: -0.41118
# Document VK-2809 - similarity: -0.41199
# Document BOC-GAMMA-D-GLU-L-LYS(CBZ)-D-BOROALA - similarity: -0.41227
# Document 2-Bromo-6-chloro-purine - similarity: -0.41594
# Document 2-CHLORO-N-[(1R,2R)-1-HYDROXY-2,3-DIHYDRO-1H-INDEN-2-YL]-6H-THIENO[2,3-B]PYRROLE-5-CARBOXAMIDE - similarity: -0.41687
# Document Influenza A virus A/California/7/2009(H1N1)-like hemagglutinin antigen (propiolactone inactivated) - similarity: -0.41695
# Document 3-(5-Amino-3-imino-3H-pyrazol-4-ylazo)-benzoic acid - similarity: -0.41730
# Document (1R,3S,5S,8R)-8-Hydroxy-2-oxabicyclo[3.3.1]non-6-ene-3,5-dicarboxylic acid - similarity: -0.42067
# Document (3S)-3-cyclopentyl-6-methyl-7-[(4-methylpiperazin-1-yl)sulfonyl]-3,4-dihydro-2H-1,2,4-benzothiadiazine 1,1-dioxide - similarity: -0.42121
# Document Raxatrigine - similarity: -0.42395
# Document alpha-methylthiofentanyl - similarity: -0.42453
# Document Cefacetrile - similarity: -0.42547
# Document D-threo-neopterin - similarity: -0.42553
# Document Gamma-Arsono-Beta, Gamma-Methyleneadenosine-5'-Diphosphate - similarity: -0.42612
# Document Glisoxepide - similarity: -0.43076
# Document N-[1-(4-CARBAMIMIDOYL-BENZYLCARBAMOYL)-3-METHYLSULFANYL-PROPYL]-3-HYDROXY-2-PROPOXYAMINO-BUTYRAMID - similarity: -0.43376
# Document Oxazolam - similarity: -0.43592
# Document (2S)-8-[(tert-butoxycarbonyl)amino]-2-(1H-indol-3-yl)octanoic acid - similarity: -0.43758
# Document Etynodiol - similarity: -0.43888
# Document PCO-371 - similarity: -0.43995
# Document 9-Methyl Uric Acid - similarity: -0.44045
# Document (2R)-2-Acetamido-3-(octadecyloxy)propyl 2-(methylsulfanyl)ethyl hydrogen phosphate - similarity: -0.44111
# Document 3'-O-Acetylthymidine-5'-diphosphate - similarity: -0.44269
# Document Bordetella pertussis pertactin antigen (formaldehyde inactivated) - similarity: -0.44449
# Document 2-butyl-1-hydroxyguanidine - similarity: -0.44468
# Document Teclozan - similarity: -0.44515
# Document Sodium phosphate, dibasic - similarity: -0.44552
# Document (S)-N-(4-carbamimidoylbenzyl)-1-(2-(cyclopentylamino)ethanoyl)pyrrolidine-2-carboxamide - similarity: -0.44677
# Document 8-(Pyrimidin-2-Ylamino)Naphthalene-2-Carboximidamide - similarity: -0.44678
# Document (5R,6S,7S,8S)-5-hydroxymethyl-6,7,8-trihydroxy-tetrazolo[1,5-A]piperidine - similarity: -0.44779
# Document 5-(2,3-dichlorophenyl)-N-(pyridin-4-ylmethyl)pyrazolo[1,5-a]pyrimidin-7-amine - similarity: -0.44780
# Document (3R)-3-[3,5-Bis(trifluoromethyl)anilino]-2-cyano-3-sulfanylpropanamide - similarity: -0.44860
# Document Heparin Disaccharide I-S - similarity: -0.44944
# Document CGP 4832 - similarity: -0.44974
# Document 1,3,4,9-Tetrahydro-2-(Hydroxybenzoyl)-9-[(4-Hydroxyphenyl)Methyl]-6-Methoxy-2h-Pyrido[3,4-B]Indole - similarity: -0.44983
# Document 5-(4'-AMINO-1'-ETHYL-5',8'-DIFLUORO-1'H-SPIRO[PIPERIDINE-4,2'-QUINAZOLINE]-1-YLCARBONYL)PICOLINONITRILE - similarity: -0.45022
# Document Trestolone acetate - similarity: -0.45203
# Document 3h-Indole-5,6-Diol - similarity: -0.45475
# Document Bimoclomol - similarity: -0.45507
# Document (S)-oxalosuccinic acid - similarity: -0.45621
# Document Guanosine 5'-diphosphate 2':3'-cyclic monophosphate - similarity: -0.45830
# Document 2-Hexyloxy-6-Hydroxymethyl-Tetrahydro-Pyran-3,5-Diol - similarity: -0.45834
# Document Tucotuzumab celmoleukin - similarity: -0.45918
# Document 1-METHYL-5-(2-PHENOXYMETHYL-PYRROLIDINE-1-SULFONYL)-1H-INDOLE-2,3-DIONE - similarity: -0.45943
# Document 1-Androstenedione - similarity: -0.45966
# Document O1-Pentyl-Mannose - similarity: -0.45979
# Document Pyroxamide - similarity: -0.46058
# Document Oxidized Acetyl Dithranol - similarity: -0.46337
# Document Zytron - similarity: -0.46512
# Document 4-({4-[(4-methoxypyridin-2-yl)amino]piperidin-1-yl}carbonyl)benzonitrile - similarity: -0.46516
# Document Methicillin Acyl-Serine - similarity: -0.46536
# Document PDPSC18 - similarity: -0.46552
# Document WAY-151693 - similarity: -0.46663
# Document methyl 4-(2,3-dihydroxy-5-methylphenoxy)-2-hydroxy-6-methylbenzoate - similarity: -0.46897
# Document 3-Amino-N-{4-[2-(2,6-Dimethyl-Phenoxy)-Acetylamino]-3-Hydroxy-1-Isobutyl-5-Phenyl-Pentyl}-Benzamide - similarity: -0.47147
# Document CTX001 - similarity: -0.47155
# Document Sodium 1,2-Dipalmitoyl-sn-glycero-3-phospho-(1'-rac-glycerol) - similarity: -0.47175
# Document N-naphthalen-1-ylmethyl-2'-[3,5-dimethoxybenzamido]-2'-deoxy-adenosine - similarity: -0.47277
# Document 2-(CYCLOHEXYLMETHYLAMINO)-4-(PHENYLAMINO)PYRAZOLO[1,5-A][1,3,5]TRIAZINE-8-CARBONITRILE - similarity: -0.47385
# Document Adamantane-1-Carboxylic Acid-5-Dimethylamino-Naphthalene-1-Sulfonylamino-Butyl-Amide - similarity: -0.47520
# Document CMLVAX100 - similarity: -0.47665
# Document 3,8-Diamino-6-Phenyl-5-[6-[1-[2-[(1,2,3,4-Tetrahydro-9-Acridinyl)Amino]Ethyl]-1h-1,2,3-Triazol-5-Yl]Hexyl]-Phenanthridinium - similarity: -0.47826
# Document Cinolazepam - similarity: -0.48206
# Document CYT006-AngQb - similarity: -0.48207
# Document N-({4-[(2-aminopyridin-4-yl)oxy]-3-fluorophenyl}carbamoyl)-2-(4-fluorophenyl)acetamide - similarity: -0.48217
# Document 3-Chloro-9-Ethyl-6,7,8,9,10,11-Hexahydro-7,11-Methanocycloocta[B]Quinolin-12-Amine - similarity: -0.48283
# Document 2'-O-[1-ethyl-1H-imidazol)] thymidine-5'-monophosphate - similarity: -0.48316
# Document Ethyl-Carbamic Acid Methyl Ester - similarity: -0.48329
# Document Bunamiodyl - similarity: -0.48342
# Document RU82197 - similarity: -0.48545
# Document Metharbital - similarity: -0.48616
# Document 1,6-Naphthalenediol - similarity: -0.48691
# Document Talviraline - similarity: -0.48771
# Document (2Z)-N-biphenyl-4-yl-2-cyano-3-cyclopropyl-3-hydroxyprop-2-enamide - similarity: -0.48906
# Document Isocyanomethane - similarity: -0.48914
# Document 1-[(2,6-difluorophenyl)sulfonyl]-4-(2,3-dihydro-1,4-benzodioxin-6-ylsulfonyl)piperazine - similarity: -0.49011
# Document S,S'-(1,4-Phenylene-Bis(1,2-Ethanediyl))Bis-Isothiourea - similarity: -0.49019
# Document BA-2664 - similarity: -0.49028
# Document 4-(1h-Imidazol-4-Yl)-3-(5-Ethyl-2,4-Dihydroxy-Phenyl)-1h-Pyrazole - similarity: -0.49156
# Document N-[5-(ETHYLSULFONYL)-2-METHOXYPHENYL]-5-[3-(2-PYRIDINYL)PHENYL]-1,3-OXAZOL-2-AMINE - similarity: -0.49303
# Document Trifluperidol - similarity: -0.49333
# Document N-Dodecyl-N,N-Dimethyl-3-Ammonio-1-Propanesulfonate - similarity: -0.49574
# Document 5-aminonaphthalene-2-sulfonic acid - similarity: -0.49655
# Document Etryptamine - similarity: -0.49852
# Document Aspergillus niger var. niger - similarity: -0.50155
# Document Hydromorphinol - similarity: -0.50182
# Document Ridogrel - similarity: -0.50244
# Document 5-(3-Amino-4,4-Dihyroxy-Butylsulfanylmethyl)-Tetrahydro-Furan-2,3,4-Triol - similarity: -0.50278
# Document EM-1745 - similarity: -0.50639
# Document 1-Phenylsulfonamide-3-Trifluoromethyl-5-Parabromophenylpyrazole - similarity: -0.50652
# Document (2r)-2-{[Formyl(Hydroxy)Amino]Methyl}Hexanoic Acid - similarity: -0.50698
# Document 4-(5-Bromo-2-Oxo-2h-Indol-3-Ylazo)-Benzenesulfonamide - similarity: -0.50843
# Document N-((1R,2R)-2-(5-CHLORO-1H-INDOLE-2-CARBOXAMIDO)CYCLOHEXYL)-5-METHYL-4,5,6,7-TETRAHYDROTHIAZOLO[5,4-C]PYRIDINE-2-CARBOXAMIDE - similarity: -0.50943
# Document Adenosine-5'-Propylphosphate - similarity: -0.50979
# Document N-[(6S)-6-Carboxy-6-(glycylamino)hexanoyl]-D-alanyl-D-alanine - similarity: -0.51108
# Document LY231514 tetra glu - similarity: -0.51263
# Document Butanilicaine - similarity: -0.51315
# Document 9-Butyl-8-(2,5-Dimethoxy-Benzyl)-2-Fluoro-9h-Purin-6-Ylamine - similarity: -0.51329
# Document 3,4,5-Trimethoxyamphetamine - similarity: -0.51486
# Document Trifluoroacetonyl coenzyme A - similarity: -0.51595
# Document OPC-14523 - similarity: -0.51733
# Document 8-Benzyl-2-Hydroperoxy-2-(4-Hydroxy-Benzyl)-6-(4-Hydroxy-Phenyl)-2h-Imidazo[1,2-a]Pyrazin-3-One - similarity: -0.52134
# Document 10-formyl-5,8,10-trideazafolic acid - similarity: -0.52157
# Document Lysophosphotidylserine - similarity: -0.52355
# Document 2,5-dibenzyloxy-3-hydroxy-hexanedioic acid bis-[(2-hydroxy-indan-1-yl)-amide] - similarity: -0.52521
# Document 2-(Sec-Butyl)Thiazole - similarity: -0.52673
# Document Isopropamide - similarity: -0.52974
# Document Pyruvamide - similarity: -0.52992
# Document {4-[3-(4-acetyl-3-hydroxy-2-propylphenoxy)propoxy]phenoxy}acetic acid - similarity: -0.53028
# Document 2',3'-Dehydro-2',3'-Deoxy-Thymidine 5'-Diphosphate - similarity: -0.53057
# Document MK-0354 - similarity: -0.53159
# Document (2S)-4-METHYL-2-(3-PHENYLTHIOUREIDO)-N-((3S)-TETRAHYDRO-2-HYDROXY-3-FURANYL)PENTANAMIDE - similarity: -0.53163
# Document ETHYL HYDROGEN DIETHYLAMIDOPHOSPHATE - similarity: -0.53180
# Document 4R-Fluoro-N6-ethanimidoyl-L-lysine - similarity: -0.53362
# Document Epsilon-N-methyllysine - similarity: -0.53496
# Document D-1,4-dithiothreitol - similarity: -0.53544
# Document [1-(1-Methyl-4,5-Dioxo-Pent-2-Enylcarbamoyl)-2-Phenyl-Ethyl]-Carbamic Acid Benzyl Ester - similarity: -0.53911
# Document FR221647 - similarity: -0.54006
# Document Pseudouridine-5'-Monophosphate - similarity: -0.54229
# Document Adenosine-5'-(Dithio)Phosphate - similarity: -0.54260
# Document SO-101 - similarity: -0.54362
# Document 4-[(4-bromo-2-{[(3R,5S)-3,5-dimethylpiperidin-1-yl]carbonyl}phenyl)amino]-4-oxobutanoic acid - similarity: -0.54385
# Document (2S)-4-(4-fluorobenzyl)-N-(2-sulfanylethyl)piperazine-2-carboxamide - similarity: -0.54441
# Document (3R)-3-cyclopentyl-7-[(4-methylpiperazin-1-yl)sulfonyl]-3,4-dihydro-2H-1,2-benzothiazine 1,1-dioxide - similarity: -0.54631
# Document (3S)-Tetrahydro-3-furanyl {(2S,3S)-4-[(2S,4R)-4-{(1S,2R)-2-[(S)-amino(hydroxy)methoxy]-2,3-dihydro-1H-inden-1-yl}-2-benzyl-3-oxo-2-pyrrolidinyl]-3-hydroxy-1-phenyl-2-butanyl}carbamate - similarity: -0.54640
# Document Adenosine monotungstate - similarity: -0.54660
# Document CTS-21166 - similarity: -0.54766
# Document Broxyquinoline - similarity: -0.54808
# Document Lividomycin A - similarity: -0.54958
# Document Bamifylline - similarity: -0.55234
# Document CRA_1801 - similarity: -0.55286
# Document Sisunatovir - similarity: -0.55681
# Document Afelimomab - similarity: -0.55838
# Document Methyprylon - similarity: -0.56174
# Document 4-CHLORO-6-(4-PIPERAZIN-1-YL-1H-PYRAZOL-5-YL)BENZENE-1,3-DIOL - similarity: -0.56236
# Document 3-[(1-Amino-2-Carboxy-Ethyl)-Hydroxy-Phosphinoyl]-2-Methyl-Propionic Acid - similarity: -0.56242
# Document N-{[2-({[1-(4-CARBOXYBUTANOYL)AMINO]-2-PHENYLETHYL}-HYDROXYPHOSPHINYL)OXY]ACETYL}-2-PHENYLETHYLAMINE - similarity: -0.56330
# Document Efloxate - similarity: -0.56387
# Document 3-(4-Amino-1-Tert-Butyl-1h-Pyrazolo[3,4-D]Pyrimidin-3-Yl)Phenol - similarity: -0.56543
# Document 2-Amino-Vinyl-Phosphate - similarity: -0.56592
# Document SD146 - similarity: -0.56862
# Document N-[(Aminooxy)Carbonyl]Aniline - similarity: -0.57031
# Document 3-deoxy-D-arabino-hexonic acid - similarity: -0.57092
# Document 6-(2-Oxo-Hexahydro-Thieno[3,4-D]Imidazol-4-Yl)-Hexanoic Acid - similarity: -0.57248
# Document 2,4-Dinitrophenyl 2-Deoxy-2-Fluoro-Beta-D-Allopyranoside - similarity: -0.57275
# Document 4-(Hydrogen sulfate)-beta-D-galactopyranose - similarity: -0.57636
# Document AZD-8330 - similarity: -0.57877
# Document Aplindore - similarity: -0.57987
# Document 1,2-Dipalmitoyl-Phosphatidyl-Glycerole - similarity: -0.58030
# Document 1,2-icosapentoyl-sn-glycero-3-phosphoserine - similarity: -0.58192
# Document Acylated ceftazidime - similarity: -0.58889
# Document 9-(5,5-Difluoro-5-Phosphonopentyl)Guanine - similarity: -0.59031
# Document RU78783 - similarity: -0.59057
# Document Cyclo-Tetrametavanadate - similarity: -0.59391
# Document 3-Fluoro-2-Methyl-Aniline - similarity: -0.60075
# Document HCV-086 - similarity: -0.60145
# Document Thiarsahydroxy-Cysteine - similarity: -0.60241
# Document CHGN111 - similarity: -0.60352
# Document XL999 - similarity: -0.60522
# Document [1-HYDROXY-2-(1,1':3',1''-TERPHENYL-3-YLOXY)ETHANE-1,1-DIYL]BIS(PHOSPHONIC ACID) - similarity: -0.60604
# Document 2-[Trans-(4-Aminocyclohexyl)Amino]-6-(Benzyl-Amino)-9-Cyclopentylpurine - similarity: -0.60780
# Document N-(2-Thienylmethyl)-2,5-Thiophenedisulfonamide - similarity: -0.60888
# Document CERE-110 - similarity: -0.61111
# Document Tetanus Immune Globulin - similarity: -0.61367
# Document Hexadecanesulfonyl fluoride - similarity: -0.61405
# Document Xylose-derived lactam oxime - similarity: -0.62244
# Document Norflurane - similarity: -0.62518
# Document (2R)-1-[4-({6-[(2,6-Difluorophenyl)amino]-4-pyrimidinyl}amino)phenoxy]-3-(dimethylamino)-2-propanol - similarity: -0.62545
# Document 2-Amino-4-(4-Amino-Cyclohexa-2,5-Dienyl)-Butyric Acid - similarity: -0.62616
# Document 5-CHLORO-N-((1R,2S)-2-(4-(2-OXOPYRIDIN-1(2H)-YL)BENZAMIDO) CYCLOPENTYL)THIOPHENE-2-CARBOXAMIDE - similarity: -0.63145
# Document 4-Imino-5-Methidyl-2-Methylpyrimidine - similarity: -0.63203
# Document NN344 - similarity: -0.63488
# Document N-Methyldehydrobutyrine - similarity: -0.63621
# Document 2-CHLORO-N-[(3R)-2-OXO-1,2,3,4-TETRAHYDROQUINOLIN-3-YL]-6H-THIENO[2,3-B]PYRROLE-5-CARBOXAMIDE - similarity: -0.63775
# Document PYRIMIDINE-4,6-DICARBOXYLIC ACID BIS-(4-FLUORO-3-METHYL-BENZYLAMIDE) - similarity: -0.64375
# Document 2-Amino-4-methylphenol - similarity: -0.64650
# Document (2s,5s)-5-Carboxymethylproline - similarity: -0.64757
# Document Codeine-N-oxide - similarity: -0.65558
# Document 6-{4-[4-(4-CHLOROPHENYL)PIPERIDIN-4-YL]PHENYL}-9H-PURINE - similarity: -0.65572
# Document 5-(2-Fluoro-5-{(1E)-3-[3-hydroxy-2-(methoxycarbonyl)phenoxy]-1-propen-1-yl}phenyl)-1,2-oxazole-3-carboxylic acid - similarity: -0.65744
# Document 2-Hydroxy-5-({1-[(4-Methylphenoxy)Methyl]-3-Oxoprop-1-Enyl}Amino)-L-Tyrosine - similarity: -0.66012
# Document 1-{(2S,5S)-4-FLUORO-5-[(TRITYLOXY)METHYL]TETRAHYDROFURAN-2-YL}PYRIMIDINE-2,4(1H,3H)-DIONE - similarity: -0.66331
# Document Influenza A virus A/Kansas/14/2017 X-327 (H3N2) antigen (UV, formaldehyde inactivated) - similarity: -0.66344
# Document 4-epi-vancosaminyl derivative of vancomycin - similarity: -0.66664
# Document Hybrid Between B and C Type Hemes (Protoporphyrin Ixcontaining Fe) - similarity: -0.66956
# Document (2R,3S,5S)-2-(Hydroxymethyl)-5-[(2-sulfoethyl)carbamoyl]-3-pyrrolidiniumyl 2-acetamido-2-deoxy-4-O-sulfo-beta-D-glucopyranoside - similarity: -0.67120
# Document (4-{(2S)-2-[(tert-butoxycarbonyl)amino]-3-methoxy-3-oxopropyl}phenyl)methaneseleninic acid - similarity: -0.67131
# Document 3,6,9,12,15-PENTAOXAHEPTADECAN-1-OL - similarity: -0.68659
# Document 2-methyl-3,5,7,8-tetrahydro-4H-thiopyrano[4,3-d]pyrimidin-4-one - similarity: -0.69819
# Document GLUTATHIONE SULFINATE - similarity: -0.69961
# Document N-Allylaniline - similarity: -0.70090
# Document Diamino-N-[3-(1,3,2-dioxaborolan-2-yloxy)propyl]methaniminium - similarity: -0.71722
# Document 5,6-dihydroxy-NADP - similarity: -0.72024
# Document 7-(2,5-dihydropyrrol-1-yl)-6-phenyl-pyrido[6,5-d]pyrimidin-2-amine - similarity: -0.72145
# Document 2-[(2-NAPHTHYLSULFONYL)AMINO]ETHYL DIHYDROGEN PHOSPHATE - similarity: -0.72229
# Document 2-{[2-Oxo-2-(1-piperidinyl)ethyl]sulfanyl}-6-(trifluoromethyl)-4(1H)-pyrimidinone - similarity: -0.72413
# Document Iofetamine I-123 - similarity: -0.73193
# Document 5'-O-(L-Serylsulfamoyl)adenosine - similarity: -0.74171
# Document IR501 - similarity: -0.74294
# Document 3-Allylfentanyl - similarity: -0.75881
# Document (3r)-1-Acetyl-3-Methylpiperidine - similarity: -0.76109
# Document AP-22408 - similarity: -0.77022
# Document KC706 - similarity: -0.77275
# Document Ethyl-Trimethyl-Silane - similarity: -0.78648
# Document N-(P-CYANOPHENYL)-N'-DIPHENYLMETHYL-GUANIDINE-ACETIC ACID - similarity: -0.78806
# Document ATX-201 - similarity: -0.80258
# Document Cholesteryl Linoleate - similarity: -0.80665
# Document Mefruside - similarity: -0.81436
# Document Morella cerifera pollen - similarity: -0.85205
# Document N-(TRANS-4'-NITRO-4-STILBENYL)-N-METHYL-5-AMINO-PENTANOIC ACID - similarity: -0.92366
# Document Beta-Amino Isobutyrate - similarity: -0.92743
# == complete

# %%
# trained_doc_vec = model.docvecs[tags[0]]
# inferred_doc_vec = model.infer_vector(text)
# print(texts_and_tags[0].tags)
# print(texts_and_tags[0][0])

# len(model.docvecs)
# model.docvecs.most_similar('Lepirudin')
# model.most_similar('and', topn=10)
from scipy import spatial

# vec1 = d2v_model.infer_vector(fisrt_text.split())
# vec2 = d2v_model.infer_vector(second_text.split())

# cos_distance = spatial.distance.cosine(vec1, vec2)

# score = model.n_similarity(questions1_split[i],questions2_split[i])
score = model.docvecs.similarity('Lepirudin', 'Ximelagatran')


# lep_xime_similarity = spatial.distance.cosine(model.docvecs['Lepirudin'], model.docvecs['Ximelagatran'])
# lep_nita_similarity = spatial.distance.cosine(model.docvecs['Lepirudin'], model.docvecs['Nitazoxanide'])
# print(lep_xime_similarity)
# print(lep_nita_similarity)
# Out:
# <ipython-input-50-e2d2d85d7922>:17: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   score = model.similarity('Lepirudin', 'Ximelagatran')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-e2d2d85d7922> in <module>
#      15
#      16 # score = model.n_similarity(questions1_split[i],questions2_split[i])
# ---> 17 score = model.similarity('Lepirudin', 'Ximelagatran')
#      18
#      19
#
# ~\anaconda3\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1459                     stacklevel=2
#    1460                 )
# -> 1461                 return func(*args, **kwargs)
#    1462
#    1463             return new_func1
#
# ~\anaconda3\lib\site-packages\gensim\models\base_any2vec.py in similarity(self, w1, w2)
#    1436
#    1437         """
# -> 1438         return self.wv.similarity(w1, w2)
#    1439
#    1440     @deprecated("Method will be removed in 4.0.0, use self.wv.n_similarity() instead")
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in similarity(self, w1, w2)
#     972
#     973         """
# --> 974         return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#     975
#     976     def n_similarity(self, ws1, ws2):
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in get_vector(self, word)
#     469
#     470     def get_vector(self, word):
# --> 471         return self.word_vec(word)
#     472
#     473     def words_closer_than(self, w1, w2):
#
# ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'Lepirudin' not in vocabulary"

# %% [markdown]
# P01AX11 — Nitazoxanide
# B01AE02 — Lepirudin
# > similar 0.9988
#
# B01AE02 — Lepirudin
# B01AE05 — Ximelagatran
#
# 유사도 API
# model.n_similarity()
# : 단어 리스트에 있는 모든 단어 벡터의 mean을 계산
#
#  -> unit-normalzation -> cosine-similary 계산하기

# %%
df_atc.head()
# Out:
#   drugbank_id                 name     type                    groups  \
# 0     DB00001            Lepirudin  biotech                  approved
# 1     DB00002            Cetuximab  biotech                  approved
# 2     DB00003         Dornase alfa  biotech                  approved
# 3     DB00004  Denileukin diftitox  biotech  approved|investigational
# 4     DB00005           Etanercept  biotech  approved|investigational
#
#   atc_codes                                         categories inchikey inchi  \
# 0   B01AE02  Amino Acids, Peptides, and Proteins|Anticoagul...      NaN   NaN
# 1   L01XC06  Amino Acids, Peptides, and Proteins|Antibodies...      NaN   NaN
# 2   R05CB13  Amino Acids, Peptides, and Proteins|Cough and ...      NaN   NaN
# 3   L01XX29  ADP Ribose Transferases|Amino Acids, Peptides,...      NaN   NaN
# 4   L04AB01  Agents reducing cytokine levels|Amino Acids, P...      NaN   NaN
#
#                                          description
# 0  Lepirudin is identical to natural hirudin exce...
# 1  Cetuximab is an epidermal growth factor recept...
# 2  Dornase alfa is a biosynthetic form of human d...
# 3  A recombinant DNA-derived cytotoxic protein co...
# 4  Dimeric fusion protein consisting of the extra...

# %%
# Accesing vector
doc_vec = dict()
cnt=0
for text, tags in texts_and_tags:
    cnt += 1
    trained_doc_vec = model.docvecs[tags[0]]
    inferred_doc_vec = model.infer_vector(text)
    doc_vec[tags[0]] = [trained_doc_vec, inferred_doc_vec]
    
#     print(f"tags: {tags}, text: {text}")
    print(f"tags: {tags}")
    print(f"trained_doc_vec: {trained_doc_vec}")
    print(f"inferred_doc_vec: {inferred_doc_vec}")
    print("--"*20)
    if(cnt == 3):
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-282a1fa2ef63> in <module>
#       5     cnt += 1
#       6     trained_doc_vec = model.docvecs[tags[0]]
# ----> 7     inferred_doc_vec = model.infer_vector(text)
#       8     doc_vec[tags[0]] = [trained_doc_vec, inferred_doc_vec]
#       9
#
# ~\anaconda3\lib\site-packages\gensim\models\doc2vec.py in infer_vector(self, doc_words, alpha, min_alpha, epochs, steps)
#     660         """
#     661         if isinstance(doc_words, string_types):
# --> 662             raise TypeError("Parameter doc_words of infer_vector() must be a list of strings (not a single string).")
#     663
#     664         alpha = alpha or self.alpha
#
# TypeError: Parameter doc_words of infer_vector() must be a list of strings (not a single string).

# %%
# return_docs = model.docvecs.most_similar(positive=[inferred_vector],topn=5)
from scipy import spatial

dor_lepi = spatial.distance.cosine(doc_vec['Dornasealf'][1], doc_vec['Lepirudin'][1])
dor_xime = spatial.distance.cosine(doc_vec['Dornasealf'][1], doc_vec['Ximelagatr'][1])
lepi_xime = spatial.distance.cosine(doc_vec['Lepirudin'][1], doc_vec['Ximelagatr'][1])

print('dor_lepi: ', dor_lepi)
print('dor_xime: ', dor_xime)
print('lepi_xime: ', lepi_xime)
# for i in enumerate(doc_vec.keys()):
#     print(i)
#     spatial.distance.cosine(doc_vec[i][1], doc_vec[i+1][1])
# Out:
# dor_lepi:  0.5919299721717834
# dor_xime:  0.5868140459060669
# lepi_xime:  0.6061707735061646

# %%
# Document Clustering
print("##"*30)
print("K-Means Clustering")
print("##"*30)
Clustering_Method = KMeans(n_clusters=2, random_state=0)
X = model.docvecs.vectors_docs # document vector 전체를 가져옴. 
Clustering_Method.fit(X)# fitting 

cluster_dict = {i:[] for i in range(0, 2)}
for text_tags, label in zip(texts_and_tags, Clustering_Method.labels_):
    text, tags = text_tags
    cluster_dict[label].append(text)
for label, lst in cluster_dict.items():
    print(f"Cluster {label}")
    for x in lst:
        print(x)
    print("--"*30)
print("##"*20)
# Out:
# ############################################################
# K-Means Clustering
# ############################################################
# Cluster 0
# ['[', '``', 'dornase-alfa', 'cystic', 'fibrosis.', 'dornase-alfa', 'current', 'use', 'mucolyt', 'treat', 'pulmonari', 'diseas', '(', 'major', 'caus', 'morbid', 'mortal', ')', 'cystic', 'fibrosis.', 'reduc', 'mucu', 'viscos', 'lung', ',', 'promot', 'improv', 'clearanc', 'secretions.', 'updat', 'previous', 'publish', 'review.', 'determin', 'whether', 'use', 'dornase-alfa', 'cystic', 'fibrosi', 'associ', 'improv', 'mortal', 'morbid', 'compar', 'placebo', 'medic', 'improv', 'airway', 'clearanc', ',', 'identifi', 'advers', 'event', 'associ', 'use.', 'search', 'cochran', 'cystic', 'fibrosi', 'genet', 'disord', 'group', 'trial', 'regist', 'compris', 'refer', 'identifi', 'comprehens', 'electron', 'databas', 'search', ',', 'handsearch', 'relev', 'journal', 'abstract', 'conferences.', 'date', 'recent', 'search', 'group', "'s", 'cystic', 'fibrosi', 'regist', ':', '23', 'april', '2018.clinicaltrials.gov', 'intern', 'clinic', 'trial', 'registri', 'platform', 'also', 'search', 'identifi', 'unpublish', 'ongo', 'trials.', 'date', 'recent', 'search', ':', '07', 'june', '2018.', 'randomis', 'quasi-randomis', 'control', 'trial', 'compar', 'dornase-alfa', 'placebo', ',', 'standard', 'therapi', 'medic', 'improv', 'airway', 'clearance.', 'author', 'independ', 'assess', 'trial', 'inclus', 'criteria', ';', 'two', 'author', 'carri', 'analysi', 'methodolog', 'qualiti', 'data', 'extraction.', 'grade', 'use', 'assess', 'level', 'evidence.', 'search', 'identifi', '69', 'trial', ',', '19', '(', '2565', 'particip', ')', 'met', 'inclus', 'criteria.', 'fifteen', 'trial', 'compar', 'dornase-alfa', 'placebo', 'dornase-alfa', '(', '2447', 'particip', ')', ';', 'two', 'compar', 'daili', 'dornas', 'hyperton', 'salin', '(', '32', 'particip', ')', ';', 'one', 'compar', 'daili', 'dornase-alfa', 'hyperton', 'salin', 'altern', 'day', 'dornase-alfa', '(', '48', 'particip', ')', ';', 'one', 'compar', 'dornase-alfa', 'mannitol', 'combin', 'drug', '(', '38', 'particip', ')', '.', 'trial', 'durat', 'vari', 'six', 'day', 'three', 'years.dornase-alfa', 'compar', 'placebo', 'treatmentdornase-alfa', 'improv', 'forc', 'expiratori', 'volum', 'one', 'second', 'one', 'month', '(', 'four', 'trial', ',', '248', 'particip', ')', ',', 'three', 'month', '(', 'one', 'trial', ',', '320', 'particip', ';', 'moderate-qu', 'evid', ')', ',', 'six', 'month', '(', 'one', 'trial', ',', '647', 'particip', ';', 'high-qual', 'evid', ')', 'two', 'year', '(', 'one', 'trial', ',', '410', 'particip', ')', '.', 'limit', 'low-qual', 'evid', 'show', 'differ', 'group', 'chang', 'qualiti', 'life.', 'decreas', 'pulmonari', 'exacerb', 'dornase-alfa', 'trial', 'two', 'year', '(', 'moderate-qu', 'evid', ')', '.', 'one', 'trial', 'examin', 'cost', 'care', ',', 'includ', 'cost', 'dornase-alfa', ',', 'found', 'cost', 'save', 'dornase-alfa', 'offset', '18', '%', '38', '%', 'medic', 'costs.dornase-alfa', ':', 'daili', 'versu', 'altern', 'dayon', 'cross-ov', 'trial', '(', '43', 'children', ')', 'found', 'differ', 'treatment', 'regimen', 'lung', 'function', ',', 'qualiti', 'life', 'pulmonari', 'exacerb', '(', 'low-qual', 'evid', ')', '.dornase-alfa', 'compar', 'medic', 'improv', 'airway', 'clearanceresult', 'comparison', 'mixed.', 'one', 'trial', '(', '43', 'children', ')', 'show', 'greater', 'improv', 'forc', 'expiratori', 'volum', 'one', 'second', 'dornase-alfa', 'compar', 'hyperton', 'salin', '(', 'low-qual', 'evid', ')', ',', 'one', 'trial', '(', '23', 'particip', ')', 'report', 'differ', 'lung', 'function', 'dornase-alfa', 'mannitol', 'dornase-alfa', 'dornase-alfa', 'plu', 'mannitol', '(', 'low-qual', 'evid', ')', '.', 'one', 'trial', '(', '23', 'particip', ')', 'found', 'differ', 'qualiti', 'life', 'favour', 'dornase-alfa', 'compar', 'dornase-alfa', 'plu', 'mannitol', '(', 'low-qual', 'evid', ')', ';', 'comparison', 'found', 'differ', 'outcom', '(', 'low-qual', 'evid', ')', '.', 'trial', 'comparison', 'report', 'differ', 'group', 'number', 'pulmonari', 'exacerb', '(', 'low-qual', 'evid', ')', '.when', 'comparison ...
# ------------------------------------------------------------
# Cluster 1
# ['[', "'lepirudin", 'lepirudin', 'longer', 'market', 'unit', 'states.', 'limit', 'inform', 'indic', 'lepirudin', 'dose', '100', 'mg', 'daili', 'produc', 'low', 'level', 'milk.', 'larg', 'molecular', 'weight', ',', 'would', 'expect', 'absorb', 'breastmilk', 'infant.', 'lepirudin', 'would', 'expect', 'caus', 'advers', 'effect', 'breastf', 'infant', ',', 'especi', 'infant', 'older', '2', 'months.', '[', '1', ']', "'", ',', "'comparison", 'argatroban', 'lepirudin', 'bivalirudin', 'treatment', 'heparin-induc', 'thrombocytopenia', ':', 'systemat', 'review', 'meta-analysis.', 'prevent', 'thromboembol', 'event', 'associ', 'heparin-induc', 'thrombocytopenia', '(', 'hit', ')', ',', 'patient', 'usual', 'treat', 'argatroban', ',', 'lepirudin', ',', 'bivalirudin.', ',', 'conduct', 'meta-analysi', 'studi', 'compar', 'treatment', 'hit', 'follow', 'direct', 'thrombin', 'inhibitor', ':', 'argatroban', 'versu', 'lepirudin', 'argatroban', 'versu', 'bivalirudin.', 'systemat', 'search', 'pubm', ',', 'embas', ',', 'cochran', 'librari', 'databas', 'relev', 'studies.', 'clinic', 'outcom', 'thromboembol', 'complic', 'bleeding.', 'total', '589', 'articl', 'found', '9', 'final', 'includ', 'meta-analysis.', 'significantli', 'differ', 'thromboembol', 'complic', 'argatroban', 'hirudin', 'analogu', '(', 'lepirudin', 'bivalirudin', ')', 'treatment', 'hit', '(', 'lepirudin', ':', 'rr\\xa0=\\xa00.773', ',', '95', '%', 'ci\\xa0=\\xa00.449-1.331', ',', 'p\\xa0=\\xa00.353', ';', 'bivalirudin', ':', 'rr\\xa0=\\xa00.768', ',', '95', '%', 'ci\\xa0=\\xa00.386-1.527', ',', 'p\\xa0=\\xa00.452', ')', '.', 'moreov', ',', 'incid', 'clinic', 'bleed', 'argatroban', 'similar', 'hirudin', 'analogu', '(', 'lepirudin', ':', 'rr\\xa0=\\xa00.755', ',', '95', '%', 'ci\\xa0=\\xa00.531-1.073', ',', 'p\\xa0=\\xa00.117', ';', 'bivalirudin', ':', 'rr\\xa0=\\xa00.995', ',', '95', '%', 'ci\\xa0=\\xa00.673-1.472', ',', 'p\\xa0=\\xa00.981', ')', '.', 'current', 'evid', 'show', 'argatroban', 'similar', 'effect', 'safeti', 'lepirudin', 'bivalirudin', 'defend', 'hit.', "'", ',', "'lepirudin", 'manag', 'heparin-induc', 'thrombocytopenia.', 'lepirudin', 'recombin', 'hirudin', 'exert', 'anticoagul', 'effect', 'direct', 'inhibit', 'thrombin.', 'lepirudin', 'indic', 'anticoagul', 'patient', 'heparin-induc', 'thrombocytopenia', '(', 'hit', ')', 'associ', 'thromboembol', 'diseas', 'prevent', 'thromboembol', 'complications.', 'review', 'address', 'variou', 'clinic', 'use', 'lepirudin', 'includ', 'limit', 'fda', 'approv', 'indication.', 'object', 'provid', 'updat', 'overview', 'clinic', 'use', 'pharmacolog', 'agent.', 'addit', ',', 'address', 'certain', 'area', 'controversi', 'especi', 'pertain', 'dose', 'lepirudin', 'use', 'differ', 'clinic', 'situations.', 'literatur', 'review', 'use', 'appropri', 'search', 'term', 'pubm', 'ovid', 'medlin', 'databases.', 'lepirudin', 'continu', 'valuabl', 'anticoagul', 'manag', 'hit.', 'lepirudin', 'highest', 'recommend', 'treatment', 'hit', 'base', 'evid', 'clinic', 'trials.', 'minor', 'modif', 'dose', 'standard', 'label', 'recommend', 'may', 'simplifi', 'use', 'enhanc', 'safety.', "'", ',', "'lepirudin", ':', 'bival', 'direct', 'thrombin', 'inhibitor', 'anticoagul', 'therapy.', 'lepirudin', '(', 'refludan', ')', ',', 'berlex', 'laboratori', ',', 'usa', 'canada', ';', 'pharmion', ',', 'countri', ')', ',', 'recombin', 'deriv', 'natur', 'occur', 'leech', 'anticoagul', 'hirudin', ',', 'first', 'direct', 'thrombin', 'inhibitor', 'approv', 'european', 'agenc', 'evalu', 'medicin', 'product', 'us', 'food', 'drug', 'administr', 'treatment', 'heparin-induc', 'thrombocytopenia.', 'sinc', 'introduct', 'europ', 'usa', ',', 'studi', '7000', 'patient', 'requir', 'anticoagul', 'condit', 'includ', 'acut', 'coronari', 'syndrom', ',', 'percutan', 'coronari', 'intervent', ',', 'cardiopulmonari', 'bypass', 'heparin-induc', 'thrombocytopenia.', 'three', 'european', 'clinic', 'trial', ',', 'design', 'heparin-associ', 'thrombocytopenia', '(', 'hat', ')', '-1', ',', '-2', '-3', ',', 'demo ...
# ['[', "'ximelagatran.", 'despit', 'signific', 'advanc', 'last', '50', 'year', 'regard', 'anticoagul', 'therapi', ',', 'warfarin', 'remain', 'definit', 'standard', 'long-term', 'prevent', 'thromboembol', 'event', 'at-risk', 'patient', ',', 'except', 'acut', 'coronari', 'syndrom', ',', 'antiplatelet', 'preferred.', 'ximelagatran', ',', 'prodrug', 'melagatran', ',', 'oral', 'administ', 'direct', 'thrombin', 'inhibitor', 'whose', 'therapeut', 'potenti', 'investig', 'venou', 'thromboembol', ',', 'acut', 'coronari', 'syndrom', 'prevent', 'stroke', 'atrial', 'fibrillation.', 'clinic', 'studi', 'demonstr', 'ximelagatran', 'compar', 'efficaci', 'oral', 'vitamin', 'k', 'antagonist', 'warfarin', 'low', 'molecular', 'weight', 'heparin', 'prophylaxi', 'venou', 'thromboembol', ',', 'compar', 'warfarin', 'stroke', 'prevent', 'set', 'atrial', 'fibril', ',', ',', 'combin', 'aspirin', ',', 'effect', 'aspirin', 'alon', 'prevent', 'major', 'advers', 'cardiovascular', 'event', 'patient', 'recent', 'myocardi', 'infarction.', 'double-blind', 'trial', 'also', 'reveal', 'efficaci', 'ximelagatran', 'secondari', 'prevent', 'venou', 'thromboembol', 'shown', 'agent', 'effect', 'enoxaparin/warfarin', 'treat', 'patient', 'acut', 'deep', 'vein', 'thrombosis.', 'advers', 'effect', 'ximelagatran', 'includ', 'elev', 'alanin', 'transaminas', '(', 'alt', ')', ',', 'may', 'requir', 'monitor', ',', 'bleed', 'complications.', 'bleed', 'complic', 'appear', 'less', 'least', 'compar', 'occur', 'standard', 'anticoagul', 'treatment', 'like', 'warfarin', 'low', 'molecular', 'weight', 'heparin.', 'addit', 'favor', 'efficaci', 'safeti', 'profil', 'comparison', 'standard', 'anticoagul', 'therapi', ',', 'conveni', 'oral', ',', 'fixed-dos', 'administr', 'without', 'need', 'anticoagul', 'monitor', 'might', 'help', 'encourag', 'wider', 'use', 'appropri', 'anticoagul', 'use', 'ximelagatran', 'across', 'popul', 'risk', ',', 'reduc', 'incid', 'thromboembol', 'events.', "'", ',', "'ximelagatran", '(', 'astrazeneca', ')', '.', 'astrazeneca', '(', 'formerli', 'astra', ')', 'develop', 'ximelagatran', ',', 'oral', 'activ', 'thrombin', 'inhibitor', 'prodrug', 'melagatran', ',', 'potenti', 'prevent', 'treatment', 'venou', 'thromboembol', '(', 'vte', ')', 'hip', 'knee', 'replac', ',', 'prevent', 'stroke', 'atrialfibril', '(', 'af', ')', 'post', 'acut', 'coronari', 'syndrome.', 'decemb', '1999', ',', 'compound', 'undergo', 'phase', 'iii', 'trial', 'prevent', 'vte', '[', '349551', ']', ';', 'ongo', 'decemb', '2001.', 'decemb', '2000', ',', 'ximelagatran', 'enter', 'phase', 'iii', 'trial', 'prevent', 'stroke', 'atrial', 'fibril', '[', '395212', ']', '.', 'septemb', '2000', ',', 'compani', 'expect', 'global', 'nda', 'file', 'indic', 'take', 'place', 'middl', '2001', '[', '383469', ']', ';', 'howev', ',', 'decemb', '2000', 'revis', 'second', 'half', '2002', '[', '395212', ']', ',', 'march', '2001', ',', 'second', 'quarter', '2003', '[', '402040', ']', ',', '[', '416882', ']', ',', '[', '431673', ']', '.', 'decemb', '2000', ',', 'phase', 'ii', 'trial', 'underway', 'ximelagatran', 'potenti', 'treatment', 'follow', 'myocardi', 'infarct', '[', '395237', ']', '.', 'decemb', '2001', ',', 'earli', 'phase', 'clinic', 'trial', 'ongo', 'post', 'acut', 'coronari', 'syndrom', '[', '431673', ']', '.', 'decemb', '2001', ',', 'eu', 'us', 'file', 'vte', 'prevent', 'anticip', 'third', 'quarter', '2002', 'second', 'quarter', '2003', ',', 'respect', '[', '3144721', ',', '[', '350050', ']', ',', '[', '431673', ']', '.', 'exanta', 'trade', 'name', 'melagatran', 'ximelagatran.', '1998', ',', 'market', 'ximelagatran', 'us', 'assign', 'astra/merek', 'joint', 'market', 'ventur', ',', 'prior', 'merger', '[', '276577', ']', '.', 'april', '1999', ',', 'abn', 'predict', 'sale', '4', 'pound', 'million', '2003', '[', '328676', ']', ',', '[', '394606', ']', '.', 'decemb', '2000', ',', 'lehman', 'brother', 'estim', 'peak', 'sale', '$', '1.4', 'billion', '[', '394606', ']', '.', 'time', ',', 'abn-amro', 'predict', 'peak', 'sale ...
# ------------------------------------------------------------
# ########################################
