# %%
import h5py
import numpy as np

pubmed_entity_2048 = f1 = h5py.File('pubmed_entity_2048.h5','r+')

# %%
len(pubmed_entity_2048)
# Out:
# 2048

# %%
pubmed_entity_2048.keys()
# Out:
# <KeysViewHDF5 ['"cblD-variant 1"', "'Ptb 33'", "'reductase'", '( )-rhabdastrellic acid A', '(+', '(+)- And (-)-amphetamine', '(2)SnL(2)', '(2R,4R)-2-amino', '(2S,3S)-2,3-butanediol', '(3R)-3-hydroxypiperidine hydrochloride', '(9R)-9-(3-iodo-4-methylphenyl)-5,9', '(AP*)G(8-oxo)T', '(Cu,Ag)S(4)', '(E)-1-(Furan-2-yl) methylene)-2-(1-phenylvinyl) hydrazine', '(OH) 0.11H2O', '(R,S)-2-octanol', '(S)-(+)-Ketoprofen', '(S)-salsolinol', '(SiW11 O39)4 x 10H2O', '(Z,Z)-1,3-dienes', '(dihapto-[60]fullerene) pentacarbonyl', '(nuclear factor) kB kinase b', '(p-MeOC(6)', '(~혻35%) and renal organic anion transp', '-1,3-diaryl-3-hydroxypropanone', '-3, 7, 11-trimethyldodeca-2,6-diene', '-384C', '-450(17)alpha lyase', '-C-C- family', '-ENaC protein', '-PRN', '-Weber syndrome', '-lactamase genes', '1,1-dichlorobutane', '1,2,2-trisinapoylgentiobose', '1,2-trimethylsilyl', '1-(1-Benzyl-1H-tetrazol-5-yl)propa-1,2-diene', '1-(5-iodonaphthalene-1-sulphonyl', '1-Hydroxyethane', '1-O-alkyl-2,3-DAG', '1-cyano-
# ...

# %%
# pubmed_entity_2048["'reductase'"]

for key in pubmed_entity_2048.keys():
    print(f'{key}: {pubmed_entity_2048[key]}')
# Out:
# "cblD-variant 1": <HDF5 group "/"cblD-variant 1"" (1 members)>
# 'Ptb 33': <HDF5 group "/'Ptb 33'" (1 members)>
# 'reductase': <HDF5 group "/'reductase'" (1 members)>
# ( )-rhabdastrellic acid A: <HDF5 group "/( )-rhabdastrellic acid A" (1 members)>
# (+: <HDF5 group "/(+" (1 members)>
# (+)- And (-)-amphetamine: <HDF5 group "/(+)- And (-)-amphetamine" (1 members)>
# (2)SnL(2): <HDF5 group "/(2)SnL(2)" (1 members)>
# (2R,4R)-2-amino: <HDF5 group "/(2R,4R)-2-amino" (1 members)>
# (2S,3S)-2,3-butanediol: <HDF5 group "/(2S,3S)-2,3-butanediol" (1 members)>
# (3R)-3-hydroxypiperidine hydrochloride: <HDF5 group "/(3R)-3-hydroxypiperidine hydrochloride" (1 members)>
# (9R)-9-(3-iodo-4-methylphenyl)-5,9: <HDF5 group "/(9R)-9-(3-iodo-4-methylphenyl)-5,9" (1 members)>
# (AP*)G(8-oxo)T: <HDF5 group "/(AP*)G(8-oxo)T" (1 members)>
# (Cu,Ag)S(4): <HDF5 group "/(Cu,Ag)S(4)" (1 members)>
# ...

# %%
# %pwd
# Out:
# 'D:\\WorkSpace\\master_thesis\\doc2Vec\\biobert-pytorch\\embedding'

# %%
# export DATA_PATH=pubmed_entity_2048.txt
# export OUTPUT_PATH=pubmed_entity_2048.h5

set DATA_PATH=pubmed_entity_2048.txt
set OUTPUT_PATH=pubmed_entity_2048.h5
# Out:
#   File "<ipython-input-23-aaa1a49f46c9>", line 4
#     set DATA_PATH=pubmed_entity_2048.txt
#         ^
# SyntaxError: invalid syntax

# %%
# load_embedding.py - import part

import logging
import os
import sys
from dataclasses import dataclass, field
from typing import Dict, List, Optional, Tuple
from torch.utils.data.dataloader import DataLoader

import numpy as np
import torch
import h5py
import pdb
from tqdm import tqdm
from transformers import (
    HfArgumentParser,
)

# %%
# load_embedding.py - function

# Setup logging
logging.basicConfig(
    format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s",
    datefmt="%m/%d/%Y %H:%M:%S",
    level=logging.INFO,
)

logger = logging.getLogger(__name__)

@dataclass
class DataArguments:
    """
    Arguments pertaining to what data we are going to input our model for training and eval.
    """
    # For Linux
    indexed_path: str = field(
        metadata={"help": "indexed h5 file path"}
    )
    inputtext_path: str = field(
        metadata={"help": "The input text file path"}
    )
        
#     indexed_path = 'pubmed_entity_2048.h5'
#     inputtext_path = 'pubmed_entity_2048.txt'
    

def main():
    # We now keep distinct sets of args, for a cleaner separation of concerns.
    parser = HfArgumentParser((DataArguments))
    data_args = parser.parse_args_into_dataclasses()[0]
    
    print(type(parser))
    print(parser)

    with h5py.File(data_args.indexed_path, 'r') as f:
        with open(data_args.inputtext_path, 'r') as f_in:
            
            print("The number of keys in h5: {}".format(len(f)))
            for i, input in enumerate(f_in):
                entity_name = input.strip()
                
                embedding = f[entity_name]['embedding'][:]
                
                print("entity_name = {}".format(entity_name))
                print("embedding = {}".format(embedding))
                
                break

def _mp_fn(index):
    # For xla_spawn (TPUs)
    main()

if __name__ == "__main__":
    main()
# Out:
# <class 'transformers.hf_argparser.HfArgumentParser'>
# HfArgumentParser(prog='ipykernel_launcher.py', usage=None, description=None, formatter_class=<class 'argparse.HelpFormatter'>, conflict_handler='error', add_help=True)

# %%
import pickle

with open("D:/WorkSpace/master_thesis/doc2Vec/biobert-pytorch/embedding/embedding_result", "rb") as f:
    embedding_result = pickle.load(f)

# %%
embedding_result
# Out:
# array([-1.01426110e-01, -2.61601031e-01,  1.65144186e-02,  1.16322182e-01,
#         2.00061709e-01,  4.56174135e-01, -3.88412178e-03, -1.09977089e-01,
#        -5.11399880e-02,  1.49866432e-01,  1.70121223e-01,  2.93048710e-01,
#        -4.52051491e-01,  4.51751314e-02, -6.16461746e-02,  7.26750866e-02,
#         1.62116840e-01,  6.37142733e-02,  7.08243176e-02,  2.49055959e-02,
#        -2.15677828e-01, -9.67691690e-02, -4.43008281e-02, -5.10224104e-02,
#         2.01230362e-01, -2.06396252e-01, -1.19882405e-01,  1.01232693e-01,
#        -3.41172516e-01,  2.62735546e-01, -1.24747060e-01,  2.31568128e-01,
#         1.96467966e-01,  2.75756419e-01, -5.14487028e-02, -3.10440250e-02,
#        -4.60623316e-02, -1.29981667e-01, -1.92022115e-01,  2.38468811e-01,
#         7.20338970e-02,  6.41142279e-02,  1.88967317e-01, -2.69384265e-01,
